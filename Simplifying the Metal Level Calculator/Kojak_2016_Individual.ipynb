# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Attribute Selection for Individual Plans from PlanAttributes.csv

# %%
df = pd.read_csv('PlanAttributes.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77353 entries, 0 to 77352
# Columns: 176 entries, AVCalculatorOutputNumber to WellnessProgramOffered
# dtypes: float64(7), int64(9), object(160)
# memory usage: 103.9+ MB

# %%
for column in df.columns:
    print ('{0:8} {1:8} {2:6} {3!s:8} {4:10}'.format(df[column].isnull().sum(), 
            df[column].notnull().sum(),
            round(df[column].notnull().sum()/df[column].notnull().count(),3), 
            df[column].dtype, column))
# Out:
#    22825    54528  0.705 object   AVCalculatorOutputNumber
#        0    77353    1.0 int64    BeginPrimaryCareCostSharingAfterNumberOfVisits
#        0    77353    1.0 int64    BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays
#        0    77353    1.0 int64    BenefitPackageId
#        0    77353    1.0 int64    BusinessYear
#        0    77353    1.0 object   CSRVariationType
#        0    77353    1.0 object   ChildOnlyOffering
#    76916      437  0.006 object   ChildOnlyPlanId
#    49972    27381  0.354 object   CompositeRatingOffered
#    76425      928  0.012 object   DEHBCombInnOonFamilyMOOP
#    77130      223  0.003 object   DEHBCombInnOonFamilyPerGroupMOOP
#    77130      223  0.003 object   DEHBCombInnOonFamilyPerPersonMOOP
#    76202     1151  0.015 object   DEHBCombInnOonIndividualMOOP
#    58680    18673  0.241 object   DEHBDedCombInnOonFamily
#    67927     9426  0.122 object   DEHBDedCombInnOonFamilyPerGroup
#    67927     9426  0.122 object   DEHBDedCombInnOonFamilyPerPerson
#    49254    28099  0.363 object   DEHBDedCombInnOonIndividual
#    49254    28099  0.363 object   DEHBDedInnTier1Coinsurance
#    58680    18673  0.241 object   DEHBDedInnTier1Family
#    67927     9426  0.122 object   DEHBDedInnTier1FamilyPerGroup
#    67927     9426  0.122 object   DEHBDedInnTier1FamilyPerPerson
#    49254    28099  0.363 object   DEHBDedInnTier1Individual
#    74592     2761  0.036 object   DEHBDedInnTier2Coinsurance
#    76397      956  0.012 object   DEHBDedInnTier2Family
#    75548     1805  0.023 object   DEHBDedInnTier2FamilyPerGroup
#    75548     1805  0.023 object   DEHBDedInnTier2FamilyPerPerson
#    74592     2761  0.036 object   DEHBDedInnTier2Individual
#    58680    18673  0.241 object   DEHBDedOutOfNetFamily
#    67927     9426  0.122 object   DEHBDedOutOfNetFamilyPerGroup
#    67927     9426  0.122 object   DEHBDedOutOfNetFamilyPerPerson
#    49254    28099  0.363 object   DEHBDedOutOfNetIndividual
#    76425      928  0.012 object   DEHBInnTier1FamilyMOOP
#    77130      223  0.003 object   DEHBInnTier1FamilyPerGroupMOOP
#    77130      223  0.003 object   DEHBInnTier1FamilyPerPersonMOOP
#    76202     1151  0.015 object   DEHBInnTier1IndividualMOOP
#    77353        0    0.0 float64  DEHBInnTier2FamilyMOOP
#    77353        0    0.0 float64  DEHBInnTier2FamilyPerGroupMOOP
#    77353        0    0.0 float64  DEHBInnTier2FamilyPerPersonMOOP
#    77353        0    0.0 float64  DEHBInnTier2IndividualMOOP
#    76425      928  0.012 object   DEHBOutOfNetFamilyMOOP
#    77130      223  0.003 object   DEHBOutOfNetFamilyPerGroupMOOP
#    77130      223  0.003 object   DEHBOutOfNetFamilyPerPersonMOOP
#    76202     1151  0.015 object   DEHBOutOfNetIndividualMOOP
#        0    77353    1.0 object   DentalOnlyPlan
#    15387    61966  0.801 object   DiseaseManagementProgramsOffered
#    65704    11649  0.151 object   EHBPediatricDentalApportionmentQuantity
#    35476    41877  0.541 float64  EHBPercentPremiumS4
#    54243    23110  0.299 float64  EHBPercentTotalPremium
#        0    77353    1.0 object   FirstTierUtilization
#    11649    65704  0.849 object   FormularyId
#    11807    65546  0.847 object   FormularyURL
#        0    77353    1.0 object   HIOSProductId
#    65503    11850  0.153 float64  HPID
#    66641    10712  0.138 object   HSAOrHRAEmployerContribution
#    77067      286  0.004 object   HSAOrHRAEmployerContributionAmount
#        0    77353    1.0 object   ImportDate
#    22361    54992  0.711 object   IndianPlanVariationEstimatedAdvancedPaymentAmountPerEnrollee
#        0    77353    1.0 int64    InpatientCopaymentMaximumDays
#    65704    11649  0.151 object   IsGuaranteedRate
#    11649    65704  0.849 object   IsHSAEligible
#        0    77353    1.0 object   IsNewPlan
#    11649    65704  0.849 object   IsNoticeRequiredForPregnancy
#    11649    65704  0.849 object   IsReferralRequiredForSpecialist
#    34827    42526   0.55 object   IssuerActuarialValue
#        0    77353    1.0 int64    IssuerId
#        0    77353    1.0 int64    IssuerId2
#    68631     8722  0.113 object   MEHBCombInnOonFamilyMOOP
#    73275     4078  0.053 object   MEHBCombInnOonFamilyPerGroupMOOP
#    73275     4078  0.053 object   MEHBCombInnOonFamilyPerPersonMOOP
#    64553    12800  0.165 object   MEHBCombInnOonIndividualMOOP
#    50886    26467  0.342 object   MEHBDedCombInnOonFamily
#    64072    13281  0.172 object   MEHBDedCombInnOonFamilyPerGroup
#    64072    13281  0.172 object   MEHBDedCombInnOonFamilyPerPerson
#    37605    39748  0.514 object   MEHBDedCombInnOonIndividual
#    49254    28099  0.363 object   MEHBDedInnTier1Coinsurance
#    50886    26467  0.342 object   MEHBDedInnTier1Family
#    64072    13281  0.172 object   MEHBDedInnTier1FamilyPerGroup
#    64072    13281  0.172 object   MEHBDedInnTier1FamilyPerPerson
#    37605    39748  0.514 object   MEHBDedInnTier1Individual
#    74592     2761  0.036 object   MEHBDedInnTier2Coinsurance
#    76090     1263  0.016 object   MEHBDedInnTier2Family
#    75338     2015  0.026 object   MEHBDedInnTier2FamilyPerGroup
#    75338     2015  0.026 object   MEHBDedInnTier2FamilyPerPerson
#    74075     3278  0.042 object   MEHBDedInnTier2Individual
#    50886    26467  0.342 object   MEHBDedOutOfNetFamily
#    64072    13281  0.172 object   MEHBDedOutOfNetFamilyPerGroup
#    64072    13281  0.172 object   MEHBDedOutOfNetFamilyPerPerson
#    37605    39748  0.514 object   MEHBDedOutOfNetIndividual
#    68631     8722  0.113 object   MEHBInnTier1FamilyMOOP
#    73275     4078  0.053 object   MEHBInnTier1FamilyPerGroupMOOP
#    73275     4078  0.053 object   MEHBInnTier1FamilyPerPersonMOOP
#    64553    12800  0.165 object   MEHBInnTier1IndividualMOOP
#    77046      307  0.004 object   MEHBInnTier2FamilyMOOP
#    77143      210  0.003 object   MEHBInnTier2FamilyPerGroupMOOP
#    77143      210  0.003 object   MEHBInnTier2FamilyPerPersonMOOP
#    76836      517  0.007 object   MEHBInnTier2IndividualMOOP
#    68631     8722  0.113 object   MEHBOutOfNetFamilyMOOP
#    73275     4078  0.053 object   MEHBOutOfNetFamilyPerGroupMOOP
#    73275     4078  0.053 object   MEHBOutOfNetFamilyPerPersonMOOP
#    64553    12800  0.165 object   MEHBOutOfNetIndividualMOOP
#        0    77353    1.0 object   MarketCoverage
#    11649    65704  0.849 object   MedicalDrugDeductiblesIntegrated
#    11649    65704  0.849 object   MedicalDrugMaximumOutofPocketIntegrated
#        0    77353    1.0 object   MetalLevel
#        0    77353    1.0 object   MultipleInNetworkTiers
#        0    77353    1.0 object   NationalNetwork
#        0    77353    1.0 object   NetworkId
#        0    77353    1.0 object   OutOfCountryCoverage
#    21631    55722   0.72 object   OutOfCountryCoverageDescription
#        0    77353    1.0 object   OutOfServiceAreaCoverage
#     8838    68515  0.886 object   OutOfServiceAreaCoverageDescription
#     9062    68291  0.883 object   PlanBrochure
#        0    77353    1.0 object   PlanEffictiveDate
#    49694    27659  0.358 object   PlanExpirationDate
#        0    77353    1.0 object   PlanId
#    67791     9562  0.124 object   PlanLevelExclusions
#        0    77353    1.0 object   PlanMarketingName
#        0    77353    1.0 object   PlanType
#        0    77353    1.0 object   QHPNonQHPTypeId
#        0    77353    1.0 int64    RowNumber
#    39354    37999  0.491 object   SBCHavingDiabetesCoinsurance
#    39277    38076  0.492 object   SBCHavingDiabetesCopayment
#    39271    38082  0.492 object   SBCHavingDiabetesDeductible
#    39344    38009  0.491 object   SBCHavingDiabetesLimit
#    39324    38029  0.492 object   SBCHavingaBabyCoinsurance
#    39255    38098  0.493 object   SBCHavingaBabyCopayment
#    39259    38094  0.492 object   SBCHavingaBabyDeductible
#    39332    38021  0.492 object   SBCHavingaBabyLimit
#    68763     8590  0.111 object   SecondTierUtilization
#        0    77353    1.0 object   ServiceAreaId
#        0    77353    1.0 object   SourceName
#    59388    17965  0.232 object   SpecialistRequiringReferral
#    69263     8090  0.105 object   SpecialtyDrugMaximumCoinsurance
#        0    77353    1.0 object   StandardComponentId
#        0    77353    1.0 object   StateCode
#        0    77353    1.0 object   StateCode2
#    36103    41250  0.533 object   TEHBCombInnOonFamilyMOOP
#    54050    23303  0.301 object   TEHBCombInnOonFamilyPerGroupMOOP
#    54050    23303  0.301 object   TEHBCombInnOonFamilyPerPersonMOOP
#    12800    64553  0.835 object   TEHBCombInnOonIndividualMOOP
#    53892    23461  0.303 object   TEHBDedCombInnOonFamily
#    63253    14100  0.182 object   TEHBDedCombInnOonFamilyPerGroup
#    63253    14100  0.182 object   TEHBDedCombInnOonFamilyPerPerson
#    39756    37597  0.486 object   TEHBDedCombInnOonIndividual
#    39748    37605  0.486 object   TEHBDedInnTier1Coinsurance
#    53848    23505  0.304 object   TEHBDedInnTier1Family
#    63253    14100  0.182 object   TEHBDedInnTier1FamilyPerGroup
#    63253    14100  0.182 object   TEHBDedInnTier1FamilyPerPerson
#    39748    37605  0.486 object   TEHBDedInnTier1Individual
#    72037     5316  0.069 object   TEHBDedInnTier2Coinsurance
#    75052     2301   0.03 object   TEHBDedInnTier2Family
#    74338     3015  0.039 object   TEHBDedInnTier2FamilyPerGroup
#    74338     3015  0.039 object   TEHBDedInnTier2FamilyPerPerson
#    72037     5316  0.069 object   TEHBDedInnTier2Individual
#    53848    23505  0.304 object   TEHBDedOutOfNetFamily
#    63253    14100  0.182 object   TEHBDedOutOfNetFamilyPerGroup
#    63253    14100  0.182 object   TEHBDedOutOfNetFamilyPerPerson
#    39748    37605  0.486 object   TEHBDedOutOfNetIndividual
#    36103    41250  0.533 object   TEHBInnTier1FamilyMOOP
#    54050    23303  0.301 object   TEHBInnTier1FamilyPerGroupMOOP
#    54050    23303  0.301 object   TEHBInnTier1FamilyPerPersonMOOP
#    12800    64553  0.835 object   TEHBInnTier1IndividualMOOP
#    74096     3257  0.042 object   TEHBInnTier2FamilyMOOP
#    72533     4820  0.062 object   TEHBInnTier2FamilyPerGroupMOOP
#    72533     4820  0.062 object   TEHBInnTier2FamilyPerPersonMOOP
#    69276     8077  0.104 object   TEHBInnTier2IndividualMOOP
#    36103    41250  0.533 object   TEHBOutOfNetFamilyMOOP
#    54050    23303  0.301 object   TEHBOutOfNetFamilyPerGroupMOOP
#    54050    23303  0.301 object   TEHBOutOfNetFamilyPerPersonMOOP
#    12800    64553  0.835 object   TEHBOutOfNetIndividualMOOP
#        0    77353    1.0 object   TIN
#    15853    61500  0.795 object   URLForEnrollmentPayment
#     7124    70229  0.908 object   URLForSummaryofBenefitsCoverage
#    11649    65704  0.849 object   UniquePlanDesign
#        0    77353    1.0 int64    VersionNum
#    11637    65716   0.85 object   WellnessProgramOffered

# %%
essentials = ['AVCalculatorOutputNumber','BeginPrimaryCareCostSharingAfterNumberOfVisits',
              'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays','BusinessYear',
              'ChildOnlyOffering','CompositeRatingOffered','DentalOnlyPlan',
              'EHBPediatricDentalApportionmentQuantity',
              'EHBPercentPremiumS4','EHBPercentTotalPremium','FirstTierUtilization',
              'HSAOrHRAEmployerContribution','HSAOrHRAEmployerContributionAmount',
              'InpatientCopaymentMaximumDays','IsGuaranteedRate','IsHSAEligible',
              'IsNewPlan','IsNoticeRequiredForPregnancy','IsReferralRequiredForSpecialist',
              'IssuerActuarialValue',
              'MarketCoverage','MedicalDrugDeductiblesIntegrated',
              'MedicalDrugMaximumOutofPocketIntegrated',
              'MetalLevel','MultipleInNetworkTiers','NationalNetwork',
              'OutOfCountryCoverage','OutOfServiceAreaCoverage',
              'PlanMarketingName','PlanType','QHPNonQHPTypeId',
              'SecondTierUtilization','StandardComponentId',
              'UniquePlanDesign','WellnessProgramOffered']

# %%
coinsurance = []
for column in df.columns:
    if ('Coinsurance' in column and 'Begin' not in column):
        print (column, (df[column].notnull().sum()/df[column].notnull().count()))
        coinsurance.append(column)
# Out:
# DEHBDedInnTier1Coinsurance 0.36325675798
# DEHBDedInnTier2Coinsurance 0.0356935089783
# MEHBDedInnTier1Coinsurance 0.36325675798
# MEHBDedInnTier2Coinsurance 0.0356935089783
# SBCHavingDiabetesCoinsurance 0.491241451527
# SBCHavingaBabyCoinsurance 0.491629283932
# SpecialtyDrugMaximumCoinsurance 0.104585471798
# TEHBDedInnTier1Coinsurance 0.486147919279
# TEHBDedInnTier2Coinsurance 0.0687239021111

# %%
individual = []
for column in df.columns:
    if ('Individual' in column) and ((df[column].notnull().sum()/df[column].notnull().count()) > 0):
        print (column, (df[column].notnull().sum()/df[column].notnull().count()))
        individual.append(column)
# Out:
# DEHBCombInnOonIndividualMOOP 0.0148798365933
# DEHBDedCombInnOonIndividual 0.36325675798
# DEHBDedInnTier1Individual 0.36325675798
# DEHBDedInnTier2Individual 0.0356935089783
# DEHBDedOutOfNetIndividual 0.36325675798
# DEHBInnTier1IndividualMOOP 0.0148798365933
# DEHBOutOfNetIndividualMOOP 0.0148798365933
# MEHBCombInnOonIndividualMOOP 0.165475159334
# MEHBDedCombInnOonIndividual 0.513852080721
# MEHBDedInnTier1Individual 0.513852080721
# MEHBDedInnTier2Individual 0.0423771540858
# MEHBDedOutOfNetIndividual 0.513852080721
# MEHBInnTier1IndividualMOOP 0.165475159334
# MEHBInnTier2IndividualMOOP 0.00668364510749
# MEHBOutOfNetIndividualMOOP 0.165475159334
# TEHBCombInnOonIndividualMOOP 0.834524840666
# TEHBDedCombInnOonIndividual 0.486044497305
# TEHBDedInnTier1Individual 0.486147919279
# TEHBDedInnTier2Individual 0.0687239021111
# TEHBDedOutOfNetIndividual 0.486147919279
# TEHBInnTier1IndividualMOOP 0.834524840666
# TEHBInnTier2IndividualMOOP 0.104417411089
# TEHBOutOfNetIndividualMOOP 0.834524840666

# %%
family = []
for column in df.columns:
    if ('Family' in column) and ((df[column].notnull().sum()/df[column].notnull().count()) > 0):
        print (column, (df[column].notnull().sum()/df[column].notnull().count()))
        family.append(column)
# Out:
# DEHBCombInnOonFamilyMOOP 0.0119969490517
# DEHBCombInnOonFamilyPerGroupMOOP 0.00288288754153
# DEHBCombInnOonFamilyPerPersonMOOP 0.00288288754153
# DEHBDedCombInnOonFamily 0.241399816426
# DEHBDedCombInnOonFamilyPerGroup 0.121856941554
# DEHBDedCombInnOonFamilyPerPerson 0.121856941554
# DEHBDedInnTier1Family 0.241399816426
# DEHBDedInnTier1FamilyPerGroup 0.121856941554
# DEHBDedInnTier1FamilyPerPerson 0.121856941554
# DEHBDedInnTier2Family 0.0123589259628
# DEHBDedInnTier2FamilyPerGroup 0.0233345830155
# DEHBDedInnTier2FamilyPerPerson 0.0233345830155
# DEHBDedOutOfNetFamily 0.241399816426
# DEHBDedOutOfNetFamilyPerGroup 0.121856941554
# DEHBDedOutOfNetFamilyPerPerson 0.121856941554
# DEHBInnTier1FamilyMOOP 0.0119969490517
# DEHBInnTier1FamilyPerGroupMOOP 0.00288288754153
# DEHBInnTier1FamilyPerPersonMOOP 0.00288288754153
# DEHBOutOfNetFamilyMOOP 0.0119969490517
# DEHBOutOfNetFamilyPerGroupMOOP 0.00288288754153
# DEHBOutOfNetFamilyPerPersonMOOP 0.00288288754153
# MEHBCombInnOonFamilyMOOP 0.11275580779
# MEHBCombInnOonFamilyPerGroupMOOP 0.0527193515442
# MEHBCombInnOonFamilyPerPersonMOOP 0.0527193515442
# MEHBDedCombInnOonFamily 0.342158675165
# MEHBDedCombInnOonFamilyPerGroup 0.171693405556
# MEHBDedCombInnOonFamilyPerPerson 0.171693405556
# MEHBDedInnTier1Family 0.342158675165
# MEHBDedInnTier1FamilyPerGroup 0.171693405556
# MEHBDedInnTier1FamilyPerPerson 0.171693405556
# MEHBDedInnTier2Family 0.0163277442375
# MEHBDedInnTier2FamilyPerGroup 0.0260494098484
# MEHBDedInnTier2FamilyPerPerson 0.0260494098484
# MEHBDedOutOfNetFamily 0.342158675165
# MEHBDedOutOfNetFamilyPerGroup 0.171693405556
# MEHBDedOutOfNetFamilyPerPerson 0.171693405556
# MEHBInnTier1FamilyMOOP 0.11275580779
# MEHBInnTier1FamilyPerGroupMOOP 0.0527193515442
# MEHBInnTier1FamilyPerPersonMOOP 0.0527193515442
# MEHBInnTier2FamilyMOOP 0.00396881827466
# MEHBInnTier2FamilyPerGroupMOOP 0.00271482683283
# MEHBInnTier2FamilyPerPersonMOOP 0.00271482683283
# MEHBOutOfNetFamilyMOOP 0.11275580779
# MEHBOutOfNetFamilyPerGroupMOOP 0.0527193515442
# MEHBOutOfNetFamilyPerPersonMOOP 0.0527193515442
# TEHBCombInnOonFamilyMOOP 0.533269556449
# TEHBCombInnOonFamilyPerGroupMOOP 0.301255284217
# TEHBCombInnOonFamilyPerPersonMOOP 0.301255284217
# TEHBDedCombInnOonFamily 0.303297868215
# TEHBDedCombInnOonFamilyPerGroup 0.182281230204
# TEHBDedCombInnOonFamilyPerPerson 0.182281230204
# TEHBDedInnTier1Family 0.303866689075
# TEHBDedInnTier1FamilyPerGroup 0.182281230204
# TEHBDedInnTier1FamilyPerPerson 0.182281230204
# TEHBDedInnTier2Family 0.0297467454397
# TEHBDedInnTier2FamilyPerGroup 0.0389771566714
# TEHBDedInnTier2FamilyPerPerson 0.0389771566714
# TEHBDedOutOfNetFamily 0.303866689075
# TEHBDedOutOfNetFamilyPerGroup 0.182281230204
# TEHBDedOutOfNetFamilyPerPerson 0.182281230204
# TEHBInnTier1FamilyMOOP 0.533269556449
# TEHBInnTier1FamilyPerGroupMOOP 0.301255284217
# TEHBInnTier1FamilyPerPersonMOOP 0.301255284217
# TEHBInnTier2FamilyMOOP 0.0421056714025
# TEHBInnTier2FamilyPerGroupMOOP 0.0623117396869
# TEHBInnTier2FamilyPerPersonMOOP 0.0623117396869
# TEHBOutOfNetFamilyMOOP 0.533269556449
# TEHBOutOfNetFamilyPerGroupMOOP 0.301255284217
# TEHBOutOfNetFamilyPerPersonMOOP 0.301255284217

# %%
SBC = []
for column in df.columns:
    if 'SBC' in column and 'Coinsurance' not in column:
        print (column,(df[column].notnull().sum()/df[column].notnull().count()))
        SBC.append(column)
# Out:
# SBCHavingDiabetesCopayment 0.492236888033
# SBCHavingDiabetesDeductible 0.492314454514
# SBCHavingDiabetesLimit 0.491370728996
# SBCHavingaBabyCopayment 0.492521298463
# SBCHavingaBabyDeductible 0.492469587476
# SBCHavingaBabyLimit 0.491525861958

# %%
df = df[essentials + coinsurance + individual + family + SBC]
df.shape
# Out:
# (77353, 142)

# %%
df['key'] = df['BusinessYear'].astype(str) + df['StandardComponentId']

# %% [markdown]
# ## Clean Columns
#
# ### Essentials

# %%
def AVcalc(x):
    if float(x) < 1:
        x = float(x)
    elif float(x) == 1:
        x = float(x)
    else:
        x = float(x)/float(100)
    return x

df['AVCalculatorOutputNumber'] = df.AVCalculatorOutputNumber.str.replace('%','')
df['AVCalculatorOutputNumber'] = pd.to_numeric(df.AVCalculatorOutputNumber,errors='raise')
df['AVCalculatorOutputNumber'] = df.AVCalculatorOutputNumber.apply(AVcalc)

df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Adult and Child-only',value=1)
df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Adult and Child-Only',value=1)
df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Adult-Only',value=0)
df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Child-Only',value=1)

df['CompositeRatingOffered'] = df.CompositeRatingOffered.replace(to_replace='Yes',value=1)
df['CompositeRatingOffered'] = df.CompositeRatingOffered.replace(to_replace='No',value=0)

df['DentalOnlyPlan'] = df.DentalOnlyPlan.replace(to_replace='Yes',value=1)
df['DentalOnlyPlan'] = df.DentalOnlyPlan.replace(to_replace='No',value=0)

df['EHBPediatricDentalApportionmentQuantity'] = df['EHBPediatricDentalApportionmentQuantity'].replace('[\$,)]','', regex=True).astype(float)

df['FirstTierUtilization'] = df.FirstTierUtilization.str.replace('%','')
df['FirstTierUtilization'] = pd.to_numeric(df.FirstTierUtilization,errors='raise')
df['FirstTierUtilization'] = df.FirstTierUtilization.apply(AVcalc)

df['SecondTierUtilization'] = df.SecondTierUtilization.str.replace('%','')
df['SecondTierUtilization'] = pd.to_numeric(df.SecondTierUtilization,errors='raise')
df['SecondTierUtilization'] = df.SecondTierUtilization.apply(AVcalc)

df['HSAOrHRAEmployerContribution'] = df.HSAOrHRAEmployerContribution.replace(to_replace='NO',value=0)
df['HSAOrHRAEmployerContribution'] = df.HSAOrHRAEmployerContribution.replace(to_replace='No',value=0)
df['HSAOrHRAEmployerContribution'] = df.HSAOrHRAEmployerContribution.replace(to_replace='Yes',value=1)

df['HSAOrHRAEmployerContributionAmount'] = df['HSAOrHRAEmployerContributionAmount'].replace('[\$,)]','', regex=True).astype(float)

df['IsGuaranteedRate'] = df.IsGuaranteedRate.replace(to_replace='Estimated Rate',value=0)
df['IsGuaranteedRate'] = df.IsGuaranteedRate.replace(to_replace='Guaranteed Rate',value=1)

df['IsHSAEligible'] = df.IsHSAEligible.replace(to_replace='NO',value=0)
df['IsHSAEligible'] = df.IsHSAEligible.replace(to_replace='No',value=0)
df['IsHSAEligible'] = df.IsHSAEligible.replace(to_replace='Yes',value=1)

df['IsNewPlan'] = df.IsNewPlan.replace(to_replace='Existing',value=0)
df['IsNewPlan'] = df.IsNewPlan.replace(to_replace='New',value=1)

df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='NO',value=0)
df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='No',value=0)
df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='Yes',value=1)
df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='yes',value=1)

df['IsReferralRequiredForSpecialist'] = df.IsReferralRequiredForSpecialist.replace(to_replace='No',value=0)
df['IsReferralRequiredForSpecialist'] = df.IsReferralRequiredForSpecialist.replace(to_replace='Yes',value=1)
df['IsReferralRequiredForSpecialist'] = df.IsReferralRequiredForSpecialist.replace(to_replace='yes',value=1)

df['IssuerActuarialValue'] = df.IssuerActuarialValue.str.replace('%','')
df['IssuerActuarialValue'] = pd.to_numeric(df.IssuerActuarialValue,errors='raise')
df['IssuerActuarialValue'] = df.IssuerActuarialValue.apply(AVcalc)

df['MarketCoverage'] = df.MarketCoverage.replace(to_replace='Individual',value=0)
df['MarketCoverage'] = df.MarketCoverage.replace(to_replace='SHOP (Small Group)',value=1)

df['MedicalDrugDeductiblesIntegrated'] = df.MedicalDrugDeductiblesIntegrated.replace(to_replace='No', value = 0)
df['MedicalDrugDeductiblesIntegrated'] = df.MedicalDrugDeductiblesIntegrated.replace(to_replace='Yes', value = 1)

df['MedicalDrugMaximumOutofPocketIntegrated'] = df.MedicalDrugMaximumOutofPocketIntegrated.replace(to_replace='No', value = 0)
df['MedicalDrugMaximumOutofPocketIntegrated'] = df.MedicalDrugMaximumOutofPocketIntegrated.replace(to_replace='Yes', value = 1)

df['MultipleInNetworkTiers'] = df.MultipleInNetworkTiers.replace(to_replace='No', value = 0)
df['MultipleInNetworkTiers'] = df.MultipleInNetworkTiers.replace(to_replace='Yes', value = 1)

df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='NO',value=0)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='no',value=0)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='No',value=0)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='YES',value=1)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='YEs',value=1)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='Yes',value=1)

df['OutOfCountryCoverage'] = df.OutOfCountryCoverage.replace(to_replace='No',value=0)
df['OutOfCountryCoverage'] = df.OutOfCountryCoverage.replace(to_replace='YES',value=1)
df['OutOfCountryCoverage'] = df.OutOfCountryCoverage.replace(to_replace='Yes',value=1)

df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='No',value=0)
df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='YES',value=1)
df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='Yes',value=1)
df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='yes',value=1)

df['UniquePlanDesign'] = df.UniquePlanDesign.replace(to_replace='No',value=0)
df['UniquePlanDesign'] = df.UniquePlanDesign.replace(to_replace='no',value=0)
df['UniquePlanDesign'] = df.UniquePlanDesign.replace(to_replace='Yes',value=1)

df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='yes',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Yes',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='no',value=0)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='No',value=0)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Guaranteed Rate',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Estimated Rate',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Allows Adult and Child-Only',value=1)

# %% [markdown]
# ### Cleaning Specific Columns

# %%
for col in coinsurance:
    if 'Tier' in col:
        df[col] = df[col].replace(to_replace='$0', value = '0')
        df[col] = df[col].replace(to_replace='$0 ', value = '0')
        df[col] = df[col].str.replace('%','')
        df[col] = pd.to_numeric(df[col],errors='raise')
        df[col] = df[col].apply(AVcalc)
    else:
        df[col] = df[col].replace(to_replace='Not Applicable', value = np.nan)
        df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for col in individual:
    df[col] = df[col].replace(to_replace='Not Applicable', value = np.nan)
    df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for col in family:
    df[col] = df[col].str.replace(' per group','')
    df[col] = df[col].str.replace(' per person','')
    df[col] = df[col].replace(to_replace='per group not applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='per group Not Applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='per person not applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='per person Not Applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='Not Applicable', value = np.nan)
    df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for col in SBC:
    df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for column in df.columns:
    print ('{0:8} {1:8} {2:6} {3!s:8} {4:10}'.format(df[column].isnull().sum(), df[column].notnull().sum(),
           round(df[column].notnull().sum()/df[column].notnull().count(),3), df[column].dtype, column))
# Out:
#    72015     5338  0.069 float64  AVCalculatorOutputNumber
#        0    77353    1.0 int64    BeginPrimaryCareCostSharingAfterNumberOfVisits
#        0    77353    1.0 int64    BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays
#        0    77353    1.0 int64    BusinessYear
#        0    77353    1.0 int64    ChildOnlyOffering
#    49972    27381  0.354 float64  CompositeRatingOffered
#        0    77353    1.0 int64    DentalOnlyPlan
#    65704    11649  0.151 float64  EHBPediatricDentalApportionmentQuantity
#    35476    41877  0.541 float64  EHBPercentPremiumS4
#    54243    23110  0.299 float64  EHBPercentTotalPremium
#        0    77353    1.0 float64  FirstTierUtilization
#    66641    10712  0.138 float64  HSAOrHRAEmployerContribution
#    77067      286  0.004 float64  HSAOrHRAEmployerContributionAmount
#        0    77353    1.0 int64    InpatientCopaymentMaximumDays
#    65704    11649  0.151 float64  IsGuaranteedRate
#    11649    65704  0.849 float64  IsHSAEligible
#        0    77353    1.0 int64    IsNewPlan
#    11649    65704  0.849 float64  IsNoticeRequiredForPregnancy
#    11649    65704  0.849 float64  IsReferralRequiredForSpecialist
#    34827    42526   0.55 float64  IssuerActuarialValue
#        0    77353    1.0 int64    MarketCoverage
#    11649    65704  0.849 float64  MedicalDrugDeductiblesIntegrated
#    11649    65704  0.849 float64  MedicalDrugMaximumOutofPocketIntegrated
#        0    77353    1.0 object   MetalLevel
#        0    77353    1.0 int64    MultipleInNetworkTiers
#        0    77353    1.0 int64    NationalNetwork
#        0    77353    1.0 int64    OutOfCountryCoverage
#        0    77353    1.0 int64    OutOfServiceAreaCoverage
#        0    77353    1.0 object   PlanMarketingName
#        0    77353    1.0 object   PlanType
#        0    77353    1.0 object   QHPNonQHPTypeId
#    68763     8590  0.111 float64  SecondTierUtilization
#        0    77353    1.0 object   StandardComponentId
#    11649    65704  0.849 float64  UniquePlanDesign
#    11637    65716   0.85 float64  WellnessProgramOffered
#    49254    28099  0.363 float64  DEHBDedInnTier1Coinsurance
#    74592     2761  0.036 float64  DEHBDedInnTier2Coinsurance
#    49254    28099  0.363 float64  MEHBDedInnTier1Coinsurance
#    74592     2761  0.036 float64  MEHBDedInnTier2Coinsurance
#    39354    37999  0.491 float64  SBCHavingDiabetesCoinsurance
#    39324    38029  0.492 float64  SBCHavingaBabyCoinsurance
#    69263     8090  0.105 float64  SpecialtyDrugMaximumCoinsurance
#    39748    37605  0.486 float64  TEHBDedInnTier1Coinsurance
#    72037     5316  0.069 float64  TEHBDedInnTier2Coinsurance
#    77160      193  0.002 float64  DEHBCombInnOonIndividualMOOP
#    69294     8059  0.104 float64  DEHBDedCombInnOonIndividual
#    50718    26635  0.344 float64  DEHBDedInnTier1Individual
#    74755     2598  0.034 float64  DEHBDedInnTier2Individual
#    65971    11382  0.147 float64  DEHBDedOutOfNetIndividual
#    76242     1111  0.014 float64  DEHBInnTier1IndividualMOOP
#    77218      135  0.002 float64  DEHBOutOfNetIndividualMOOP
#    75842     1511   0.02 float64  MEHBCombInnOonIndividualMOOP
#    65191    12162  0.157 float64  MEHBDedCombInnOonIndividual
#    42833    34520  0.446 float64  MEHBDedInnTier1Individual
#    74399     2954  0.038 float64  MEHBDedInnTier2Individual
#    57407    19946  0.258 float64  MEHBDedOutOfNetIndividual
#    65734    11619   0.15 float64  MEHBInnTier1IndividualMOOP
#    76864      489  0.006 float64  MEHBInnTier2IndividualMOOP
#    75086     2267  0.029 float64  MEHBOutOfNetIndividualMOOP
#    61777    15576  0.201 float64  TEHBCombInnOonIndividualMOOP
#    68125     9228  0.119 float64  TEHBDedCombInnOonIndividual
#    40039    37314  0.482 float64  TEHBDedInnTier1Individual
#    72116     5237  0.068 float64  TEHBDedInnTier2Individual
#    55033    22320  0.289 float64  TEHBDedOutOfNetIndividual
#    13124    64229   0.83 float64  TEHBInnTier1IndividualMOOP
#    69298     8055  0.104 float64  TEHBInnTier2IndividualMOOP
#    46203    31150  0.403 float64  TEHBOutOfNetIndividualMOOP
#    77209      144  0.002 float64  DEHBCombInnOonFamilyMOOP
#    77307       46  0.001 float64  DEHBCombInnOonFamilyPerGroupMOOP
#    77307       46  0.001 float64  DEHBCombInnOonFamilyPerPersonMOOP
#    72424     4929  0.064 float64  DEHBDedCombInnOonFamily
#    74949     2404  0.031 float64  DEHBDedCombInnOonFamilyPerGroup
#    74524     2829  0.037 float64  DEHBDedCombInnOonFamilyPerPerson
#    60360    16993   0.22 float64  DEHBDedInnTier1Family
#    70242     7111  0.092 float64  DEHBDedInnTier1FamilyPerGroup
#    69128     8225  0.106 float64  DEHBDedInnTier1FamilyPerPerson
#    76536      817  0.011 float64  DEHBDedInnTier2Family
#    75698     1655  0.021 float64  DEHBDedInnTier2FamilyPerGroup
#    75608     1745  0.023 float64  DEHBDedInnTier2FamilyPerPerson
#    69951     7402  0.096 float64  DEHBDedOutOfNetFamily
#    74396     2957  0.038 float64  DEHBDedOutOfNetFamilyPerGroup
#    73816     3537  0.046 float64  DEHBDedOutOfNetFamilyPerPerson
#    76465      888  0.011 float64  DEHBInnTier1FamilyMOOP
#    77130      223  0.003 float64  DEHBInnTier1FamilyPerGroupMOOP
#    77130      223  0.003 float64  DEHBInnTier1FamilyPerPersonMOOP
#    77252      101  0.001 float64  DEHBOutOfNetFamilyMOOP
#    77319       34    0.0 float64  DEHBOutOfNetFamilyPerGroupMOOP
#    77319       34    0.0 float64  DEHBOutOfNetFamilyPerPersonMOOP
#    76575      778   0.01 float64  MEHBCombInnOonFamilyMOOP
#    76652      701  0.009 float64  MEHBCombInnOonFamilyPerGroupMOOP
#    76664      689  0.009 float64  MEHBCombInnOonFamilyPerPersonMOOP
#    72376     4977  0.064 float64  MEHBDedCombInnOonFamily
#    74337     3016  0.039 float64  MEHBDedCombInnOonFamilyPerGroup
#    73232     4121  0.053 float64  MEHBDedCombInnOonFamilyPerPerson
#    57826    19527  0.252 float64  MEHBDedInnTier1Family
#    67667     9686  0.125 float64  MEHBDedInnTier1FamilyPerGroup
#    67347    10006  0.129 float64  MEHBDedInnTier1FamilyPerPerson
#    76300     1053  0.014 float64  MEHBDedInnTier2Family
#    75547     1806  0.023 float64  MEHBDedInnTier2FamilyPerGroup
#    75550     1803  0.023 float64  MEHBDedInnTier2FamilyPerPerson
#    66996    10357  0.134 float64  MEHBDedOutOfNetFamily
#    72756     4597  0.059 float64  MEHBDedOutOfNetFamilyPerGroup
#    72384     4969  0.064 float64  MEHBDedOutOfNetFamilyPerPerson
#    69270     8083  0.104 float64  MEHBInnTier1FamilyMOOP
#    73910     3443  0.045 float64  MEHBInnTier1FamilyPerGroupMOOP
#    73977     3376  0.044 float64  MEHBInnTier1FamilyPerPersonMOOP
#    77070      283  0.004 float64  MEHBInnTier2FamilyMOOP
#    77147      206  0.003 float64  MEHBInnTier2FamilyPerGroupMOOP
#    77158      195  0.003 float64  MEHBInnTier2FamilyPerPersonMOOP
#    75760     1593  0.021 float64  MEHBOutOfNetFamilyMOOP
#    76869      484  0.006 float64  MEHBOutOfNetFamilyPerGroupMOOP
#    76883      470  0.006 float64  MEHBOutOfNetFamilyPerPersonMOOP
#    67242    10111  0.131 float64  TEHBCombInnOonFamilyMOOP
#    71986     5367  0.069 float64  TEHBCombInnOonFamilyPerGroupMOOP
#    72001     5352  0.069 float64  TEHBCombInnOonFamilyPerPersonMOOP
#    71603     5750  0.074 float64  TEHBDedCombInnOonFamily
#    73944     3409  0.044 float64  TEHBDedCombInnOonFamilyPerGroup
#    74053     3300  0.043 float64  TEHBDedCombInnOonFamilyPerPerson
#    54156    23197    0.3 float64  TEHBDedInnTier1Family
#    63408    13945   0.18 float64  TEHBDedInnTier1FamilyPerGroup
#    64207    13146   0.17 float64  TEHBDedInnTier1FamilyPerPerson
#    75095     2258  0.029 float64  TEHBDedInnTier2Family
#    74374     2979  0.039 float64  TEHBDedInnTier2FamilyPerGroup
#    74402     2951  0.038 float64  TEHBDedInnTier2FamilyPerPerson
#    62730    14623  0.189 float64  TEHBDedOutOfNetFamily
#    69875     7478  0.097 float64  TEHBDedOutOfNetFamilyPerGroup
#    70428     6925   0.09 float64  TEHBDedOutOfNetFamilyPerPerson
#    36489    40864  0.528 float64  TEHBInnTier1FamilyMOOP
#    54161    23192    0.3 float64  TEHBInnTier1FamilyPerGroupMOOP
#    54164    23189    0.3 float64  TEHBInnTier1FamilyPerPersonMOOP
#    74100     3253  0.042 float64  TEHBInnTier2FamilyMOOP
#    72551     4802  0.062 float64  TEHBInnTier2FamilyPerGroupMOOP
#    72551     4802  0.062 float64  TEHBInnTier2FamilyPerPersonMOOP
#    55426    21927  0.283 float64  TEHBOutOfNetFamilyMOOP
#    68237     9116  0.118 float64  TEHBOutOfNetFamilyPerGroupMOOP
#    68427     8926  0.115 float64  TEHBOutOfNetFamilyPerPersonMOOP
#    39277    38076  0.492 float64  SBCHavingDiabetesCopayment
#    39271    38082  0.492 float64  SBCHavingDiabetesDeductible
#    39344    38009  0.491 float64  SBCHavingDiabetesLimit
#    39255    38098  0.493 float64  SBCHavingaBabyCopayment
#    39259    38094  0.492 float64  SBCHavingaBabyDeductible
#    39332    38021  0.492 float64  SBCHavingaBabyLimit
#        0    77353    1.0 object   key

# %%
df_attr = df
print (df_attr.key.unique().shape)
print (df_attr.shape)
# Out:
# (25614,)
# (77353, 143)

# %% [markdown]
# # Prepare Rate.csv for Join with Plan Attributes

# %%
df = pd.read_csv('Rate.csv')

# %%
ordered_cols = ['BusinessYear','StateCode','IssuerId','PlanId','RatingAreaId','Tobacco','Age',
                'IndividualRate','IndividualTobaccoRate','PrimarySubscriberAndOneDependent',
                'PrimarySubscriberAndTwoDependents','PrimarySubscriberAndThreeOrMoreDependents',
                'Couple','CoupleAndOneDependent','CoupleAndTwoDependents',
                'CoupleAndThreeOrMoreDependents']

df_rate = df[ordered_cols]
df_rate = df_rate[df_rate['BusinessYear'] == 2016]
df_rate['key'] = df_rate.BusinessYear.astype(str) + df_rate.PlanId

# %%
print (df_rate.key.unique().shape)
print (df_rate.shape)
# Out:
# (8887,)
# (4221965, 17)

# %%
df_rate['Age'] = df_rate.Age.str.replace('0-20','20')
df_rate['Age'] = df_rate.Age.str.replace('65 and over','65')
df_rate['Age'] = df_rate.Age.replace(to_replace="Family Option", value = '66')
df_rate['Age'] = df_rate.Age.astype(float)

df_rate['Tobacco'] = df_rate.Tobacco.replace(to_replace='No Preference', value = 0)
df_rate['Tobacco'] = df_rate.Tobacco.replace(to_replace='Tobacco User/Non-Tobacco User', value = 1)

# %%
df_rate.shape
# Out:
# (4221965, 17)

# %%
df_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4221965 entries, 8472480 to 12694444
# Data columns (total 17 columns):
# BusinessYear                                 int64
# StateCode                                    object
# IssuerId                                     int64
# PlanId                                       object
# RatingAreaId                                 object
# Tobacco                                      int64
# Age                                          float64
# IndividualRate                               float64
# IndividualTobaccoRate                        float64
# PrimarySubscriberAndOneDependent             float64
# PrimarySubscriberAndTwoDependents            float64
# PrimarySubscriberAndThreeOrMoreDependents    float64
# Couple                                       float64
# CoupleAndOneDependent                        float64
# CoupleAndTwoDependents                       float64
# CoupleAndThreeOrMoreDependents               float64
# key                                          object
# dtypes: float64(10), int64(3), object(4)
# memory usage: 579.8+ MB

# %%
del df

# %% [markdown]
# ## Join Rate and Attribute Tables

# %%
print (df_attr.key.unique().shape)
print (df_rate.key.unique().shape)
# Out:
# (25614,)
# (8887,)

# %%
df_join_RA = df_rate.merge(df_attr,how='left',on='key') #left, don't want to lose any rate keys
df_join_RA = df_join_RA.drop_duplicates()

# %%
if 'BusinessYear_y' in df_join_RA.columns:
    df_join_RA = df_join_RA.drop('BusinessYear_y',axis=1)
    
df_join_RA = df_join_RA.rename(columns={'BusinessYear_x':'BusinessYear'})

# %%
print (df_join_RA.key.unique().shape)
print (df_join_RA.shape)
# Out:
# (8887,)
# (6213495, 158)

# %%
df_join_RA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6213495 entries, 0 to 10066072
# Columns: 158 entries, BusinessYear to SBCHavingaBabyLimit
# dtypes: float64(135), int64(14), object(9)
# memory usage: 7.4+ GB

# %%
df_join_RA.to_csv('df_join_RA.csv',encoding='utf-8')

# %% [markdown]
# ## We will now begin the modeling

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier

labels = ['Catastrophic','Bronze','Silver','Gold','Platinum']
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues,labels=labels):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 16)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45, fontsize = 14)
    plt.yticks(tick_marks, labels, fontsize = 14)
    plt.tight_layout()
    plt.ylabel('True label', fontsize = 16)
    plt.xlabel('Predicted label', fontsize = 16)

# %%
df_join_RA = pd.read_csv('df_join_RA.csv')
df_join_RA = df_join_RA.iloc[:,1:]
df_join_RA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6213495 entries, 0 to 6213494
# Columns: 158 entries, BusinessYear to SBCHavingaBabyLimit
# dtypes: float64(135), int64(14), object(9)
# memory usage: 7.3+ GB

# %%
df = df_join_RA

# %% [markdown]
# ### Filtering

# %%
df = df[df['CompositeRatingOffered'] == 0] # No for Individual Plans = 0,
df = df[df['DentalOnlyPlan'] == 0] # Not a Dental Plan Only = 0, DentalOnlyPlan = 1
df = df[df['MarketCoverage'] == 0] # Individual = 0, Small Group = 1

# %%
df.shape
# Out:
# (2907384, 158)

# %%
df.groupby('MetalLevel')['key','BusinessYear'].count()
# Out:
#                   key  BusinessYear
# MetalLevel
# Bronze         553242        553242
# Catastrophic    51060         51060
# Gold           380420        380420
# Platinum        72220         72220
# Silver        1850442       1850442

# %%
df.groupby('BusinessYear')['key','BusinessYear'].count()
# Out:
#                   key  BusinessYear
# BusinessYear
# 2016          2907384       2907384

# %%
df.groupby('PlanType')['key','BusinessYear'].count()
# Out:
#               key  BusinessYear
# PlanType
# EPO        780942        780942
# HMO       1210628       1210628
# POS        234048        234048
# PPO        681766        681766

# %%
df.groupby('QHPNonQHPTypeId')['key','BusinessYear'].count()
# Out:
#                      key  BusinessYear
# QHPNonQHPTypeId
# Both             2776836       2776836
# On the Exchange   130548        130548

# %%
tmp_df = pd.get_dummies(df.PlanType,prefix='PlanType')
df = pd.concat((df,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(df.QHPNonQHPTypeId,prefix='QHP')
df = pd.concat((df,tmp_df),axis=1) # add back into the dataframe

# %%
df = df.rename(columns = {'BeginPrimaryCareCostSharingAfterNumberOfVisits':'BeginCostSharingAfterNumberOfVisits'})
df = df.rename(columns = {'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays':'BeginDedCoinsAfterNumberOfCopays'})
df = df.rename(columns = {'EHBPediatricDentalApportionmentQuantity':'PediatricDentalApportionmentQty'})
df = df.rename(columns = {'InpatientCopaymentMaximumDays':'InpatientCopayMaxDays'})

# %%
for column in df.columns:
    print ('{0:8} {1:8} {2:6} {3!s:10} {4:20}'.format(
            df[column].isnull().sum(), 
            df[column].notnull().sum(),
            round(df[column].notnull().sum()/df[column].notnull().count(),3),
            df[column].dtype,column))
# Out:
#        0  2907384    1.0 int64      BusinessYear
#        0  2907384    1.0 object     StateCode
#        0  2907384    1.0 int64      IssuerId
#        0  2907384    1.0 object     PlanId
#        0  2907384    1.0 object     RatingAreaId
#        0  2907384    1.0 int64      Tobacco
#        0  2907384    1.0 float64    Age
#        0  2907384    1.0 float64    IndividualRate
#    74244  2833140  0.974 float64    IndividualTobaccoRate
#  2907384        0    0.0 float64    PrimarySubscriberAndOneDependent
#  2907384        0    0.0 float64    PrimarySubscriberAndTwoDependents
#  2907384        0    0.0 float64    PrimarySubscriberAndThreeOrMoreDependents
#  2907384        0    0.0 float64    Couple
#  2907384        0    0.0 float64    CoupleAndOneDependent
#  2907384        0    0.0 float64    CoupleAndTwoDependents
#  2907384        0    0.0 float64    CoupleAndThreeOrMoreDependents
#        0  2907384    1.0 object     key
#  2907384        0    0.0 float64    AVCalculatorOutputNumber
#        0  2907384    1.0 int64      BeginCostSharingAfterNumberOfVisits
#        0  2907384    1.0 int64      BeginDedCoinsAfterNumberOfCopays
#        0  2907384    1.0 int64      ChildOnlyOffering
#        0  2907384    1.0 float64    CompositeRatingOffered
#        0  2907384    1.0 int64      DentalOnlyPlan
#  2907384        0    0.0 float64    PediatricDentalApportionmentQty
#  2907384        0    0.0 float64    EHBPercentPremiumS4
#     7452  2899932  0.997 float64    EHBPercentTotalPremium
#        0  2907384    1.0 float64    FirstTierUtilization
#  2907384        0    0.0 float64    HSAOrHRAEmployerContribution
#  2907384        0    0.0 float64    HSAOrHRAEmployerContributionAmount
#        0  2907384    1.0 int64      InpatientCopayMaxDays
#  2907384        0    0.0 float64    IsGuaranteedRate
#        0  2907384    1.0 float64    IsHSAEligible
#        0  2907384    1.0 int64      IsNewPlan
#        0  2907384    1.0 float64    IsNoticeRequiredForPregnancy
#        0  2907384    1.0 float64    IsReferralRequiredForSpecialist
#  1871326  1036058  0.356 float64    IssuerActuarialValue
#        0  2907384    1.0 int64      MarketCoverage
#        0  2907384    1.0 float64    MedicalDrugDeductiblesIntegrated
#        0  2907384    1.0 float64    MedicalDrugMaximumOutofPocketIntegrated
#        0  2907384    1.0 object     MetalLevel
#        0  2907384    1.0 int64      MultipleInNetworkTiers
#        0  2907384    1.0 int64      NationalNetwork
#        0  2907384    1.0 int64      OutOfCountryCoverage
#        0  2907384    1.0 int64      OutOfServiceAreaCoverage
#        0  2907384    1.0 object     PlanMarketingName
#        0  2907384    1.0 object     PlanType
#        0  2907384    1.0 object     QHPNonQHPTypeId
#  2655580   251804  0.087 float64    SecondTierUtilization
#        0  2907384    1.0 object     StandardComponentId
#        0  2907384    1.0 float64    UniquePlanDesign
#        0  2907384    1.0 float64    WellnessProgramOffered
#  1836044  1071340  0.368 float64    DEHBDedInnTier1Coinsurance
#  2821870    85514  0.029 float64    DEHBDedInnTier2Coinsurance
#  1836044  1071340  0.368 float64    MEHBDedInnTier1Coinsurance
#  2821870    85514  0.029 float64    MEHBDedInnTier2Coinsurance
#        0  2907384    1.0 float64    SBCHavingDiabetesCoinsurance
#        0  2907384    1.0 float64    SBCHavingaBabyCoinsurance
#  2568962   338422  0.116 float64    SpecialtyDrugMaximumCoinsurance
#  1071340  1836044  0.632 float64    TEHBDedInnTier1Coinsurance
#  2741094   166290  0.057 float64    TEHBDedInnTier2Coinsurance
#  2901128     6256  0.002 float64    DEHBCombInnOonIndividualMOOP
#  2479630   427754  0.147 float64    DEHBDedCombInnOonIndividual
#  1885448  1021936  0.351 float64    DEHBDedInnTier1Individual
#  2827068    80316  0.028 float64    DEHBDedInnTier2Individual
#  2479354   428030  0.147 float64    DEHBDedOutOfNetIndividual
#  2892434    14950  0.005 float64    DEHBInnTier1IndividualMOOP
#  2902692     4692  0.002 float64    DEHBOutOfNetIndividualMOOP
#  2901128     6256  0.002 float64    MEHBCombInnOonIndividualMOOP
#  2540488   366896  0.126 float64    MEHBDedCombInnOonIndividual
#  1845474  1061910  0.365 float64    MEHBDedInnTier1Individual
#  2825734    81650  0.028 float64    MEHBDedInnTier2Individual
#  2409986   497398  0.171 float64    MEHBDedOutOfNetIndividual
#  2892434    14950  0.005 float64    MEHBInnTier1IndividualMOOP
#  2907384        0    0.0 float64    MEHBInnTier2IndividualMOOP
#  2899748     7636  0.003 float64    MEHBOutOfNetIndividualMOOP
#  1943270   964114  0.332 float64    TEHBCombInnOonIndividualMOOP
#  2279714   627670  0.216 float64    TEHBDedCombInnOonIndividual
#  1078286  1829098  0.629 float64    TEHBDedInnTier1Individual
#  2744774   162610  0.056 float64    TEHBDedInnTier2Individual
#  2008176   899208  0.309 float64    TEHBDedOutOfNetIndividual
#    23966  2883418  0.992 float64    TEHBInnTier1IndividualMOOP
#  2659444   247940  0.085 float64    TEHBInnTier2IndividualMOOP
#  1676148  1231236  0.423 float64    TEHBOutOfNetIndividualMOOP
#  2907384        0    0.0 float64    DEHBCombInnOonFamilyMOOP
#  2901128     6256  0.002 float64    DEHBCombInnOonFamilyPerGroupMOOP
#  2901128     6256  0.002 float64    DEHBCombInnOonFamilyPerPersonMOOP
#  2907384        0    0.0 float64    DEHBDedCombInnOonFamily
#  2532070   375314  0.129 float64    DEHBDedCombInnOonFamilyPerGroup
#  2479906   427478  0.147 float64    DEHBDedCombInnOonFamilyPerPerson
#  2907384        0    0.0 float64    DEHBDedInnTier1Family
#  2071978   835406  0.287 float64    DEHBDedInnTier1FamilyPerGroup
#  1901502  1005882  0.346 float64    DEHBDedInnTier1FamilyPerPerson
#  2907384        0    0.0 float64    DEHBDedInnTier2Family
#  2834428    72956  0.025 float64    DEHBDedInnTier2FamilyPerGroup
#  2827344    80040  0.028 float64    DEHBDedInnTier2FamilyPerPerson
#  2907384        0    0.0 float64    DEHBDedOutOfNetFamily
#  2545732   361652  0.124 float64    DEHBDedOutOfNetFamilyPerGroup
#  2483586   423798  0.146 float64    DEHBDedOutOfNetFamilyPerPerson
#  2907384        0    0.0 float64    DEHBInnTier1FamilyMOOP
#  2892434    14950  0.005 float64    DEHBInnTier1FamilyPerGroupMOOP
#  2892434    14950  0.005 float64    DEHBInnTier1FamilyPerPersonMOOP
#  2907384        0    0.0 float64    DEHBOutOfNetFamilyMOOP
#  2902692     4692  0.002 float64    DEHBOutOfNetFamilyPerGroupMOOP
#  2902692     4692  0.002 float64    DEHBOutOfNetFamilyPerPersonMOOP
#  2907384        0    0.0 float64    MEHBCombInnOonFamilyMOOP
#  2901128     6256  0.002 float64    MEHBCombInnOonFamilyPerGroupMOOP
#  2901128     6256  0.002 float64    MEHBCombInnOonFamilyPerPersonMOOP
#  2907384        0    0.0 float64    MEHBDedCombInnOonFamily
#  2542236   365148  0.126 float64    MEHBDedCombInnOonFamilyPerGroup
#  2544076   363308  0.125 float64    MEHBDedCombInnOonFamilyPerPerson
#  2907384        0    0.0 float64    MEHBDedInnTier1Family
#  1852006  1055378  0.363 float64    MEHBDedInnTier1FamilyPerGroup
#  1860240  1047144   0.36 float64    MEHBDedInnTier1FamilyPerPerson
#  2907384        0    0.0 float64    MEHBDedInnTier2Family
#  2825734    81650  0.028 float64    MEHBDedInnTier2FamilyPerGroup
#  2825964    81420  0.028 float64    MEHBDedInnTier2FamilyPerPerson
#  2907384        0    0.0 float64    MEHBDedOutOfNetFamily
#  2415690   491694  0.169 float64    MEHBDedOutOfNetFamilyPerGroup
#  2427558   479826  0.165 float64    MEHBDedOutOfNetFamilyPerPerson
#  2907384        0    0.0 float64    MEHBInnTier1FamilyMOOP
#  2892434    14950  0.005 float64    MEHBInnTier1FamilyPerGroupMOOP
#  2892434    14950  0.005 float64    MEHBInnTier1FamilyPerPersonMOOP
#  2907384        0    0.0 float64    MEHBInnTier2FamilyMOOP
#  2907384        0    0.0 float64    MEHBInnTier2FamilyPerGroupMOOP
#  2907384        0    0.0 float64    MEHBInnTier2FamilyPerPersonMOOP
#  2907384        0    0.0 float64    MEHBOutOfNetFamilyMOOP
#  2899748     7636  0.003 float64    MEHBOutOfNetFamilyPerGroupMOOP
#  2899748     7636  0.003 float64    MEHBOutOfNetFamilyPerPersonMOOP
#  2907384        0    0.0 float64    TEHBCombInnOonFamilyMOOP
#  1944880   962504  0.331 float64    TEHBCombInnOonFamilyPerGroupMOOP
#  1946674   960710   0.33 float64    TEHBCombInnOonFamilyPerPersonMOOP
#  2907384        0    0.0 float64    TEHBDedCombInnOonFamily
#  2273550   633834  0.218 float64    TEHBDedCombInnOonFamilyPerGroup
#  2284360   623024  0.214 float64    TEHBDedCombInnOonFamilyPerPerson
#  2907384        0    0.0 float64    TEHBDedInnTier1Family
#  1087486  1819898  0.626 float64    TEHBDedInnTier1FamilyPerGroup
#  1142594  1764790  0.607 float64    TEHBDedInnTier1FamilyPerPerson
#  2907384        0    0.0 float64    TEHBDedInnTier2Family
#  2744774   162610  0.056 float64    TEHBDedInnTier2FamilyPerGroup
#  2745142   162242  0.056 float64    TEHBDedInnTier2FamilyPerPerson
#  2907384        0    0.0 float64    TEHBDedOutOfNetFamily
#  2029244   878140  0.302 float64    TEHBDedOutOfNetFamilyPerGroup
#  2058316   849068  0.292 float64    TEHBDedOutOfNetFamilyPerPerson
#  2907384        0    0.0 float64    TEHBInnTier1FamilyMOOP
#    23966  2883418  0.992 float64    TEHBInnTier1FamilyPerGroupMOOP
#    24656  2882728  0.992 float64    TEHBInnTier1FamilyPerPersonMOOP
#  2907384        0    0.0 float64    TEHBInnTier2FamilyMOOP
#  2659444   247940  0.085 float64    TEHBInnTier2FamilyPerGroupMOOP
#  2659444   247940  0.085 float64    TEHBInnTier2FamilyPerPersonMOOP
#  2907384        0    0.0 float64    TEHBOutOfNetFamilyMOOP
#  1679552  1227832  0.422 float64    TEHBOutOfNetFamilyPerGroupMOOP
#  1707152  1200232  0.413 float64    TEHBOutOfNetFamilyPerPersonMOOP
#        0  2907384    1.0 float64    SBCHavingDiabetesCopayment
#        0  2907384    1.0 float64    SBCHavingDiabetesDeductible
#        0  2907384    1.0 float64    SBCHavingDiabetesLimit
#        0  2907384    1.0 float64    SBCHavingaBabyCopayment
#        0  2907384    1.0 float64    SBCHavingaBabyDeductible
#        0  2907384    1.0 float64    SBCHavingaBabyLimit
#        0  2907384    1.0 float64    PlanType_EPO
#        0  2907384    1.0 float64    PlanType_HMO
#        0  2907384    1.0 float64    PlanType_POS
#        0  2907384    1.0 float64    PlanType_PPO
#        0  2907384    1.0 float64    QHP_Both
#        0  2907384    1.0 float64    QHP_On the Exchange

# %%
noNeed = ['BusinessYear','Age','IssuerId','IndividualTobaccoRate','logIndividualRate',
          'logTEHBDedInnTier1Individual','logTEHBInnTier1IndividualMOOP','logTEHBInnTier1FamilyPerGroupMOOP']
noNulls = []
for column in df.columns:
    if ((df[column].notnull().sum()/df[column].notnull().count() == 1) and (df[column].dtype != 'object')
       and (column not in noNeed)):
        print ('{0:6} {1:20}'.format(df[column].notnull().sum()/df[column].notnull().count(),column))
        noNulls.append(column)
# Out:
#    1.0 Tobacco
#    1.0 IndividualRate
#    1.0 BeginCostSharingAfterNumberOfVisits
#    1.0 BeginDedCoinsAfterNumberOfCopays
#    1.0 ChildOnlyOffering
#    1.0 CompositeRatingOffered
#    1.0 DentalOnlyPlan
#    1.0 FirstTierUtilization
#    1.0 InpatientCopayMaxDays
#    1.0 IsHSAEligible
#    1.0 IsNewPlan
#    1.0 IsNoticeRequiredForPregnancy
#    1.0 IsReferralRequiredForSpecialist
#    1.0 MarketCoverage
#    1.0 MedicalDrugDeductiblesIntegrated
#    1.0 MedicalDrugMaximumOutofPocketIntegrated
#    1.0 MultipleInNetworkTiers
#    1.0 NationalNetwork
#    1.0 OutOfCountryCoverage
#    1.0 OutOfServiceAreaCoverage
#    1.0 UniquePlanDesign
#    1.0 WellnessProgramOffered
#    1.0 SBCHavingDiabetesCoinsurance
#    1.0 SBCHavingaBabyCoinsurance
#    1.0 SBCHavingDiabetesCopayment
#    1.0 SBCHavingDiabetesDeductible
#    1.0 SBCHavingDiabetesLimit
#    1.0 SBCHavingaBabyCopayment
#    1.0 SBCHavingaBabyDeductible
#    1.0 SBCHavingaBabyLimit
#    1.0 PlanType_EPO
#    1.0 PlanType_HMO
#    1.0 PlanType_POS
#    1.0 PlanType_PPO
#    1.0 QHP_Both
#    1.0 QHP_On the Exchange

# %%
imputed = []
for column in df.columns:
    if ((column not in noNulls) and (df[column].dtype != 'object') and (column not in noNeed)
       and ( df[column].notnull().sum()/df[column].notnull().count() > 0.6 )):
        print ('{0:6} {1:20}'.format(round(df[column].notnull().sum()/df[column].notnull().count(),4),column))
        imputed.append(column)
# Out:
# 0.9974 EHBPercentTotalPremium
# 0.6315 TEHBDedInnTier1Coinsurance
# 0.6291 TEHBDedInnTier1Individual
# 0.9918 TEHBInnTier1IndividualMOOP
#  0.626 TEHBDedInnTier1FamilyPerGroup
#  0.607 TEHBDedInnTier1FamilyPerPerson
# 0.9918 TEHBInnTier1FamilyPerGroupMOOP
# 0.9915 TEHBInnTier1FamilyPerPersonMOOP

# %%
#df.IndividualTobaccoRate = df.IndividualTobaccoRate.fillna(df.IndividualTobaccoRate.median()) #?
df.EHBPercentTotalPremium = df.EHBPercentTotalPremium.fillna(df.EHBPercentTotalPremium.median()) #median
df.TEHBDedInnTier1Coinsurance = df.TEHBDedInnTier1Coinsurance.fillna(df.TEHBDedInnTier1Coinsurance.median()) #median
df.TEHBDedInnTier1Individual = df.TEHBDedInnTier1Individual.fillna(df.TEHBDedInnTier1Individual.median()) #median
df.TEHBInnTier1IndividualMOOP = df.TEHBInnTier1IndividualMOOP.fillna(df.TEHBInnTier1IndividualMOOP.median()) #median
df.TEHBDedInnTier1FamilyPerGroup = df.TEHBDedInnTier1FamilyPerGroup.fillna(df.TEHBDedInnTier1FamilyPerGroup.median()) #median
df.TEHBDedInnTier1FamilyPerPerson = df.TEHBDedInnTier1FamilyPerPerson.fillna(df.TEHBDedInnTier1FamilyPerPerson.median()) #median
df.TEHBInnTier1FamilyPerGroupMOOP = df.TEHBInnTier1FamilyPerGroupMOOP.fillna(df.TEHBInnTier1FamilyPerGroupMOOP.median()) #median
df.TEHBInnTier1FamilyPerPersonMOOP = df.TEHBInnTier1FamilyPerPersonMOOP.fillna(df.TEHBInnTier1FamilyPerPersonMOOP.median()) #median

# %% [markdown]
# ### Train and Test with 2016 Data

# %%
colX = noNulls + imputed

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

# %%
scl_obj = StandardScaler()
scl_obj.fit(X_train)

X_train = scl_obj.transform(X_train)
X_test = scl_obj.transform(X_test)

svm_sgd = SGDClassifier(alpha=0.0001, loss='hinge', penalty='l2',class_weight='balanced')

svm_sgd.fit(X_train,y_train)
yhat = svm_sgd.predict(X_test)

conf = confusion_matrix(y_test,yhat,labels)
acc = accuracy_score(y_test,yhat)
print (conf)
print (acc)
# Out:
# [[ 14983    245      0      1      0]
#  [  4346  91505  51512  10091   8135]
#  [     0  79283 382157  54330  39871]
#  [     0   7963  39901  45328  20861]
#  [     0    227   3345   1664  16468]]
# 0.631083355499

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, 
                      title='        Confusion Matrix: Individual & Family Plans (SVM)\n',
                      labels=labels)

# %%
plt.figure(figsize=(10, 8))
#weights = pd.Series(svm_sgd.coef_[0],index=colX)
weights = pd.Series(abs(svm_sgd.coef_[0]),index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %% [markdown]
# ## Try a different Classifier, RandomForests
#
# ### Train and Test with 2016 Data

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

# %%
model = RandomForestClassifier(class_weight='balanced')
model.fit(X_train,y_train)
predictions = model.predict(X_test)

conf = confusion_matrix(y_test,predictions,labels)
acc = accuracy_score(y_test,predictions)

print (conf)
print (acc)
# Out:
# [[ 15200     29      0      0      0]
#  [     8 155767   7631   2049    134]
#  [     0   8830 536014   9451   1346]
#  [     0   2363   8186 102279   1225]
#  [     0    117   1179   1243  19165]]
# 0.9497933998

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, 
                      title='        Confusion Matrix: Individual & Family Plans (RandomForests)\n',
                      labels=labels)

# %%
plt.figure(figsize=(10, 8))
weights = pd.Series(model.feature_importances_,index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %% [markdown]
# ### Weight Comparison Plots

# %%
weightsSVM = pd.Series(abs(svm_sgd.coef_[0]),index=colX)
weightsRF = pd.Series(model.feature_importances_,index=colX)

inf = pd.concat([weightsSVM,weightsRF],axis=1)
inf = inf.rename(columns={0:'SVM',1:'RandomForests'})

inf['SVM'] = inf.SVM/inf.SVM.max()
inf['RandomForests'] = inf.RandomForests/inf.RandomForests.max()

inf.sort_values('RandomForests', ascending=True).plot(kind='barh',stacked=False,figsize=(10,10))
plt.xlim([0,1.1])
plt.xticks(np.arange(0, 1.05, .1))
plt.yticks(fontsize=11)
plt.title('Model Comparison: SVM & Random Forests Attribute Weights\n', fontsize = 16)
plt.xlabel('Normalized Model Weights')
plt.legend(loc='best', fontsize = 'x-large')

# inf.sort_values('RandomForests', ascending=False).plot(kind='bar',stacked=False,figsize=(16,10))
# plt.ylim([0,1.05])

#Attributes to keep
attributesKeep = inf.loc[inf['RandomForests'] > 0.1,:].index.values

# %% [markdown]
# ### Train and Test but let's Eliminate Variables

# %%
colX = attributesKeep

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

# %%
model = RandomForestClassifier(class_weight='balanced')
model.fit(X_train,y_train)
predictions = model.predict(X_test)

conf = confusion_matrix(y_test,predictions,labels)
acc = accuracy_score(y_test,predictions)

print (conf)
print (acc)
# Out:
# [[ 15210     19      0      0      0]
#  [     7 150403  10871   4053    255]
#  [     0  13515 528559  11952   1615]
#  [     0   4229  10267  98014   1543]
#  [     0    238   1380   1554  18532]]
# 0.929492235868

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, title='Normalized confusion matrix',labels=labels)

# %%
plt.figure(figsize=(10, 8))
weights = pd.Series(model.feature_importances_,index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %% [markdown]
# ### Now try with SVM

# %%
scl_obj = StandardScaler()
scl_obj.fit(X_train)

X_train = scl_obj.transform(X_train)
X_test = scl_obj.transform(X_test)

svm_sgd = SGDClassifier(alpha=0.0001, loss='hinge', penalty='l2',class_weight='balanced')

svm_sgd.fit(X_train,y_train)
yhat = svm_sgd.predict(X_test)

conf = confusion_matrix(y_test,yhat,labels)
acc = accuracy_score(y_test,yhat)
print (conf)
print (acc)
# Out:
# [[ 14130   1099      0      0      0]
#  [  4049 100321  40758   5769  14692]
#  [     0 109244 344627  43771  57999]
#  [     0  11132  36188  33582  33151]
#  [     0    417   4131   1298  15858]]
# 0.583018426628

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, title='Normalized confusion matrix',labels=labels)

# %%
plt.figure(figsize=(10, 8))
#weights = pd.Series(svm_sgd.coef_[0],index=colX)
weights = pd.Series(abs(svm_sgd.coef_[0]),index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %%
weightsSVM = pd.Series(abs(svm_sgd.coef_[0]),index=colX)
weightsRF = pd.Series(model.feature_importances_,index=colX)

inf = pd.concat([weightsSVM,weightsRF],axis=1)
inf = inf.rename(columns={0:'SVM',1:'RandomForests'})

inf['SVM'] = inf.SVM/inf.SVM.max()
inf['RandomForests'] = inf.RandomForests/inf.RandomForests.max()

inf.sort_values('RandomForests', ascending=True).plot(kind='barh',stacked=False,figsize=(10,10))
plt.xlim([0,1.1])
plt.xticks(np.arange(0, 1.05, .1))
plt.yticks(fontsize=12)
plt.title('Model Comparison: SVM & Random Forests Attribute Weights\n', fontsize = 16)
plt.xlabel('Normalized Model Weights')
plt.legend(loc='best', fontsize = 'x-large')

# inf.sort_values('RandomForests', ascending=False).plot(kind='bar',stacked=False,figsize=(16,10))
# plt.ylim([0,1.05])

#Attributes to keep
attributesKeep = inf.loc[inf['RandomForests'] > 0.2,:].index.values

# %% [markdown]
# ### Third Iteration

# %%
colX = attributesKeep

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

# %%
model = RandomForestClassifier(class_weight='balanced')
model.fit(X_train,y_train)
predictions = model.predict(X_test)

conf = confusion_matrix(y_test,predictions,labels)
acc = accuracy_score(y_test,predictions)

print (conf)
print (acc)
# Out:
# [[ 15057    172      0      0      0]
#  [   231 146531  10794   6716   1317]
#  [     0  20244 515743  15887   3767]
#  [     0   6974  10557  94324   2198]
#  [     0    768   2384   1907  16645]]
# 0.903789886909

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, 
                      title='        Confusion Matrix: Individual & Family Plans (RandomForests)\n',
                      labels=labels)

# %%
plt.figure(figsize=(10, 8))
weights = pd.Series(model.feature_importances_,index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %% [markdown]
# ### Try with SVM again

# %%
scl_obj = StandardScaler()
scl_obj.fit(X_train)

X_train = scl_obj.transform(X_train)
X_test = scl_obj.transform(X_test)

svm_sgd = SGDClassifier(alpha=0.0001, loss='hinge', penalty='l2',class_weight='balanced')

svm_sgd.fit(X_train,y_train)
yhat = svm_sgd.predict(X_test)

conf = confusion_matrix(y_test,yhat,labels)
acc = accuracy_score(y_test,yhat)
print (conf)
print (acc)
# Out:
# [[  9253   5976      0      0      0]
#  [  6458  81852  56743   1860  18676]
#  [   659 136156 294933  35865  88028]
#  [     0  12236  43758  22643  35416]
#  [     0    672   4345   1010  15677]]
# 0.486528566318

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, title='Normalized confusion matrix',labels=labels)

# %%
plt.figure(figsize=(10, 8))
#weights = pd.Series(svm_sgd.coef_[0],index=colX)
weights = pd.Series(abs(svm_sgd.coef_[0]),index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %%
weightsSVM = pd.Series(abs(svm_sgd.coef_[0]),index=colX)
weightsRF = pd.Series(model.feature_importances_,index=colX)

inf = pd.concat([weightsSVM,weightsRF],axis=1)
inf = inf.rename(columns={0:'SVM',1:'RandomForests'})

inf['SVM'] = inf.SVM/inf.SVM.max()
inf['RandomForests'] = inf.RandomForests/inf.RandomForests.max()

inf.sort_values('RandomForests', ascending=True).plot(kind='barh',stacked=False,figsize=(10,10))
plt.xlim([0,1.1])
plt.xticks(np.arange(0, 1.05, .1))
plt.yticks(fontsize=12)
plt.title('Model Comparison: SVM & Random Forests Attribute Weights\n', fontsize = 16)
plt.xlabel('Normalized Model Weights')
plt.legend(loc='best', fontsize = 'x-large')

# inf.sort_values('RandomForests', ascending=False).plot(kind='bar',stacked=False,figsize=(16,10))
# plt.ylim([0,1.05])

#Attributes to keep
attributesKeep = inf.loc[inf['RandomForests'] > 0.2,:].index.values

# %% [markdown]
# ### Let's Generate Some Plots

# %%
df['logIndividualRate'] = np.log10(df['IndividualRate']+1)
df['logTEHBDedInnTier1Individual'] = np.log10(df['TEHBDedInnTier1Individual']+1)
df['logTEHBInnTier1IndividualMOOP'] = np.log10(df['TEHBInnTier1IndividualMOOP']+1)
df['logTEHBInnTier1FamilyPerGroupMOOP'] = np.log10(df['TEHBInnTier1FamilyPerGroupMOOP']+1)

# %%
col = 'IndividualRate'
#col = 'TEHBDedInnTier1Individual'
#col = 'logTEHBInnTier1IndividualMOOP'
#col = 'logTEHBInnTier1FamilyPerGroupMOOP'
tmp1 = df.loc[df['MetalLevel'] == 'Catastrophic',[col]]
tmp2 = df.loc[df['MetalLevel'] == 'Bronze',[col]]
tmp3 = df.loc[df['MetalLevel'] == 'Silver',[col]].head(700000)
tmp4 = df.loc[df['MetalLevel'] == 'Gold',[col]]
tmp5 = df.loc[df['MetalLevel'] == 'Platinum',[col]]

# %%
col = 'IndividualRate'
#col = 'TEHBDedInnTier1Individual'
#col = 'logTEHBInnTier1IndividualMOOP'
#col = 'logTEHBInnTier1FamilyPerGroupMOOP'
tmp1 = df.loc[(df['MetalLevel'] == 'Catastrophic') & (df['Age'] == 29),[col]]
tmp2 = df.loc[(df['MetalLevel'] == 'Bronze') & (df['Age'] == 29),[col]].head(6000)
tmp3 = df.loc[(df['MetalLevel'] == 'Silver') & (df['Age'] == 29),[col]].head(9000)
tmp4 = df.loc[(df['MetalLevel'] == 'Gold') & (df['Age'] == 29),[col]].head(5000)
tmp5 = df.loc[(df['MetalLevel'] == 'Platinum') & (df['Age'] == 29),[col]]

# %%
plt.figure(figsize=(16, 8))
plt.hist(df.IndividualRate,bins=60, label='IndividualRate')
plt.legend(loc='best',fontsize='xx-large')
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.hist(tmp3[col],bins=60, label = 'Silver', color = '#c0c0c0')
plt.hist(tmp2[col],bins=60, alpha = .65,label = 'Bronze',color='#cd7f32')
plt.hist(tmp4[col],bins=60, alpha = .65,label = 'Gold',color='#ffd700')
plt.hist(tmp5[col],bins=60, label = 'Platinum', color='#e5e4e2')
plt.hist(tmp1[col],bins=60, label = 'Catastrophic', color = '#ff0000')
plt.xlim([0,700])
#plt.ylim([0,50000])
plt.legend(loc='best',fontsize='xx-large')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Testing Treeinterpreter package

# %%
## Let's get tree paths to build a model
from treeinterpreter import treeinterpreter as ti

# %%
instance = X_train[1000,:].reshape(1,-1)
print (model.predict_proba(instance))
# Out:
# [[ 0.9  0.   0.   0.   0.1]]

# %%
y_train.iloc[1000]
# Out:
# 'Silver'

# %%
prediction, bias, contributions = ti.predict(model, instance)

X_train[1000,:]
# Out:
# array([ 0.86632496, -0.28821009, -0.67756781, -0.79387566,  0.05937393,
#        -0.38205974, -1.07362193, -0.38615053, -0.37787402, -1.07567282,
#        -1.0774596 ])

# %%
print ("Prediction", prediction)
print ("Bias (trainset prior)", bias)
print ("Feature contributions:")
print ("")
for c, feature in zip(contributions[0], colX):
    print ('{0!s:10} {1!s:10}'.format(c, feature))
# Out:
# Prediction [[ 0.9  0.   0.   0.   0.1]]
# Bias (trainset prior) [[ 0.19980357  0.20016527  0.19984531  0.20019284  0.19999301]]
# Feature contributions:
#
# [ 0.39041148  0.         -0.19579695 -0.2202592   0.02564466] IndividualRate
# [ 0.00790082  0.          0.02665102 -0.04850073  0.01394889] BeginCostSharingAfterNumberOfVisits
# [ 0.0374816   0.         -0.01828928  0.06270513 -0.08189744] SBCHavingDiabetesDeductible
# [ 0.0043811   0.         -0.00631623  0.0285342  -0.02659906] SBCHavingaBabyDeductible
# [ 0.07118921  0.         -0.03772107 -0.01154597 -0.02192218] EHBPercentTotalPremium
# [-0.00069386 -0.12016406  0.04296459  0.03583883  0.04205449] TEHBDedInnTier1Individual
# [ 0.02119691 -0.01988621  0.01459691 -0.00969223 -0.00621538] TEHBInnTier1IndividualMOOP
# [ 0.04648301 -0.01999385 -0.01942234  0.00127567 -0.00834248] TEHBDedInnTier1FamilyPerGroup
# [ 0.054301   -0.02000632 -0.02797123 -0.00476507 -0.00155838] TEHBDedInnTier1FamilyPerPerson
# [ 0.0443156   0.          0.0115767  -0.02219047 -0.03370183] TEHBInnTier1FamilyPerGroupMOOP
# [ 0.02322955 -0.02011482  0.00988258 -0.01159301 -0.0014043 ] TEHBInnTier1FamilyPerPersonMOOP

# %% [markdown]
# # Simplifying the Health Insurance Metal Level
#
# ## Classification Task 1: Binary Metal Level Classification ('Family Option' Plans)
#
# ## Classification Task 2: Multi-class Metal Level Classification ('Individual' Plans)
#
# Metal Levels (Bronze, Silver, Gold, Platinum) were designed to simplify the plan selection process for customers. By building supervised classification models, we wish to better understand Metal Levels and simplify the method by which Metal Levels are determined. Today, Metal Levels are generated via an Excel Spreadsheet. This method is time consuming and requires domain-based knowledge to fill out.
#
# ### General Results
#
# Dental Plans:     99% Accuracy given 2 Plan-Level attributes
# Small Business:   95% Accuracy given 5 Plan-Level attributes
# Individual Plans: 90% Accuracy given 11 Plan-Level attributes

# %%
# Import libraries needed for processing and visualizations
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Acquisition and Preparation
#
# ## Attribute Selection from PlanAttributes.csv

# %%
df = pd.read_csv('PlanAttributes.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77353 entries, 0 to 77352
# Columns: 176 entries, AVCalculatorOutputNumber to WellnessProgramOffered
# dtypes: float64(7), int64(9), object(160)
# memory usage: 103.9+ MB

# %% [markdown]
# As seen below, there are 176 attributes available per plan. Most are 'Object' type or Strings that may be converted to numerical values. There are also many null values in the dataset. A data dictionary is available and helps interpret each attribute. The approach here is to capture as many attributes as possible that may be useful in modeling. We will narrow down the list of attributes in later sections.

# %%
#Data Summary by Column, Null v Not Null Counts
print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format('Data Type','   Null', 'Not Null', 'Not Null %','','Column Name'))
for column in df.columns:
    print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format(df[column].dtype,
                                                         df[column].isnull().sum(), 
                                                         df[column].notnull().sum(),
                                                         round(df[column].notnull().sum()/df[column].notnull().count(),3),
                                                         ' ',column))
# Out:
# Data Type    Null  Not Null Not Null %      Column Name
# object       1666    11910    0.877      AVCalculatorOutputNumber
# int64           0    13576      1.0      BeginPrimaryCareCostSharingAfterNumberOfVisits
# int64           0    13576      1.0      BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays
# int64           0    13576      1.0      BenefitPackageId
# int64           0    13576      1.0      BusinessYear
# object          0    13576      1.0      CSRVariationType
# object          0    13576      1.0      ChildOnlyOffering
# object      13538       38    0.003      ChildOnlyPlanId
# object       8010     5566     0.41      CompositeRatingOffered
# object      13402      174    0.013      DEHBCombInnOonFamilyMOOP
# object      13576        0      0.0      DEHBCombInnOonFamilyPerGroupMOOP
# object      13576        0      0.0      DEHBCombInnOonFamilyPerPersonMOOP
# object      13402      174    0.013      DEHBCombInnOonIndividualMOOP
# object       9446     4130    0.304      DEHBDedCombInnOonFamily
# object      11535     2041     0.15      DEHBDedCombInnOonFamilyPerGroup
# object      11535     2041     0.15      DEHBDedCombInnOonFamilyPerPerson
# object       7405     6171    0.455      DEHBDedCombInnOonIndividual
# object       7405     6171    0.455      DEHBDedInnTier1Coinsurance
# object       9446     4130    0.304      DEHBDedInnTier1Family
# object      11535     2041     0.15      DEHBDedInnTier1FamilyPerGroup
# object      11535     2041     0.15      DEHBDedInnTier1FamilyPerPerson
# object       7405     6171    0.455      DEHBDedInnTier1Individual
# object      13222      354    0.026      DEHBDedInnTier2Coinsurance
# object      13576        0      0.0      DEHBDedInnTier2Family
# object      13222      354    0.026      DEHBDedInnTier2FamilyPerGroup
# object      13222      354    0.026      DEHBDedInnTier2FamilyPerPerson
# object      13222      354    0.026      DEHBDedInnTier2Individual
# object       9446     4130    0.304      DEHBDedOutOfNetFamily
# object      11535     2041     0.15      DEHBDedOutOfNetFamilyPerGroup
# object      11535     2041     0.15      DEHBDedOutOfNetFamilyPerPerson
# object       7405     6171    0.455      DEHBDedOutOfNetIndividual
# object      13402      174    0.013      DEHBInnTier1FamilyMOOP
# object      13576        0      0.0      DEHBInnTier1FamilyPerGroupMOOP
# object      13576        0      0.0      DEHBInnTier1FamilyPerPersonMOOP
# object      13402      174    0.013      DEHBInnTier1IndividualMOOP
# float64     13576        0      0.0      DEHBInnTier2FamilyMOOP
# float64     13576        0      0.0      DEHBInnTier2FamilyPerGroupMOOP
# float64     13576        0      0.0      DEHBInnTier2FamilyPerPersonMOOP
# float64     13576        0      0.0      DEHBInnTier2IndividualMOOP
# object      13402      174    0.013      DEHBOutOfNetFamilyMOOP
# object      13576        0      0.0      DEHBOutOfNetFamilyPerGroupMOOP
# object      13576        0      0.0      DEHBOutOfNetFamilyPerPersonMOOP
# object      13402      174    0.013      DEHBOutOfNetIndividualMOOP
# object          0    13576      1.0      DentalOnlyPlan
# object       1135    12441    0.916      DiseaseManagementProgramsOffered
# object      12681      895    0.066      EHBPediatricDentalApportionmentQuantity
# float64      6173     7403    0.545      EHBPercentPremiumS4
# float64      8310     5266    0.388      EHBPercentTotalPremium
# object          0    13576      1.0      FirstTierUtilization
# object        895    12681    0.934      FormularyId
# object        895    12681    0.934      FormularyURL
# object          0    13576      1.0      HIOSProductId
# float64     10223     3353    0.247      HPID
# object      11270     2306     0.17      HSAOrHRAEmployerContribution
# object      13528       48    0.004      HSAOrHRAEmployerContributionAmount
# object          0    13576      1.0      ImportDate
# object       3201    10375    0.764      IndianPlanVariationEstimatedAdvancedPaymentAmountPerEnrollee
# int64           0    13576      1.0      InpatientCopaymentMaximumDays
# object      12681      895    0.066      IsGuaranteedRate
# object        895    12681    0.934      IsHSAEligible
# object          0    13576      1.0      IsNewPlan
# object        895    12681    0.934      IsNoticeRequiredForPregnancy
# object        895    12681    0.934      IsReferralRequiredForSpecialist
# object       7794     5782    0.426      IssuerActuarialValue
# int64           0    13576      1.0      IssuerId
# int64           0    13576      1.0      IssuerId2
# object      12795      781    0.058      MEHBCombInnOonFamilyMOOP
# object      13288      288    0.021      MEHBCombInnOonFamilyPerGroupMOOP
# object      13288      288    0.021      MEHBCombInnOonFamilyPerPersonMOOP
# object      12507     1069    0.079      MEHBCombInnOonIndividualMOOP
# object       8839     4737    0.349      MEHBDedCombInnOonFamily
# object      11247     2329    0.172      MEHBDedCombInnOonFamilyPerGroup
# object      11247     2329    0.172      MEHBDedCombInnOonFamilyPerPerson
# object       6510     7066     0.52      MEHBDedCombInnOonIndividual
# object       7405     6171    0.455      MEHBDedInnTier1Coinsurance
# object       8839     4737    0.349      MEHBDedInnTier1Family
# object      11247     2329    0.172      MEHBDedInnTier1FamilyPerGroup
# object      11247     2329    0.172      MEHBDedInnTier1FamilyPerPerson
# object       6510     7066     0.52      MEHBDedInnTier1Individual
# object      13222      354    0.026      MEHBDedInnTier2Coinsurance
# object      13559       17    0.001      MEHBDedInnTier2Family
# object      13207      369    0.027      MEHBDedInnTier2FamilyPerGroup
# object      13207      369    0.027      MEHBDedInnTier2FamilyPerPerson
# object      13190      386    0.028      MEHBDedInnTier2Individual
# object       8839     4737    0.349      MEHBDedOutOfNetFamily
# object      11247     2329    0.172      MEHBDedOutOfNetFamilyPerGroup
# object      11247     2329    0.172      MEHBDedOutOfNetFamilyPerPerson
# object       6510     7066     0.52      MEHBDedOutOfNetIndividual
# object      12795      781    0.058      MEHBInnTier1FamilyMOOP
# object      13288      288    0.021      MEHBInnTier1FamilyPerGroupMOOP
# object      13288      288    0.021      MEHBInnTier1FamilyPerPersonMOOP
# object      12507     1069    0.079      MEHBInnTier1IndividualMOOP
# object      13559       17    0.001      MEHBInnTier2FamilyMOOP
# object      13561       15    0.001      MEHBInnTier2FamilyPerGroupMOOP
# object      13561       15    0.001      MEHBInnTier2FamilyPerPersonMOOP
# object      13544       32    0.002      MEHBInnTier2IndividualMOOP
# object      12795      781    0.058      MEHBOutOfNetFamilyMOOP
# object      13288      288    0.021      MEHBOutOfNetFamilyPerGroupMOOP
# object      13288      288    0.021      MEHBOutOfNetFamilyPerPersonMOOP
# object      12507     1069    0.079      MEHBOutOfNetIndividualMOOP
# object          0    13576      1.0      MarketCoverage
# object        895    12681    0.934      MedicalDrugDeductiblesIntegrated
# object        895    12681    0.934      MedicalDrugMaximumOutofPocketIntegrated
# object          0    13576      1.0      MetalLevel
# object          0    13576      1.0      MultipleInNetworkTiers
# object          0    13576      1.0      NationalNetwork
# object          0    13576      1.0      NetworkId
# object          0    13576      1.0      OutOfCountryCoverage
# object       2129    11447    0.843      OutOfCountryCoverageDescription
# object          0    13576      1.0      OutOfServiceAreaCoverage
# object       1295    12281    0.905      OutOfServiceAreaCoverageDescription
# object       1013    12563    0.925      PlanBrochure
# object          0    13576      1.0      PlanEffictiveDate
# object       7125     6451    0.475      PlanExpirationDate
# object          0    13576      1.0      PlanId
# object      12275     1301    0.096      PlanLevelExclusions
# object          0    13576      1.0      PlanMarketingName
# object          0    13576      1.0      PlanType
# object          0    13576      1.0      QHPNonQHPTypeId
# int64           0    13576      1.0      RowNumber
# object       5620     7956    0.586      SBCHavingDiabetesCoinsurance
# object       5608     7968    0.587      SBCHavingDiabetesCopayment
# object       5600     7976    0.588      SBCHavingDiabetesDeductible
# object       5602     7974    0.587      SBCHavingDiabetesLimit
# object       5601     7975    0.587      SBCHavingaBabyCoinsurance
# object       5598     7978    0.588      SBCHavingaBabyCopayment
# object       5600     7976    0.588      SBCHavingaBabyDeductible
# object       5602     7974    0.587      SBCHavingaBabyLimit
# object      11919     1657    0.122      SecondTierUtilization
# object          0    13576      1.0      ServiceAreaId
# object          0    13576      1.0      SourceName
# object       6598     6978    0.514      SpecialistRequiringReferral
# object      12112     1464    0.108      SpecialtyDrugMaximumCoinsurance
# object          0    13576      1.0      StandardComponentId
# object          0    13576      1.0      StateCode
# object          0    13576      1.0      StateCode2
# object       6347     7229    0.532      TEHBCombInnOonFamilyMOOP
# object       8298     5278    0.389      TEHBCombInnOonFamilyPerGroupMOOP
# object       8298     5278    0.389      TEHBCombInnOonFamilyPerPersonMOOP
# object       1069    12507    0.921      TEHBCombInnOonIndividualMOOP
# object      10303     3273    0.241      TEHBDedCombInnOonFamily
# object      10339     3237    0.238      TEHBDedCombInnOonFamilyPerGroup
# object      10339     3237    0.238      TEHBDedCombInnOonFamilyPerPerson
# object       7066     6510     0.48      TEHBDedCombInnOonIndividual
# object       7066     6510     0.48      TEHBDedInnTier1Coinsurance
# object      10303     3273    0.241      TEHBDedInnTier1Family
# object      10339     3237    0.238      TEHBDedInnTier1FamilyPerGroup
# object      10339     3237    0.238      TEHBDedInnTier1FamilyPerPerson
# object       7066     6510     0.48      TEHBDedInnTier1Individual
# object      12305     1271    0.094      TEHBDedInnTier2Coinsurance
# object      13503       73    0.005      TEHBDedInnTier2Family
# object      12378     1198    0.088      TEHBDedInnTier2FamilyPerGroup
# object      12378     1198    0.088      TEHBDedInnTier2FamilyPerPerson
# object      12305     1271    0.094      TEHBDedInnTier2Individual
# object      10303     3273    0.241      TEHBDedOutOfNetFamily
# object      10339     3237    0.238      TEHBDedOutOfNetFamilyPerGroup
# object      10339     3237    0.238      TEHBDedOutOfNetFamilyPerPerson
# object       7066     6510     0.48      TEHBDedOutOfNetIndividual
# object       6347     7229    0.532      TEHBInnTier1FamilyMOOP
# object       8298     5278    0.389      TEHBInnTier1FamilyPerGroupMOOP
# object       8298     5278    0.389      TEHBInnTier1FamilyPerPersonMOOP
# object       1069    12507    0.921      TEHBInnTier1IndividualMOOP
# object      13503       73    0.005      TEHBInnTier2FamilyMOOP
# object      12024     1552    0.114      TEHBInnTier2FamilyPerGroupMOOP
# object      12024     1552    0.114      TEHBInnTier2FamilyPerPersonMOOP
# object      11951     1625     0.12      TEHBInnTier2IndividualMOOP
# object       6347     7229    0.532      TEHBOutOfNetFamilyMOOP
# object       8298     5278    0.389      TEHBOutOfNetFamilyPerGroupMOOP
# object       8298     5278    0.389      TEHBOutOfNetFamilyPerPersonMOOP
# object       1069    12507    0.921      TEHBOutOfNetIndividualMOOP
# object          0    13576      1.0      TIN
# object       2840    10736    0.791      URLForEnrollmentPayment
# object        548    13028     0.96      URLForSummaryofBenefitsCoverage
# object        895    12681    0.934      UniquePlanDesign
# int64           0    13576      1.0      VersionNum
# object        895    12681    0.934      WellnessProgramOffered

# %% [markdown]
# From a total of 176 Attributes in the PlanAttributes.csv file, the list of relevant attributes below was put together after referencing the PlansAttributes_DataDictionary.pdf, which describes each attribute's contents and meaning. Attributes that are not included are those containing Product ID's, URLs, redundant columns, import data, and free-text entries.

# %%
relevant = ['AVCalculatorOutputNumber','BeginPrimaryCareCostSharingAfterNumberOfVisits',
              'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays','BusinessYear',
              'ChildOnlyOffering','CompositeRatingOffered','DentalOnlyPlan',
              'EHBPediatricDentalApportionmentQuantity',
              'EHBPercentPremiumS4','EHBPercentTotalPremium','FirstTierUtilization',
              'HSAOrHRAEmployerContribution','HSAOrHRAEmployerContributionAmount',
              'InpatientCopaymentMaximumDays','IsGuaranteedRate','IsHSAEligible',
              'IsNewPlan','IsNoticeRequiredForPregnancy','IsReferralRequiredForSpecialist',
              'IssuerActuarialValue','MarketCoverage','MedicalDrugDeductiblesIntegrated',
              'MedicalDrugMaximumOutofPocketIntegrated',
              'MetalLevel','MultipleInNetworkTiers','NationalNetwork',
              'OutOfCountryCoverage','OutOfServiceAreaCoverage',
              'PlanType','QHPNonQHPTypeId',
              'SecondTierUtilization','StandardComponentId',
              'UniquePlanDesign','WellnessProgramOffered']

# %% [markdown]
# Additionally, the lists below: coinsurance, individual, family, and summary of benefits (SBC), target attributes that can be grouped into these categories. Organizing into these lists enables us to clean data efficiently in a later step

# %%
coinsurance = []
print ('{0:10} {1:10}'.format('    Not Null %','    Column Name'))
for column in df.columns:
    if ('Coinsurance' in column and 'Begin' not in column):
        print ((df[column].notnull().sum()/df[column].notnull().count()), column)
        coinsurance.append(column)
# Out:
#     Not Null %     Column Name
# 0.454552150854 DEHBDedInnTier1Coinsurance
# 0.0260754272245 DEHBDedInnTier2Coinsurance
# 0.454552150854 MEHBDedInnTier1Coinsurance
# 0.0260754272245 MEHBDedInnTier2Coinsurance
# 0.586034177961 SBCHavingDiabetesCoinsurance
# 0.587433706541 SBCHavingaBabyCoinsurance
# 0.107837360047 SpecialtyDrugMaximumCoinsurance
# 0.479522687095 TEHBDedInnTier1Coinsurance
# 0.0936210960519 TEHBDedInnTier2Coinsurance

# %%
individual = []
print ('{0:10} {1:10}'.format('    Not Null %','    Column Name'))
for column in df.columns:
    if ('Individual' in column) and ((df[column].notnull().sum()/df[column].notnull().count()) > 0):
        print ((df[column].notnull().sum()/df[column].notnull().count()), column)
        individual.append(column)
# Out:
#     Not Null %     Column Name
# 0.0128167354154 DEHBCombInnOonIndividualMOOP
# 0.454552150854 DEHBDedCombInnOonIndividual
# 0.454552150854 DEHBDedInnTier1Individual
# 0.0260754272245 DEHBDedInnTier2Individual
# 0.454552150854 DEHBDedOutOfNetIndividual
# 0.0128167354154 DEHBInnTier1IndividualMOOP
# 0.0128167354154 DEHBOutOfNetIndividualMOOP
# 0.0787418974661 MEHBCombInnOonIndividualMOOP
# 0.520477312905 MEHBDedCombInnOonIndividual
# 0.520477312905 MEHBDedInnTier1Individual
# 0.0284325279906 MEHBDedInnTier2Individual
# 0.520477312905 MEHBDedOutOfNetIndividual
# 0.0787418974661 MEHBInnTier1IndividualMOOP
# 0.00235710076606 MEHBInnTier2IndividualMOOP
# 0.0787418974661 MEHBOutOfNetIndividualMOOP
# 0.921258102534 TEHBCombInnOonIndividualMOOP
# 0.479522687095 TEHBDedCombInnOonIndividual
# 0.479522687095 TEHBDedInnTier1Individual
# 0.0936210960519 TEHBDedInnTier2Individual
# 0.479522687095 TEHBDedOutOfNetIndividual
# 0.921258102534 TEHBInnTier1IndividualMOOP
# 0.119696523276 TEHBInnTier2IndividualMOOP
# 0.921258102534 TEHBOutOfNetIndividualMOOP

# %%
family = []
print ('{0:10} {1:10}'.format('    Not Null %','    Column Name'))
for column in df.columns:
    if ('Family' in column) and ((df[column].notnull().sum()/df[column].notnull().count()) > 0):
        print ((df[column].notnull().sum()/df[column].notnull().count()), column)
        family.append(column)
# Out:
#     Not Null %     Column Name
# 0.0128167354154 DEHBCombInnOonFamilyMOOP
# 0.304213317619 DEHBDedCombInnOonFamily
# 0.150338833235 DEHBDedCombInnOonFamilyPerGroup
# 0.150338833235 DEHBDedCombInnOonFamilyPerPerson
# 0.304213317619 DEHBDedInnTier1Family
# 0.150338833235 DEHBDedInnTier1FamilyPerGroup
# 0.150338833235 DEHBDedInnTier1FamilyPerPerson
# 0.0260754272245 DEHBDedInnTier2FamilyPerGroup
# 0.0260754272245 DEHBDedInnTier2FamilyPerPerson
# 0.304213317619 DEHBDedOutOfNetFamily
# 0.150338833235 DEHBDedOutOfNetFamilyPerGroup
# 0.150338833235 DEHBDedOutOfNetFamilyPerPerson
# 0.0128167354154 DEHBInnTier1FamilyMOOP
# 0.0128167354154 DEHBOutOfNetFamilyMOOP
# 0.0575279905716 MEHBCombInnOonFamilyMOOP
# 0.0212139068945 MEHBCombInnOonFamilyPerGroupMOOP
# 0.0212139068945 MEHBCombInnOonFamilyPerPersonMOOP
# 0.348924572775 MEHBDedCombInnOonFamily
# 0.17155274013 MEHBDedCombInnOonFamilyPerGroup
# 0.17155274013 MEHBDedCombInnOonFamilyPerPerson
# 0.348924572775 MEHBDedInnTier1Family
# 0.17155274013 MEHBDedInnTier1FamilyPerGroup
# 0.17155274013 MEHBDedInnTier1FamilyPerPerson
# 0.00125220978197 MEHBDedInnTier2Family
# 0.0271803182086 MEHBDedInnTier2FamilyPerGroup
# 0.0271803182086 MEHBDedInnTier2FamilyPerPerson
# 0.348924572775 MEHBDedOutOfNetFamily
# 0.17155274013 MEHBDedOutOfNetFamilyPerGroup
# 0.17155274013 MEHBDedOutOfNetFamilyPerPerson
# 0.0575279905716 MEHBInnTier1FamilyMOOP
# 0.0212139068945 MEHBInnTier1FamilyPerGroupMOOP
# 0.0212139068945 MEHBInnTier1FamilyPerPersonMOOP
# 0.00125220978197 MEHBInnTier2FamilyMOOP
# 0.00110489098409 MEHBInnTier2FamilyPerGroupMOOP
# 0.00110489098409 MEHBInnTier2FamilyPerPersonMOOP
# 0.0575279905716 MEHBOutOfNetFamilyMOOP
# 0.0212139068945 MEHBOutOfNetFamilyPerGroupMOOP
# 0.0212139068945 MEHBOutOfNetFamilyPerPersonMOOP
# 0.532483794932 TEHBCombInnOonFamilyMOOP
# 0.388774307602 TEHBCombInnOonFamilyPerGroupMOOP
# 0.388774307602 TEHBCombInnOonFamilyPerPersonMOOP
# 0.241087212728 TEHBDedCombInnOonFamily
# 0.238435474367 TEHBDedCombInnOonFamilyPerGroup
# 0.238435474367 TEHBDedCombInnOonFamilyPerPerson
# 0.241087212728 TEHBDedInnTier1Family
# 0.238435474367 TEHBDedInnTier1FamilyPerGroup
# 0.238435474367 TEHBDedInnTier1FamilyPerPerson
# 0.00537713612257 TEHBDedInnTier2Family
# 0.0882439599293 TEHBDedInnTier2FamilyPerGroup
# 0.0882439599293 TEHBDedInnTier2FamilyPerPerson
# 0.241087212728 TEHBDedOutOfNetFamily
# 0.238435474367 TEHBDedOutOfNetFamilyPerGroup
# 0.238435474367 TEHBDedOutOfNetFamilyPerPerson
# 0.532483794932 TEHBInnTier1FamilyMOOP
# 0.388774307602 TEHBInnTier1FamilyPerGroupMOOP
# 0.388774307602 TEHBInnTier1FamilyPerPersonMOOP
# 0.00537713612257 TEHBInnTier2FamilyMOOP
# 0.114319387154 TEHBInnTier2FamilyPerGroupMOOP
# 0.114319387154 TEHBInnTier2FamilyPerPersonMOOP
# 0.532483794932 TEHBOutOfNetFamilyMOOP
# 0.388774307602 TEHBOutOfNetFamilyPerGroupMOOP
# 0.388774307602 TEHBOutOfNetFamilyPerPersonMOOP

# %%
SBC = []
print ('{0:10} {1:10}'.format('    Not Null %','    Column Name'))
for column in df.columns:
    if 'SBC' in column and 'Coinsurance' not in column:
        print ((df[column].notnull().sum()/df[column].notnull().count()), column)
        SBC.append(column)
# Out:
#     Not Null %     Column Name
# 0.586918090748 SBCHavingDiabetesCopayment
# 0.58750736594 SBCHavingDiabetesDeductible
# 0.587360047142 SBCHavingDiabetesLimit
# 0.587654684738 SBCHavingaBabyCopayment
# 0.58750736594 SBCHavingaBabyDeductible
# 0.587360047142 SBCHavingaBabyLimit

# %% [markdown]
# ### We combine the column/attribute lists above to define our new dataframe without unnecessary columns

# %%
df = df[relevant + coinsurance + individual + family + SBC]
df.shape
# Out:
# (13576, 134)

# %% [markdown]
# ### We create the key below to uniquely identify each plan by year

# %%
df['key'] = df['BusinessYear'].astype(str) + df['StandardComponentId']

# %% [markdown]
# ## Attribute Data Cleaning
#
# From the Relevant Attributes List: Attributes in the revelant category are converted from text (object dtypes) to their respective int, float, or binary versions. For example, 64% is converted to 0.64, Yes or No, to 0 and 1.

# %%
def pConvert(x): #function to convert percentage (%) entries to a value between 0 - 1.
    if float(x) < 1:
        x = float(x)
    elif float(x) == 1:
        x = float(x)
    else:
        x = float(x)/float(100)
    return x

df['AVCalculatorOutputNumber'] = df.AVCalculatorOutputNumber.str.replace('%','')
df['AVCalculatorOutputNumber'] = pd.to_numeric(df.AVCalculatorOutputNumber,errors='raise')
df['AVCalculatorOutputNumber'] = df.AVCalculatorOutputNumber.apply(pConvert)

df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Adult and Child-only',value=1)
df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Adult and Child-Only',value=1)
df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Adult-Only',value=0)
df['ChildOnlyOffering'] = df.ChildOnlyOffering.replace(to_replace='Allows Child-Only',value=1)

df['CompositeRatingOffered'] = df.CompositeRatingOffered.replace(to_replace='Yes',value=1)
df['CompositeRatingOffered'] = df.CompositeRatingOffered.replace(to_replace='No',value=0)

df['DentalOnlyPlan'] = df.DentalOnlyPlan.replace(to_replace='Yes',value=1)
df['DentalOnlyPlan'] = df.DentalOnlyPlan.replace(to_replace='No',value=0)

df['EHBPediatricDentalApportionmentQuantity'] = df['EHBPediatricDentalApportionmentQuantity'].replace('[\$,)]','', regex=True).astype(float)

df['FirstTierUtilization'] = df.FirstTierUtilization.str.replace('%','')
df['FirstTierUtilization'] = pd.to_numeric(df.FirstTierUtilization,errors='raise')
df['FirstTierUtilization'] = df.FirstTierUtilization.apply(pConvert)

df['SecondTierUtilization'] = df.SecondTierUtilization.str.replace('%','')
df['SecondTierUtilization'] = pd.to_numeric(df.SecondTierUtilization,errors='raise')
df['SecondTierUtilization'] = df.SecondTierUtilization.apply(pConvert)

df['HSAOrHRAEmployerContribution'] = df.HSAOrHRAEmployerContribution.replace(to_replace='NO',value=0)
df['HSAOrHRAEmployerContribution'] = df.HSAOrHRAEmployerContribution.replace(to_replace='No',value=0)
df['HSAOrHRAEmployerContribution'] = df.HSAOrHRAEmployerContribution.replace(to_replace='Yes',value=1)

df['HSAOrHRAEmployerContributionAmount'] = df['HSAOrHRAEmployerContributionAmount'].replace('[\$,)]','', regex=True).astype(float)

df['IsGuaranteedRate'] = df.IsGuaranteedRate.replace(to_replace='Estimated Rate',value=0)
df['IsGuaranteedRate'] = df.IsGuaranteedRate.replace(to_replace='Guaranteed Rate',value=1)

df['IsHSAEligible'] = df.IsHSAEligible.replace(to_replace='NO',value=0)
df['IsHSAEligible'] = df.IsHSAEligible.replace(to_replace='No',value=0)
df['IsHSAEligible'] = df.IsHSAEligible.replace(to_replace='Yes',value=1)

df['IsNewPlan'] = df.IsNewPlan.replace(to_replace='Existing',value=0)
df['IsNewPlan'] = df.IsNewPlan.replace(to_replace='New',value=1)

df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='NO',value=0)
df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='No',value=0)
df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='Yes',value=1)
df['IsNoticeRequiredForPregnancy'] = df.IsNoticeRequiredForPregnancy.replace(to_replace='yes',value=1)

df['IsReferralRequiredForSpecialist'] = df.IsReferralRequiredForSpecialist.replace(to_replace='No',value=0)
df['IsReferralRequiredForSpecialist'] = df.IsReferralRequiredForSpecialist.replace(to_replace='Yes',value=1)
df['IsReferralRequiredForSpecialist'] = df.IsReferralRequiredForSpecialist.replace(to_replace='yes',value=1)

df['IssuerActuarialValue'] = df.IssuerActuarialValue.str.replace('%','')
df['IssuerActuarialValue'] = pd.to_numeric(df.IssuerActuarialValue,errors='raise')
df['IssuerActuarialValue'] = df.IssuerActuarialValue.apply(pConvert)

df['MarketCoverage'] = df.MarketCoverage.replace(to_replace='Individual',value=0)
df['MarketCoverage'] = df.MarketCoverage.replace(to_replace='SHOP (Small Group)',value=1)

df['MedicalDrugDeductiblesIntegrated'] = df.MedicalDrugDeductiblesIntegrated.replace(to_replace='No', value = 0)
df['MedicalDrugDeductiblesIntegrated'] = df.MedicalDrugDeductiblesIntegrated.replace(to_replace='Yes', value = 1)

df['MedicalDrugMaximumOutofPocketIntegrated'] = df.MedicalDrugMaximumOutofPocketIntegrated.replace(to_replace='No', value = 0)
df['MedicalDrugMaximumOutofPocketIntegrated'] = df.MedicalDrugMaximumOutofPocketIntegrated.replace(to_replace='Yes', value = 1)

df['MultipleInNetworkTiers'] = df.MultipleInNetworkTiers.replace(to_replace='No', value = 0)
df['MultipleInNetworkTiers'] = df.MultipleInNetworkTiers.replace(to_replace='Yes', value = 1)

df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='NO',value=0)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='no',value=0)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='No',value=0)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='YES',value=1)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='YEs',value=1)
df['NationalNetwork'] = df.NationalNetwork.replace(to_replace='Yes',value=1)

df['OutOfCountryCoverage'] = df.OutOfCountryCoverage.replace(to_replace='No',value=0)
df['OutOfCountryCoverage'] = df.OutOfCountryCoverage.replace(to_replace='YES',value=1)
df['OutOfCountryCoverage'] = df.OutOfCountryCoverage.replace(to_replace='Yes',value=1)

df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='No',value=0)
df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='YES',value=1)
df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='Yes',value=1)
df['OutOfServiceAreaCoverage'] = df.OutOfServiceAreaCoverage.replace(to_replace='yes',value=1)

df['UniquePlanDesign'] = df.UniquePlanDesign.replace(to_replace='No',value=0)
df['UniquePlanDesign'] = df.UniquePlanDesign.replace(to_replace='no',value=0)
df['UniquePlanDesign'] = df.UniquePlanDesign.replace(to_replace='Yes',value=1)

df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='yes',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Yes',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='no',value=0)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='No',value=0)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Guaranteed Rate',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Estimated Rate',value=1)
df['WellnessProgramOffered'] = df.WellnessProgramOffered.replace(to_replace='Allows Adult and Child-Only',value=1)

# %% [markdown]
# Cleaning Specific Attribute Categories - as mentioned earlier, each category is now cleaned. Like in the relevant list, entries are converted to their respective numerical values

# %%
for col in coinsurance:
    if 'Tier' in col:
        df[col] = df[col].replace(to_replace='$0', value = '0')
        df[col] = df[col].replace(to_replace='$0 ', value = '0')
        df[col] = df[col].str.replace('%','')
        df[col] = pd.to_numeric(df[col],errors='raise')
        df[col] = df[col].apply(pConvert)
    else:
        df[col] = df[col].replace(to_replace='Not Applicable', value = np.nan)
        df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for col in individual:
    df[col] = df[col].replace(to_replace='Not Applicable', value = np.nan)
    df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for col in family:
    df[col] = df[col].str.replace(' per group','')
    df[col] = df[col].str.replace(' per person','')
    df[col] = df[col].replace(to_replace='per group not applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='per group Not Applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='per person not applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='per person Not Applicable', value = np.nan)
    df[col] = df[col].replace(to_replace='Not Applicable', value = np.nan)
    df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %%
for col in SBC:
    df[col] = df[col].replace('[\$,)]','', regex=True).astype(float)

# %% [markdown]
# Now we can see that most of the columns are no longer 'Object' type and are now int or float type.

# %%
#Data Summary by Column, Null v Not Null Counts
print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format('Data Type','   Null', 'Not Null', 'Not Null %','','Column Name'))
for column in df.columns:
    print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format(df[column].dtype,
                                                         df[column].isnull().sum(), 
                                                         df[column].notnull().sum(),
                                                         round(df[column].notnull().sum()/df[column].notnull().count(),3),
                                                         ' ',column))
# Out:
# Data Type    Null  Not Null Not Null %      Column Name
# float64     13576        0      0.0      AVCalculatorOutputNumber
# int64           0    13576      1.0      BeginPrimaryCareCostSharingAfterNumberOfVisits
# int64           0    13576      1.0      BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays
# int64           0    13576      1.0      BusinessYear
# int64           0    13576      1.0      ChildOnlyOffering
# float64      8010     5566     0.41      CompositeRatingOffered
# int64           0    13576      1.0      DentalOnlyPlan
# float64     12681      895    0.066      EHBPediatricDentalApportionmentQuantity
# float64      6173     7403    0.545      EHBPercentPremiumS4
# float64      8310     5266    0.388      EHBPercentTotalPremium
# float64         0    13576      1.0      FirstTierUtilization
# float64     11270     2306     0.17      HSAOrHRAEmployerContribution
# float64     13528       48    0.004      HSAOrHRAEmployerContributionAmount
# int64           0    13576      1.0      InpatientCopaymentMaximumDays
# float64     12681      895    0.066      IsGuaranteedRate
# float64       895    12681    0.934      IsHSAEligible
# int64           0    13576      1.0      IsNewPlan
# float64       895    12681    0.934      IsNoticeRequiredForPregnancy
# float64       895    12681    0.934      IsReferralRequiredForSpecialist
# float64      7794     5782    0.426      IssuerActuarialValue
# int64           0    13576      1.0      MarketCoverage
# float64       895    12681    0.934      MedicalDrugDeductiblesIntegrated
# float64       895    12681    0.934      MedicalDrugMaximumOutofPocketIntegrated
# object          0    13576      1.0      MetalLevel
# int64           0    13576      1.0      MultipleInNetworkTiers
# int64           0    13576      1.0      NationalNetwork
# int64           0    13576      1.0      OutOfCountryCoverage
# int64           0    13576      1.0      OutOfServiceAreaCoverage
# object          0    13576      1.0      PlanType
# object          0    13576      1.0      QHPNonQHPTypeId
# float64     11919     1657    0.122      SecondTierUtilization
# object          0    13576      1.0      StandardComponentId
# float64       895    12681    0.934      UniquePlanDesign
# float64       895    12681    0.934      WellnessProgramOffered
# float64      7405     6171    0.455      DEHBDedInnTier1Coinsurance
# float64     13222      354    0.026      DEHBDedInnTier2Coinsurance
# float64      7405     6171    0.455      MEHBDedInnTier1Coinsurance
# float64     13222      354    0.026      MEHBDedInnTier2Coinsurance
# float64      5620     7956    0.586      SBCHavingDiabetesCoinsurance
# float64      5601     7975    0.587      SBCHavingaBabyCoinsurance
# float64     12112     1464    0.108      SpecialtyDrugMaximumCoinsurance
# float64      7066     6510     0.48      TEHBDedInnTier1Coinsurance
# float64     12305     1271    0.094      TEHBDedInnTier2Coinsurance
# float64     13566       10    0.001      DEHBCombInnOonIndividualMOOP
# float64     12859      717    0.053      DEHBDedCombInnOonIndividual
# float64      7420     6156    0.453      DEHBDedInnTier1Individual
# float64     13222      354    0.026      DEHBDedInnTier2Individual
# float64     12558     1018    0.075      DEHBDedOutOfNetIndividual
# float64     13402      174    0.013      DEHBInnTier1IndividualMOOP
# float64     13569        7    0.001      DEHBOutOfNetIndividualMOOP
# float64     13333      243    0.018      MEHBCombInnOonIndividualMOOP
# float64     12398     1178    0.087      MEHBDedCombInnOonIndividual
# float64      6916     6660    0.491      MEHBDedInnTier1Individual
# float64     13198      378    0.028      MEHBDedInnTier2Individual
# float64     11917     1659    0.122      MEHBDedOutOfNetIndividual
# float64     12689      887    0.065      MEHBInnTier1IndividualMOOP
# float64     13544       32    0.002      MEHBInnTier2IndividualMOOP
# float64     13417      159    0.012      MEHBOutOfNetIndividualMOOP
# float64     11567     2009    0.148      TEHBCombInnOonIndividualMOOP
# float64     12347     1229    0.091      TEHBDedCombInnOonIndividual
# float64      7066     6510     0.48      TEHBDedInnTier1Individual
# float64     12305     1271    0.094      TEHBDedInnTier2Individual
# float64     10698     2878    0.212      TEHBDedOutOfNetIndividual
# float64      1081    12495     0.92      TEHBInnTier1IndividualMOOP
# float64     11951     1625     0.12      TEHBInnTier2IndividualMOOP
# float64     10313     3263     0.24      TEHBOutOfNetIndividualMOOP
# float64     13569        7    0.001      DEHBCombInnOonFamilyMOOP
# float64     13167      409     0.03      DEHBDedCombInnOonFamily
# float64     13268      308    0.023      DEHBDedCombInnOonFamilyPerGroup
# float64     13268      308    0.023      DEHBDedCombInnOonFamilyPerPerson
# float64      9497     4079      0.3      DEHBDedInnTier1Family
# float64     11702     1874    0.138      DEHBDedInnTier1FamilyPerGroup
# float64     11675     1901     0.14      DEHBDedInnTier1FamilyPerPerson
# float64     13222      354    0.026      DEHBDedInnTier2FamilyPerGroup
# float64     13222      354    0.026      DEHBDedInnTier2FamilyPerPerson
# float64     13016      560    0.041      DEHBDedOutOfNetFamily
# float64     13154      422    0.031      DEHBDedOutOfNetFamilyPerGroup
# float64     13154      422    0.031      DEHBDedOutOfNetFamilyPerPerson
# float64     13402      174    0.013      DEHBInnTier1FamilyMOOP
# float64     13569        7    0.001      DEHBOutOfNetFamilyMOOP
# float64     13437      139     0.01      MEHBCombInnOonFamilyMOOP
# float64     13472      104    0.008      MEHBCombInnOonFamilyPerGroupMOOP
# float64     13472      104    0.008      MEHBCombInnOonFamilyPerPersonMOOP
# float64     13114      462    0.034      MEHBDedCombInnOonFamily
# float64     13175      401     0.03      MEHBDedCombInnOonFamilyPerGroup
# float64     13092      484    0.036      MEHBDedCombInnOonFamilyPerPerson
# float64      9334     4242    0.312      MEHBDedInnTier1Family
# float64     11486     2090    0.154      MEHBDedInnTier1FamilyPerGroup
# float64     11474     2102    0.155      MEHBDedInnTier1FamilyPerPerson
# float64     13563       13    0.001      MEHBDedInnTier2Family
# float64     13211      365    0.027      MEHBDedInnTier2FamilyPerGroup
# float64     13211      365    0.027      MEHBDedInnTier2FamilyPerPerson
# float64     12628      948     0.07      MEHBDedOutOfNetFamily
# float64     13169      407     0.03      MEHBDedOutOfNetFamilyPerGroup
# float64     13157      419    0.031      MEHBDedOutOfNetFamilyPerPerson
# float64     12895      681     0.05      MEHBInnTier1FamilyMOOP
# float64     13372      204    0.015      MEHBInnTier1FamilyPerGroupMOOP
# float64     13372      204    0.015      MEHBInnTier1FamilyPerPersonMOOP
# float64     13559       17    0.001      MEHBInnTier2FamilyMOOP
# float64     13561       15    0.001      MEHBInnTier2FamilyPerGroupMOOP
# float64     13561       15    0.001      MEHBInnTier2FamilyPerPersonMOOP
# float64     13453      123    0.009      MEHBOutOfNetFamilyMOOP
# float64     13540       36    0.003      MEHBOutOfNetFamilyPerGroupMOOP
# float64     13540       36    0.003      MEHBOutOfNetFamilyPerPersonMOOP
# float64     12603      973    0.072      TEHBCombInnOonFamilyMOOP
# float64     12540     1036    0.076      TEHBCombInnOonFamilyPerGroupMOOP
# float64     12540     1036    0.076      TEHBCombInnOonFamilyPerPersonMOOP
# float64     13061      515    0.038      TEHBDedCombInnOonFamily
# float64     12862      714    0.053      TEHBDedCombInnOonFamilyPerGroup
# float64     12862      714    0.053      TEHBDedCombInnOonFamilyPerPerson
# float64     10303     3273    0.241      TEHBDedInnTier1Family
# float64     10339     3237    0.238      TEHBDedInnTier1FamilyPerGroup
# float64     10411     3165    0.233      TEHBDedInnTier1FamilyPerPerson
# float64     13503       73    0.005      TEHBDedInnTier2Family
# float64     12378     1198    0.088      TEHBDedInnTier2FamilyPerGroup
# float64     12378     1198    0.088      TEHBDedInnTier2FamilyPerPerson
# float64     12087     1489     0.11      TEHBDedOutOfNetFamily
# float64     12182     1394    0.103      TEHBDedOutOfNetFamilyPerGroup
# float64     12234     1342    0.099      TEHBDedOutOfNetFamilyPerPerson
# float64      6359     7217    0.532      TEHBInnTier1FamilyMOOP
# float64      8298     5278    0.389      TEHBInnTier1FamilyPerGroupMOOP
# float64      8298     5278    0.389      TEHBInnTier1FamilyPerPersonMOOP
# float64     13503       73    0.005      TEHBInnTier2FamilyMOOP
# float64     12024     1552    0.114      TEHBInnTier2FamilyPerGroupMOOP
# float64     12024     1552    0.114      TEHBInnTier2FamilyPerPersonMOOP
# float64     11397     2179    0.161      TEHBOutOfNetFamilyMOOP
# float64     12508     1068    0.079      TEHBOutOfNetFamilyPerGroupMOOP
# float64     12508     1068    0.079      TEHBOutOfNetFamilyPerPersonMOOP
# float64      5608     7968    0.587      SBCHavingDiabetesCopayment
# float64      5600     7976    0.588      SBCHavingDiabetesDeductible
# float64      5602     7974    0.587      SBCHavingDiabetesLimit
# float64      5598     7978    0.588      SBCHavingaBabyCopayment
# float64      5600     7976    0.588      SBCHavingaBabyDeductible
# float64      5602     7974    0.587      SBCHavingaBabyLimit
# object          0    13576      1.0      key

# %% [markdown]
# We now save this dataframe as df_attr

# %%
df_attr = df
print ("Number of unique keys:",df_attr.key.unique().shape)
print ("Shape of df_attr:",df_attr.shape)
# Out:
# Number of unique keys: (3937,)
# Shape of df_attr: (13576, 135)

# %% [markdown]
# # Prepare Plan-Level Rate data to Join with Plan Attributes

# %%
df = pd.read_csv('Rate.csv')

# %% [markdown]
# For the Rate.csv, the columns below are relevant for further analysis. Columns that are ignored include data import tags and redundant columns.

# %%
ordered_cols = ['BusinessYear','StateCode','IssuerId','PlanId','Tobacco','Age',
                'IndividualRate','IndividualTobaccoRate','PrimarySubscriberAndOneDependent',
                'PrimarySubscriberAndTwoDependents','PrimarySubscriberAndThreeOrMoreDependents',
                'Couple','CoupleAndOneDependent','CoupleAndTwoDependents',
                'CoupleAndThreeOrMoreDependents']

df_rate = df[ordered_cols]

df_rate['key'] = df_rate.BusinessYear.astype(str) + df_rate.PlanId

# %%
print ("Number of unique keys:",df_rate.key.unique().shape)
print ("Shape of rate data:",df_rate.shape)
# Out:
# Number of unique keys: (3938,)
# Shape of rate data: (1872992, 16)

# %% [markdown]
# Here, we convert the age to a float value by designating some options to single numeric values. This enables us to use age as an attribute in our models, and since we are building separate models based on the 'Family Option', we can simply filter by Age == 66 or Age != 66.

# %%
df_rate['Age'] = df_rate.Age.str.replace('0-20','20')
df_rate['Age'] = df_rate.Age.str.replace('65 and over','65')
df_rate['Age'] = df_rate.Age.replace(to_replace="Family Option", value = '66')
df_rate['Age'] = df_rate.Age.astype(float)

df_rate['Tobacco'] = df_rate.Tobacco.replace(to_replace='No Preference', value = 0)
df_rate['Tobacco'] = df_rate.Tobacco.replace(to_replace='Tobacco User/Non-Tobacco User', value = 1)

# %%
df_rate.info() #Checking that our data is in proper data type form before we move forward
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1872992 entries, 2095510 to 11439957
# Data columns (total 16 columns):
# BusinessYear                                 int64
# StateCode                                    object
# IssuerId                                     int64
# PlanId                                       object
# Tobacco                                      int64
# Age                                          float64
# IndividualRate                               float64
# IndividualTobaccoRate                        float64
# PrimarySubscriberAndOneDependent             float64
# PrimarySubscriberAndTwoDependents            float64
# PrimarySubscriberAndThreeOrMoreDependents    float64
# Couple                                       float64
# CoupleAndOneDependent                        float64
# CoupleAndTwoDependents                       float64
# CoupleAndThreeOrMoreDependents               float64
# key                                          object
# dtypes: float64(10), int64(3), object(3)
# memory usage: 242.9+ MB

# %%
del df # Free some memory

# %% [markdown]
# ## Join Rate and Attribute Tables

# %%
#Pre-join key check
print ("Plan Attribute keys:",df_attr.key.unique().shape)
print ("Rate keys:",df_rate.key.unique().shape)
# Out:
# Plan Attribute keys: (3937,)
# Rate keys: (3938,)

# %%
df_join_RA = df_rate.merge(df_attr,how='left',on='key') #left, don't want to lose any rate keys
df_join_RA = df_join_RA.drop_duplicates()

# %%
# dropping and renaming redundant columns generated by the join operation
if 'BusinessYear_y' in df_join_RA.columns:
    df_join_RA = df_join_RA.drop('BusinessYear_y',axis=1)
    
df_join_RA = df_join_RA.rename(columns={'BusinessYear_x':'BusinessYear'})

# %%
#Post-join key check, appears that no keys were lost, which is good
print ('Joined Table key count:',df_join_RA.key.unique().shape)
print ('Joined Table Shape:',df_join_RA.shape)
# Out:
# Joined Table key count: (3938,)
# Joined Table Shape: (1818921, 149)

# %%
df_join_RA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1818921 entries, 0 to 4555884
# Columns: 149 entries, BusinessYear to SBCHavingaBabyLimit
# dtypes: float64(139), int64(3), object(7)
# memory usage: 2.0+ GB

# %% [markdown]
# Saving df_join_RA for future use and to skip all steps above.

# %%
df_join_RA.to_csv('df_join_RA.csv',encoding='utf-8')

# %% [markdown]
# # Modeling Phase
#
# We will now begin the modeling process using the joined dataset from the Rate & Plan Attributes files

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.cross_validation import ShuffleSplit
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.grid_search import GridSearchCV

# %%
#define confusion matrix plotting function
labels = ['Catastrophic','Bronze','Silver','Gold','Platinum']
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues,labels=labels):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 16)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45, fontsize = 14)
    plt.yticks(tick_marks, labels, fontsize = 14)
    plt.tight_layout()
    plt.ylabel('True label', fontsize = 16)
    plt.xlabel('Predicted label', fontsize = 16)

# %%
#reload the joined table into the dataframe (only needed if the kernel is re-started)
df_join_RA = pd.read_csv('df_join_RA.csv')
df_join_RA = df_join_RA.iloc[:,1:]
df_join_RA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1818921 entries, 0 to 1818920
# Columns: 149 entries, BusinessYear to SBCHavingaBabyLimit
# dtypes: float64(139), int64(3), object(7)
# memory usage: 2.0+ GB

# %% [markdown]
# # Classification Task 1: Binary Classification

# %%
df = df_join_RA

# %%
# Filter the data and verify only two levels exist for the Family Option criteria
# Age = 66 was designated to represent the Family Option
tmp = df[df['Age'] == 66].groupby('MetalLevel').count().reset_index().sort_values('PlanId', ascending = True)
tmp.plot(kind='barh',x ='MetalLevel', y='PlanId')

# %% [markdown]
# The family option contains two Metal Levels: Low and High. We will filter our original dataframe by 'Family Option' and inspect the remaining 'object' type attributes to generate one-hot encodings if needed.

# %%
df = df[df['Age'] == 66]
df.shape
# Out:
# (1742, 149)

# %%
df.groupby('MetalLevel')['key','BusinessYear'].count() #verifying Metal Levels after filter
# Out:
#             key  BusinessYear
# MetalLevel
# High        948           948
# Low         794           794

# %%
df.groupby('PlanType')['key','BusinessYear'].count() #Plan Types to require one-hot encoding
# Out:
#            key  BusinessYear
# PlanType
# HMO         15            15
# PPO       1727          1727

# %%
#Qualified health plan designation to require one-hot encoding
df.groupby('QHPNonQHPTypeId')['key','BusinessYear'].count()
# Out:
#                    key  BusinessYear
# QHPNonQHPTypeId
# Both               663           663
# Off the Exchange  1079          1079

# %%
#Generate one-hot encodings
tmp_df = pd.get_dummies(df.PlanType,prefix='PlanType')
df = pd.concat((df,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(df.QHPNonQHPTypeId,prefix='QHP')
df = pd.concat((df,tmp_df),axis=1) # add back into the dataframe

# %%
#Renaming a few columns for brevity
df = df.rename(columns = {'BeginPrimaryCareCostSharingAfterNumberOfVisits':'BeginCostSharingAfterNumberOfVisits'})
df = df.rename(columns = {'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays':'BeginDedCoinsAfterNumberOfCopays'})
df = df.rename(columns = {'EHBPediatricDentalApportionmentQuantity':'PediatricDentalApportionmentQty'})
df = df.rename(columns = {'InpatientCopaymentMaximumDays':'InpatientCopayMaxDays'})

# %% [markdown]
# As we can see below, very few of the Plan Attributes and Rates apply to the 'Family Option'. Given this, we will keep attributes that are 100% complete (contain no Null values) and will create another list of attributes to be imputed given that they at least have 50% of data available. The choice of 50% is a lower bound that the team felt was acceptable for imputing. Generally, we observed poor/biased distributions when we imputed attributes with less than 50% available data.

# %%
#Data Summary by Column, Null v Not Null Counts
print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format('Data Type','   Null', 'Not Null', 'Not Null %','','Column Name'))
for column in df.columns:
    print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format(df[column].dtype,
                                                         df[column].isnull().sum(), 
                                                         df[column].notnull().sum(),
                                                         round(df[column].notnull().sum()/df[column].notnull().count(),3),
                                                         ' ',column))
# Out:
# Data Type    Null  Not Null Not Null %      Column Name
# int64           0     1742      1.0      BusinessYear
# object          0     1742      1.0      StateCode
# int64           0     1742      1.0      IssuerId
# object          0     1742      1.0      PlanId
# int64           0     1742      1.0      Tobacco
# float64         0     1742      1.0      Age
# float64         0     1742      1.0      IndividualRate
# float64      1742        0      0.0      IndividualTobaccoRate
# float64         0     1742      1.0      PrimarySubscriberAndOneDependent
# float64         0     1742      1.0      PrimarySubscriberAndTwoDependents
# float64         0     1742      1.0      PrimarySubscriberAndThreeOrMoreDependents
# float64         0     1742      1.0      Couple
# float64         0     1742      1.0      CoupleAndOneDependent
# float64         0     1742      1.0      CoupleAndTwoDependents
# float64         0     1742      1.0      CoupleAndThreeOrMoreDependents
# object          0     1742      1.0      key
# float64      1742        0      0.0      AVCalculatorOutputNumber
# float64         0     1742      1.0      BeginCostSharingAfterNumberOfVisits
# float64         0     1742      1.0      BeginDedCoinsAfterNumberOfCopays
# float64         0     1742      1.0      ChildOnlyOffering
# float64      1209      533    0.306      CompositeRatingOffered
# float64         0     1742      1.0      DentalOnlyPlan
# float64         0     1742      1.0      PediatricDentalApportionmentQty
# float64      1742        0      0.0      EHBPercentPremiumS4
# float64      1742        0      0.0      EHBPercentTotalPremium
# float64         0     1742      1.0      FirstTierUtilization
# float64      1742        0      0.0      HSAOrHRAEmployerContribution
# float64      1742        0      0.0      HSAOrHRAEmployerContributionAmount
# float64         0     1742      1.0      InpatientCopayMaxDays
# float64         0     1742      1.0      IsGuaranteedRate
# float64      1742        0      0.0      IsHSAEligible
# float64         0     1742      1.0      IsNewPlan
# float64      1742        0      0.0      IsNoticeRequiredForPregnancy
# float64      1742        0      0.0      IsReferralRequiredForSpecialist
# float64         0     1742      1.0      IssuerActuarialValue
# float64         0     1742      1.0      MarketCoverage
# float64      1742        0      0.0      MedicalDrugDeductiblesIntegrated
# float64      1742        0      0.0      MedicalDrugMaximumOutofPocketIntegrated
# object          0     1742      1.0      MetalLevel
# float64         0     1742      1.0      MultipleInNetworkTiers
# float64         0     1742      1.0      NationalNetwork
# float64         0     1742      1.0      OutOfCountryCoverage
# float64         0     1742      1.0      OutOfServiceAreaCoverage
# object          0     1742      1.0      PlanType
# object          0     1742      1.0      QHPNonQHPTypeId
# float64      1742        0      0.0      SecondTierUtilization
# object          0     1742      1.0      StandardComponentId
# float64      1742        0      0.0      UniquePlanDesign
# float64      1742        0      0.0      WellnessProgramOffered
# float64      1742        0      0.0      DEHBDedInnTier1Coinsurance
# float64      1742        0      0.0      DEHBDedInnTier2Coinsurance
# float64      1742        0      0.0      MEHBDedInnTier1Coinsurance
# float64      1742        0      0.0      MEHBDedInnTier2Coinsurance
# float64      1742        0      0.0      SBCHavingDiabetesCoinsurance
# float64      1742        0      0.0      SBCHavingaBabyCoinsurance
# float64      1742        0      0.0      SpecialtyDrugMaximumCoinsurance
# float64      1742        0      0.0      TEHBDedInnTier1Coinsurance
# float64      1742        0      0.0      TEHBDedInnTier2Coinsurance
# float64      1742        0      0.0      DEHBCombInnOonIndividualMOOP
# float64      1742        0      0.0      DEHBDedCombInnOonIndividual
# float64      1742        0      0.0      DEHBDedInnTier1Individual
# float64      1742        0      0.0      DEHBDedInnTier2Individual
# float64      1742        0      0.0      DEHBDedOutOfNetIndividual
# float64      1742        0      0.0      DEHBInnTier1IndividualMOOP
# float64      1742        0      0.0      DEHBOutOfNetIndividualMOOP
# float64      1259      483    0.277      MEHBCombInnOonIndividualMOOP
# float64       983      759    0.436      MEHBDedCombInnOonIndividual
# float64       838      904    0.519      MEHBDedInnTier1Individual
# float64      1742        0      0.0      MEHBDedInnTier2Individual
# float64       876      866    0.497      MEHBDedOutOfNetIndividual
# float64       481     1261    0.724      MEHBInnTier1IndividualMOOP
# float64      1742        0      0.0      MEHBInnTier2IndividualMOOP
# float64      1539      203    0.117      MEHBOutOfNetIndividualMOOP
# float64      1742        0      0.0      TEHBCombInnOonIndividualMOOP
# float64      1742        0      0.0      TEHBDedCombInnOonIndividual
# float64      1742        0      0.0      TEHBDedInnTier1Individual
# float64      1742        0      0.0      TEHBDedInnTier2Individual
# float64      1742        0      0.0      TEHBDedOutOfNetIndividual
# float64      1742        0      0.0      TEHBInnTier1IndividualMOOP
# float64      1742        0      0.0      TEHBInnTier2IndividualMOOP
# float64      1742        0      0.0      TEHBOutOfNetIndividualMOOP
# float64      1742        0      0.0      DEHBCombInnOonFamilyMOOP
# float64      1742        0      0.0      DEHBDedCombInnOonFamily
# float64      1742        0      0.0      DEHBDedCombInnOonFamilyPerGroup
# float64      1742        0      0.0      DEHBDedCombInnOonFamilyPerPerson
# float64      1742        0      0.0      DEHBDedInnTier1Family
# float64      1742        0      0.0      DEHBDedInnTier1FamilyPerGroup
# float64      1742        0      0.0      DEHBDedInnTier1FamilyPerPerson
# float64      1742        0      0.0      DEHBDedInnTier2FamilyPerGroup
# float64      1742        0      0.0      DEHBDedInnTier2FamilyPerPerson
# float64      1742        0      0.0      DEHBDedOutOfNetFamily
# float64      1742        0      0.0      DEHBDedOutOfNetFamilyPerGroup
# float64      1742        0      0.0      DEHBDedOutOfNetFamilyPerPerson
# float64      1742        0      0.0      DEHBInnTier1FamilyMOOP
# float64      1742        0      0.0      DEHBOutOfNetFamilyMOOP
# float64      1497      245    0.141      MEHBCombInnOonFamilyMOOP
# float64      1504      238    0.137      MEHBCombInnOonFamilyPerGroupMOOP
# float64      1504      238    0.137      MEHBCombInnOonFamilyPerPersonMOOP
# float64      1690       52     0.03      MEHBDedCombInnOonFamily
# float64      1688       54    0.031      MEHBDedCombInnOonFamilyPerGroup
# float64      1360      382    0.219      MEHBDedCombInnOonFamilyPerPerson
# float64      1412      330    0.189      MEHBDedInnTier1Family
# float64      1740        2    0.001      MEHBDedInnTier1FamilyPerGroup
# float64      1732       10    0.006      MEHBDedInnTier1FamilyPerPerson
# float64      1742        0      0.0      MEHBDedInnTier2Family
# float64      1742        0      0.0      MEHBDedInnTier2FamilyPerGroup
# float64      1742        0      0.0      MEHBDedInnTier2FamilyPerPerson
# float64      1422      320    0.184      MEHBDedOutOfNetFamily
# float64      1742        0      0.0      MEHBDedOutOfNetFamilyPerGroup
# float64      1734        8    0.005      MEHBDedOutOfNetFamilyPerPerson
# float64       776      966    0.555      MEHBInnTier1FamilyMOOP
# float64      1447      295    0.169      MEHBInnTier1FamilyPerGroupMOOP
# float64      1447      295    0.169      MEHBInnTier1FamilyPerPersonMOOP
# float64      1742        0      0.0      MEHBInnTier2FamilyMOOP
# float64      1742        0      0.0      MEHBInnTier2FamilyPerGroupMOOP
# float64      1742        0      0.0      MEHBInnTier2FamilyPerPersonMOOP
# float64      1551      191     0.11      MEHBOutOfNetFamilyMOOP
# float64      1730       12    0.007      MEHBOutOfNetFamilyPerGroupMOOP
# float64      1730       12    0.007      MEHBOutOfNetFamilyPerPersonMOOP
# float64      1742        0      0.0      TEHBCombInnOonFamilyMOOP
# float64      1742        0      0.0      TEHBCombInnOonFamilyPerGroupMOOP
# float64      1742        0      0.0      TEHBCombInnOonFamilyPerPersonMOOP
# float64      1742        0      0.0      TEHBDedCombInnOonFamily
# float64      1742        0      0.0      TEHBDedCombInnOonFamilyPerGroup
# float64      1742        0      0.0      TEHBDedCombInnOonFamilyPerPerson
# float64      1742        0      0.0      TEHBDedInnTier1Family
# float64      1742        0      0.0      TEHBDedInnTier1FamilyPerGroup
# float64      1742        0      0.0      TEHBDedInnTier1FamilyPerPerson
# float64      1742        0      0.0      TEHBDedInnTier2Family
# float64      1742        0      0.0      TEHBDedInnTier2FamilyPerGroup
# float64      1742        0      0.0      TEHBDedInnTier2FamilyPerPerson
# float64      1742        0      0.0      TEHBDedOutOfNetFamily
# float64      1742        0      0.0      TEHBDedOutOfNetFamilyPerGroup
# float64      1742        0      0.0      TEHBDedOutOfNetFamilyPerPerson
# float64      1742        0      0.0      TEHBInnTier1FamilyMOOP
# float64      1742        0      0.0      TEHBInnTier1FamilyPerGroupMOOP
# float64      1742        0      0.0      TEHBInnTier1FamilyPerPersonMOOP
# float64      1742        0      0.0      TEHBInnTier2FamilyMOOP
# float64      1742        0      0.0      TEHBInnTier2FamilyPerGroupMOOP
# float64      1742        0      0.0      TEHBInnTier2FamilyPerPersonMOOP
# float64      1742        0      0.0      TEHBOutOfNetFamilyMOOP
# float64      1742        0      0.0      TEHBOutOfNetFamilyPerGroupMOOP
# float64      1742        0      0.0      TEHBOutOfNetFamilyPerPersonMOOP
# float64      1742        0      0.0      SBCHavingDiabetesCopayment
# float64      1742        0      0.0      SBCHavingDiabetesDeductible
# float64      1742        0      0.0      SBCHavingDiabetesLimit
# float64      1742        0      0.0      SBCHavingaBabyCopayment
# float64      1742        0      0.0      SBCHavingaBabyDeductible
# float64      1742        0      0.0      SBCHavingaBabyLimit
# float64         0     1742      1.0      PlanType_HMO
# float64         0     1742      1.0      PlanType_PPO
# float64         0     1742      1.0      QHP_Both
# float64         0     1742      1.0      QHP_Off the Exchange

# %% [markdown]
# List of Attributes with no missing values

# %%
#The items in the noNeed list are exceptions that will not be needed in the modeling portion but otherwise qualify
noNeed = ['IssuerId']
noNulls = []
for column in df.columns:
    if ((df[column].notnull().sum()/df[column].notnull().count() == 1) and (df[column].dtype != 'object')
       and (column not in noNeed)):
        print ('{0:6} {1:20}'.format(df[column].notnull().sum()/df[column].notnull().count(),column))
        noNulls.append(column)
# Out:
#    1.0 BusinessYear
#    1.0 Tobacco
#    1.0 Age
#    1.0 IndividualRate
#    1.0 PrimarySubscriberAndOneDependent
#    1.0 PrimarySubscriberAndTwoDependents
#    1.0 PrimarySubscriberAndThreeOrMoreDependents
#    1.0 Couple
#    1.0 CoupleAndOneDependent
#    1.0 CoupleAndTwoDependents
#    1.0 CoupleAndThreeOrMoreDependents
#    1.0 BeginCostSharingAfterNumberOfVisits
#    1.0 BeginDedCoinsAfterNumberOfCopays
#    1.0 ChildOnlyOffering
#    1.0 DentalOnlyPlan
#    1.0 PediatricDentalApportionmentQty
#    1.0 FirstTierUtilization
#    1.0 InpatientCopayMaxDays
#    1.0 IsGuaranteedRate
#    1.0 IsNewPlan
#    1.0 IssuerActuarialValue
#    1.0 MarketCoverage
#    1.0 MultipleInNetworkTiers
#    1.0 NationalNetwork
#    1.0 OutOfCountryCoverage
#    1.0 OutOfServiceAreaCoverage
#    1.0 PlanType_HMO
#    1.0 PlanType_PPO
#    1.0 QHP_Both
#    1.0 QHP_Off the Exchange

# %% [markdown]
# List of attributes that may be imputed as more than 50% of data is available. Imputed with medians.

# %%
imputed = []
for column in df.columns:
    if ((column not in noNulls) and (df[column].dtype != 'object') and (column not in noNeed)
       and ( df[column].notnull().sum()/df[column].notnull().count() > 0.5 )):
        print ('{0:6} {1:20}'.format(round(df[column].notnull().sum()/df[column].notnull().count(),4),column))
        imputed.append(column)
# Out:
# 0.5189 MEHBDedInnTier1Individual
# 0.7239 MEHBInnTier1IndividualMOOP
# 0.5545 MEHBInnTier1FamilyMOOP

# %%
df.MEHBDedInnTier1Individual = df.MEHBDedInnTier1Individual.fillna(df.MEHBDedInnTier1Individual.median()) #median
df.MEHBInnTier1IndividualMOOP = df.MEHBInnTier1IndividualMOOP.fillna(df.MEHBInnTier1IndividualMOOP.median()) #median
df.MEHBInnTier1FamilyMOOP = df.MEHBInnTier1FamilyMOOP.fillna(df.MEHBInnTier1FamilyMOOP.median()) #median

# %% [markdown]
# The colX list contains attribute names that will be used in the models

# %%
colX = noNulls + imputed

# %% [markdown]
# Before we model, we will separate our attributes into continuous and categorical feature types. The OneLevel list will capture attributes that only have 1 value and thus offer no value in the modeling process and will thus be excluded from colX

# %%
continuous = []
categorical = []
oneLevel = []
for col in colX:
    if df[col].unique().size > 2:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Continuous', df[col].dtype ,col))
        continuous.append(col)
    elif df[col].unique().size == 1:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'One Level', df[col].dtype ,col))
        oneLevel.append(col)
    else:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Categorical', df[col].dtype ,col))
        categorical.append(col)
        
colX = continuous + categorical
# Out:
#      3 Continuous   int64      BusinessYear
#      1 One Level    int64      Tobacco
#      1 One Level    float64    Age
#   1150 Continuous   float64    IndividualRate
#   1484 Continuous   float64    PrimarySubscriberAndOneDependent
#   1506 Continuous   float64    PrimarySubscriberAndTwoDependents
#   1565 Continuous   float64    PrimarySubscriberAndThreeOrMoreDependents
#   1243 Continuous   float64    Couple
#   1527 Continuous   float64    CoupleAndOneDependent
#   1572 Continuous   float64    CoupleAndTwoDependents
#   1576 Continuous   float64    CoupleAndThreeOrMoreDependents
#      1 One Level    float64    BeginCostSharingAfterNumberOfVisits
#      1 One Level    float64    BeginDedCoinsAfterNumberOfCopays
#      1 One Level    float64    ChildOnlyOffering
#      1 One Level    float64    DentalOnlyPlan
#     89 Continuous   float64    PediatricDentalApportionmentQty
#      1 One Level    float64    FirstTierUtilization
#      1 One Level    float64    InpatientCopayMaxDays
#      2 Categorical  float64    IsGuaranteedRate
#      2 Categorical  float64    IsNewPlan
#     28 Continuous   float64    IssuerActuarialValue
#      2 Categorical  float64    MarketCoverage
#      1 One Level    float64    MultipleInNetworkTiers
#      2 Categorical  float64    NationalNetwork
#      2 Categorical  float64    OutOfCountryCoverage
#      2 Categorical  float64    OutOfServiceAreaCoverage
#      2 Categorical  float64    PlanType_HMO
#      2 Categorical  float64    PlanType_PPO
#      2 Categorical  float64    QHP_Both
#      2 Categorical  float64    QHP_Off the Exchange
#      9 Continuous   float64    MEHBDedInnTier1Individual
#      2 Categorical  float64    MEHBInnTier1IndividualMOOP
#      2 Categorical  float64    MEHBInnTier1FamilyMOOP

# %% [markdown]
# ## Collinearity Analysis
#
# We will now explore the correlations between attributes.

# %%
tmp = df[continuous]
print (tmp.shape)

# Compute the correlation matrix
corr = tmp.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = False

sns.set(style="darkgrid")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16,16))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={"shrink": .75}, ax=ax, annot = True, fmt = '.2f')
# Out:
# (1742, 12)

# %% [markdown]
# The above correlation matrix shows a large amount of collinearity among the variables.  We will create a temporary array for the attributes that we wish to keep in the model by removing attributes showed the highest collinearity.  We will then repeat the process of creating arrays for the continuous and categorical variables.

# %%
collinear = ['PrimarySubscriberAndOneDependent','PrimarySubscriberAndTwoDependents',
            'CoupleAndOneDependent','CoupleAndTwoDependents']

tmp = []
for col in colX:
    if col not in collinear:
        tmp.append(col)
        
colX = tmp

# %%
continuous = []
categorical = []
oneLevel = []
for col in colX:
    if df[col].unique().size > 2:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Continuous', df[col].dtype ,col))
        continuous.append(col)
    elif df[col].unique().size == 1:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'One Level', df[col].dtype ,col))
        oneLevel.append(col)
    else:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Categorical', df[col].dtype ,col))
        categorical.append(col)
# Out:
#      3 Continuous   int64      BusinessYear
#   1150 Continuous   float64    IndividualRate
#   1565 Continuous   float64    PrimarySubscriberAndThreeOrMoreDependents
#   1243 Continuous   float64    Couple
#   1576 Continuous   float64    CoupleAndThreeOrMoreDependents
#     89 Continuous   float64    PediatricDentalApportionmentQty
#     28 Continuous   float64    IssuerActuarialValue
#      9 Continuous   float64    MEHBDedInnTier1Individual
#      2 Categorical  float64    IsGuaranteedRate
#      2 Categorical  float64    IsNewPlan
#      2 Categorical  float64    MarketCoverage
#      2 Categorical  float64    NationalNetwork
#      2 Categorical  float64    OutOfCountryCoverage
#      2 Categorical  float64    OutOfServiceAreaCoverage
#      2 Categorical  float64    PlanType_HMO
#      2 Categorical  float64    PlanType_PPO
#      2 Categorical  float64    QHP_Both
#      2 Categorical  float64    QHP_Off the Exchange
#      2 Categorical  float64    MEHBInnTier1IndividualMOOP
#      2 Categorical  float64    MEHBInnTier1FamilyMOOP

# %%
tmp = df[continuous]
print (tmp.shape)

# Compute the correlation matrix
corr = tmp.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = False

sns.set(style="darkgrid")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16,16))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={"shrink": .75}, ax=ax, annot = True, fmt = '.2f')
# Out:
# (1742, 8)

# %% [markdown]
# Based on the correlation matrix above, the correlation among variables has been reduced although it remains high between some of the continuous attributes. We decided to keep the attributes above as they may shed light on the Metal Level determination.
#
# The data will now be prepared for modeling.  We will begin with the multinomial naive bayes model.  We utilize a 70/30 shufflesplit to randomize our data between the training and test sets, along with 10 iterations for cross-validation of the model.  A seed value of 42 is set to maintain consistency when we compare models.  A Grid Search is utilized to test multiple parameter values for each model.
#
# By default, grid search scoring is based on accuracy unless otherwise specified. In this binary classification case, we believe that accuracy is an adequate comparison measure between models as there is no compelling argument to prioritize recall or precision over accuracy.

# %%
colX = continuous + categorical #Final set of attributes before modeling

# %%
cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

parameters = {'alpha': [0.0001, 0.01, 0.1, 1, 10, 100]} #only viable parameter at this point

# %%
from sklearn.naive_bayes import MultinomialNB

mnb = MultinomialNB()
gs = GridSearchCV(mnb, parameters, cv=cv, n_jobs=-1, verbose=10)

gs.fit(df[colX], df['MetalLevel'])
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] alpha=0.0001 ....................................................
# [CV] alpha=0.0001 ....................................................
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.632887 -   0.0s
# [CV] alpha=0.0001 ....................................................
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.623327 -   0.1s
# [CV] ........................... alpha=0.0001, score=0.613767 -   0.0s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.611855 -   0.1s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.632887 -   0.1s
# [CV] alpha=0.0001 ....................................................
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.621415 -   0.0s
# [CV] alpha=0.01 ......................................................
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0797s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.2s
# [CV] ........................... alpha=0.0001, score=0.600382 -   0.1s
# [CV] ........................... alpha=0.0001, score=0.621415 -   0.0s
# [CV] ........................... alpha=0.0001, score=0.632887 -   0.0s
# [CV] alpha=0.0001 ....................................................
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.1 .......................................................
# [CV] ............................. alpha=0.01, score=0.623327 -   0.0s
# [CV] ........................... alpha=0.0001, score=0.615679 -   0.0s
# [CV] ............................. alpha=0.01, score=0.621415 -   0.0s
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.01 ......................................................
# [CV] .............................. alpha=0.1, score=0.613767 -   0.0s
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.1 .......................................................
# [CV] ............................. alpha=0.01, score=0.621415 -   0.0s
# [CV] ............................. alpha=0.01, score=0.611855 -   0.0s
# [CV] ............................. alpha=0.01, score=0.613767 -   0.0s
# [CV] .............................. alpha=0.1, score=0.632887 -   0.0s
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.1 .......................................................
# [CV] ............................. alpha=0.01, score=0.632887 -   0.0s
# [CV] alpha=0.01 ......................................................
# [CV] ............................. alpha=0.01, score=0.632887 -   0.0s
# [CV] ............................. alpha=0.01, score=0.632887 -   0.0s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.623327 -   0.0s
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.632887 -   0.0s
# [CV] ............................. alpha=0.01, score=0.615679 -   0.0s
# [CV] ............................. alpha=0.01, score=0.600382 -   0.0s
# [CV] alpha=0.1 .......................................................
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.611855 -   0.0s
# [CV] alpha=1 .........................................................
# [CV] alpha=1 .........................................................
# [CV] .............................. alpha=0.1, score=0.632887 -   0.0s
# [CV] .............................. alpha=0.1, score=0.600382 -   0.0s
# [CV] ................................ alpha=1, score=0.623327 -   0.0s
# [CV] alpha=0.1 .......................................................
# [CV] alpha=1 .........................................................
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.621415 -   0.0s
# [CV] ................................ alpha=1, score=0.611855 -   0.0s
# [CV] alpha=0.1 .......................................................
# [CV] alpha=1 .........................................................
# [CV] ................................ alpha=1, score=0.621415 -   0.0s
# [CV] .............................. alpha=0.1, score=0.615679 -   0.0s
# [CV] alpha=1 .........................................................
# [CV] alpha=1 .........................................................
# [CV] .............................. alpha=0.1, score=0.621415 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] ................................ alpha=1, score=0.613767 -   0.0s
# [CV] ................................ alpha=1, score=0.632887 -   0.0s
# [CV] alpha=1 .........................................................
# [CV] ................................ alpha=1, score=0.621415 -   0.0s
# [CV] alpha=1 .........................................................
# [CV] ............................... alpha=10, score=0.613767 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] alpha=1 .........................................................
# [CV] ................................ alpha=1, score=0.632887 -   0.0s
# [CV] ................................ alpha=1, score=0.632887 -   0.0s
# [CV] alpha=1 .........................................................
# [CV] alpha=10 ........................................................
# [CV] ............................... alpha=10, score=0.632887 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] ................................ alpha=1, score=0.600382 -   0.0s
# [CV] ................................ alpha=1, score=0.615679 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] ............................... alpha=10, score=0.632887 -   0.0s
# [CV] alpha=100 .......................................................
# [CV] alpha=10 ........................................................
# [CV] ............................... alpha=10, score=0.623327 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] ............................... alpha=10, score=0.632887 -   0.0s
# [CV] ............................... alpha=10, score=0.598470 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] alpha=10 ........................................................
# [CV] .............................. alpha=100, score=0.623327 -   0.0s
# [CV] alpha=100 .......................................................
# [CV] ............................... alpha=10, score=0.621415 -   0.0s
# [CV] alpha=10 ........................................................
# [CV] ............................... alpha=10, score=0.611855 -   0.0s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.4s
# [CV] ............................... alpha=10, score=0.615679 -   0.0s
# [CV] alpha=100 .......................................................
# [CV] alpha=100 .......................................................
# [CV] .............................. alpha=100, score=0.611855 -   0.0s
# [CV] .............................. alpha=100, score=0.621415 -   0.0s
# [CV] ............................... alpha=10, score=0.621415 -   0.0s
# [CV] .............................. alpha=100, score=0.611855 -   0.0s
# [CV] alpha=100 .......................................................
# [CV] alpha=100 .......................................................
# [CV] alpha=100 .......................................................
# [CV] .............................. alpha=100, score=0.630975 -   0.0s
# [CV] .............................. alpha=100, score=0.629063 -   0.0s
# [CV] .............................. alpha=100, score=0.623327 -   0.0s
# [CV] alpha=100 .......................................................
# [CV] alpha=100 .......................................................
# [CV] .............................. alpha=100, score=0.632887 -   0.0s
# [CV] .............................. alpha=100, score=0.596558 -   0.0s
# [CV] alpha=100 .......................................................
# [CV] .............................. alpha=100, score=0.617591 -   0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.8s finished
# GridSearchCV(cv=ShuffleSplit(1742, n_iter=10, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'alpha': [0.0001, 0.01, 0.1, 1, 10, 100]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=10)

# %%
sorted(gs.grid_scores_,key=lambda x: x[1], reverse=True) #sorted grid scores
# Out:
# [mean: 0.62065, std: 0.01009, params: {'alpha': 0.0001},
#  mean: 0.62065, std: 0.01009, params: {'alpha': 0.01},
#  mean: 0.62065, std: 0.01009, params: {'alpha': 0.1},
#  mean: 0.62065, std: 0.01009, params: {'alpha': 1},
#  mean: 0.62046, std: 0.01048, params: {'alpha': 10},
#  mean: 0.61989, std: 0.01040, params: {'alpha': 100}]

# %%
print (gs.best_score_, gs.best_params_) #display best score and parameters
# Out:
# 0.620650095602 {'alpha': 0.0001}

# %% [markdown]
# ### Best MultinomialNB classifier achieved 62% accuracy
#
# ### We will not try BernoulliNB

# %%
cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

parameters = {'alpha': [0.0001, 0.01, 0.1, 1, 10, 100],
              'binarize': [0, 0.1, 0.3, 0.5, 1]}

# %%
from sklearn.naive_bayes import BernoulliNB

bnb = BernoulliNB()
gs = GridSearchCV(bnb, parameters, cv=cv, n_jobs=-1, verbose=10)

gs.fit(df[colX], df['MetalLevel'])
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] ............... binarize=0, alpha=0.0001, score=0.634799 -   0.1s
# [CV] ............... binarize=0, alpha=0.0001, score=0.646272 -   0.1s
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] ............... binarize=0, alpha=0.0001, score=0.657744 -   0.1s
# [CV] ............... binarize=0, alpha=0.0001, score=0.642447 -   0.1s
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] ............... binarize=0, alpha=0.0001, score=0.644359 -   0.1s
# [CV] ............... binarize=0, alpha=0.0001, score=0.625239 -   0.0s
# [CV] ............... binarize=0, alpha=0.0001, score=0.642447 -   0.0s
# [CV] ............... binarize=0, alpha=0.0001, score=0.657744 -   0.1s
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1078s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.3s
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.634799 -   0.0s
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] ............... binarize=0, alpha=0.0001, score=0.667304 -   0.0s
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.657744 -   0.0s
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.644359 -   0.0s
# [CV] binarize=0, alpha=0.0001 ........................................
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.642447 -   0.1s
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.646272 -   0.0s
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.625239 -   0.0s
# [CV] ............... binarize=0, alpha=0.0001, score=0.646272 -   0.0s
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.667304 -   0.0s
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.634799 -   0.0s
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.642447 -   0.0s
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] binarize=0.1, alpha=0.0001 ......................................
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.646272 -   0.0s
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.646272 -   0.0s
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.657744 -   0.0s
# [CV] ............. binarize=0.1, alpha=0.0001, score=0.642447 -   0.0s
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.657744 -   0.0s
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.667304 -   0.0s
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.644359 -   0.0s
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.634799 -   0.0s
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] binarize=0.3, alpha=0.0001 ......................................
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.642447 -   0.0s
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.657744 -   0.0s
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.625239 -   0.0s
# [CV] ............. binarize=0.3, alpha=0.0001, score=0.646272 -   0.0s
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.642447 -   0.0s
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.644359 -   0.0s
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.657744 -   0.0s
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.667304 -   0.0s
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.625239 -   0.0s
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.646272 -   0.0s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1971s.) Setting batch_size=4.
# [CV] binarize=0.5, alpha=0.0001 ......................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.642447 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] ............. binarize=0.5, alpha=0.0001, score=0.646272 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.512428 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.554493 -   0.0s
# [CV] ............... binarize=1, alpha=0.0001, score=0.560229 -   0.0s
# [CV] ............... binarize=1, alpha=0.0001, score=0.562141 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] ................. binarize=0, alpha=0.01, score=0.642447 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.537285 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.533461 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.564054 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] ................. binarize=0, alpha=0.01, score=0.646272 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.571702 -   0.0s
# [CV] ................. binarize=0, alpha=0.01, score=0.634799 -   0.0s
# [CV] binarize=1, alpha=0.0001 ........................................
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] ............... binarize=1, alpha=0.0001, score=0.533461 -   0.0s
# [CV] ................. binarize=0, alpha=0.01, score=0.644359 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] ................. binarize=0, alpha=0.01, score=0.657744 -   0.0s
# [CV] ............... binarize=1, alpha=0.0001, score=0.546845 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ................. binarize=0, alpha=0.01, score=0.657744 -   0.0s
# [CV] ................. binarize=0, alpha=0.01, score=0.625239 -   0.0s
# [CV] ............... binarize=0.1, alpha=0.01, score=0.634799 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ............... binarize=0.1, alpha=0.01, score=0.644359 -   0.0s
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ............... binarize=0.1, alpha=0.01, score=0.667304 -   0.0s
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ................. binarize=0, alpha=0.01, score=0.642447 -   0.0s
# [CV] ............... binarize=0.1, alpha=0.01, score=0.657744 -   0.0s
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] ............... binarize=0.1, alpha=0.01, score=0.625239 -   0.0s
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ............... binarize=0.1, alpha=0.01, score=0.646272 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ............... binarize=0.1, alpha=0.01, score=0.642447 -   0.0s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.7s
# [CV] ................. binarize=0, alpha=0.01, score=0.667304 -   0.0s
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ............... binarize=0.1, alpha=0.01, score=0.657744 -   0.0s
# [CV] binarize=0, alpha=0.01 ..........................................
# [CV] binarize=0.1, alpha=0.01 ........................................
# [CV] ............... binarize=0.3, alpha=0.01, score=0.634799 -   0.0s
# [CV] ............... binarize=0.1, alpha=0.01, score=0.646272 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ................. binarize=0, alpha=0.01, score=0.646272 -   0.0s
# [CV] ............... binarize=0.1, alpha=0.01, score=0.642447 -   0.0s
# [CV] ............... binarize=0.3, alpha=0.01, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] ............... binarize=0.3, alpha=0.01, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ............... binarize=0.3, alpha=0.01, score=0.642447 -   0.0s
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.634799 -   0.0s
# [CV] ............... binarize=0.3, alpha=0.01, score=0.642447 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] ............... binarize=0.3, alpha=0.01, score=0.646272 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.644359 -   0.0s
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.657744 -   0.0s
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] ............... binarize=0.3, alpha=0.01, score=0.667304 -   0.0s
# [CV] ............... binarize=0.3, alpha=0.01, score=0.644359 -   0.0s
# [CV] ............... binarize=0.5, alpha=0.01, score=0.625239 -   0.0s
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.642447 -   0.0s
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] binarize=0.3, alpha=0.01 ........................................
# [CV] ............... binarize=0.3, alpha=0.01, score=0.625239 -   0.0s
# [CV] ............... binarize=0.5, alpha=0.01, score=0.646272 -   0.0s
# [CV] ............... binarize=0.5, alpha=0.01, score=0.657744 -   0.0s
# [CV] ............... binarize=0.3, alpha=0.01, score=0.646272 -   0.0s
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.642447 -   0.0s
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.667304 -   0.0s
# [CV] ................. binarize=1, alpha=0.01, score=0.571702 -   0.0s
# [CV] binarize=0.5, alpha=0.01 ........................................
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] .................. binarize=0, alpha=0.1, score=0.634799 -   0.0s
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] ................. binarize=1, alpha=0.01, score=0.537285 -   0.0s
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] ................. binarize=1, alpha=0.01, score=0.546845 -   0.0s
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] ............... binarize=0.5, alpha=0.01, score=0.646272 -   0.0s
# [CV] .................. binarize=0, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] ................. binarize=1, alpha=0.01, score=0.554493 -   0.0s
# [CV] ................. binarize=1, alpha=0.01, score=0.533461 -   0.0s
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] .................. binarize=0, alpha=0.1, score=0.640535 -   0.0s
# [CV] ................. binarize=1, alpha=0.01, score=0.512428 -   0.0s
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] ................. binarize=1, alpha=0.01, score=0.564054 -   0.0s
# [CV] .................. binarize=0, alpha=0.1, score=0.646272 -   0.0s
# [CV] ................. binarize=1, alpha=0.01, score=0.562141 -   0.0s
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] binarize=1, alpha=0.01 ..........................................
# [CV] ................. binarize=1, alpha=0.01, score=0.560229 -   0.0s
# [CV] ................. binarize=1, alpha=0.01, score=0.533461 -   0.0s
# [CV] .................. binarize=0, alpha=0.1, score=0.644359 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.640535 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] .................. binarize=0, alpha=0.1, score=0.667304 -   0.0s
# [CV] .................. binarize=0, alpha=0.1, score=0.625239 -   0.0s
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.646272 -   0.0s
# [CV] ................ binarize=0.1, alpha=0.1, score=0.642447 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] .................. binarize=0, alpha=0.1, score=0.657744 -   0.0s
# [CV] .................. binarize=0, alpha=0.1, score=0.646272 -   0.0s
# [CV] binarize=0, alpha=0.1 ...........................................
# [CV] binarize=0.1, alpha=0.1 .........................................
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    1.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.667304 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.644359 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] .................. binarize=0, alpha=0.1, score=0.642447 -   0.0s
# [CV] ................ binarize=0.1, alpha=0.1, score=0.634799 -   0.0s
# [CV] binarize=0.1, alpha=0.1 .........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.646272 -   0.0s
# [CV] ................ binarize=0.1, alpha=0.1, score=0.625239 -   0.0s
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.1, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] ................ binarize=0.3, alpha=0.1, score=0.634799 -   0.0s
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.3, alpha=0.1, score=0.644359 -   0.0s
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.3, alpha=0.1, score=0.667304 -   0.0s
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.640535 -   0.0s
# [CV] ................ binarize=0.3, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.3, alpha=0.1, score=0.625239 -   0.0s
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.646272 -   0.0s
# [CV] ................ binarize=0.3, alpha=0.1, score=0.646272 -   0.0s
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] ................ binarize=0.3, alpha=0.1, score=0.640535 -   0.0s
# [CV] ................ binarize=0.3, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] binarize=0.3, alpha=0.1 .........................................
# [CV] ................ binarize=0.3, alpha=0.1, score=0.646272 -   0.0s
# [CV] ................ binarize=0.5, alpha=0.1, score=0.644359 -   0.0s
# [CV] ................ binarize=0.3, alpha=0.1, score=0.642447 -   0.0s
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.634799 -   0.0s
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.625239 -   0.0s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.657744 -   0.0s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] .................. binarize=1, alpha=0.1, score=0.510516 -   0.0s
# [CV] .................. binarize=1, alpha=0.1, score=0.562141 -   0.0s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.642447 -   0.0s
# [CV] .................. binarize=1, alpha=0.1, score=0.552581 -   0.0s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] .................. binarize=1, alpha=0.1, score=0.533461 -   0.0s
# [CV] .................. binarize=1, alpha=0.1, score=0.560229 -   0.0s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] .................. binarize=1, alpha=0.1, score=0.564054 -   0.0s
# [CV] binarize=0, alpha=1 .............................................
# [CV] .................. binarize=1, alpha=0.1, score=0.537285 -   0.0s
# [CV] ................ binarize=0.5, alpha=0.1, score=0.667304 -   0.0s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    1.3s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] binarize=0.5, alpha=0.1 .........................................
# [CV] .................. binarize=1, alpha=0.1, score=0.569790 -   0.0s
# [CV] binarize=1, alpha=0.1 ...........................................
# [CV] .................... binarize=0, alpha=1, score=0.634799 -   0.0s
# [CV] .................. binarize=1, alpha=0.1, score=0.533461 -   0.0s
# [CV] binarize=0, alpha=1 .............................................
# [CV] ................ binarize=0.5, alpha=0.1, score=0.646272 -   0.0s
# [CV] .................. binarize=1, alpha=0.1, score=0.546845 -   0.0s
# [CV] binarize=0, alpha=1 .............................................
# [CV] binarize=0, alpha=1 .............................................
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................... binarize=0, alpha=1, score=0.657744 -   0.0s
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................... binarize=0, alpha=1, score=0.657744 -   0.0s
# [CV] binarize=0, alpha=1 .............................................
# [CV] .................. binarize=0.1, alpha=1, score=0.634799 -   0.0s
# [CV] .................... binarize=0, alpha=1, score=0.646272 -   0.0s
# [CV] binarize=0, alpha=1 .............................................
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................. binarize=0.1, alpha=1, score=0.644359 -   0.0s
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................. binarize=0.1, alpha=1, score=0.657744 -   0.0s
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................. binarize=0.1, alpha=1, score=0.623327 -   0.0s
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................... binarize=0, alpha=1, score=0.650096 -   0.1s
# [CV] .................. binarize=0.1, alpha=1, score=0.646272 -   0.0s
# [CV] .................... binarize=0, alpha=1, score=0.642447 -   0.1s
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] binarize=0, alpha=1 .............................................
# [CV] binarize=0, alpha=1 .............................................
# [CV] .................. binarize=0.1, alpha=1, score=0.657744 -   0.1s
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] .................... binarize=0, alpha=1, score=0.669216 -   0.0s
# [CV] .................. binarize=0.1, alpha=1, score=0.650096 -   0.0s
# [CV] .................... binarize=0, alpha=1, score=0.644359 -   0.0s
# [CV] binarize=0, alpha=1 .............................................
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] binarize=0, alpha=1 .............................................
# [CV] .................. binarize=0.1, alpha=1, score=0.642447 -   0.0s
# [CV] .................... binarize=0, alpha=1, score=0.623327 -   0.0s
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] .................... binarize=0, alpha=1, score=0.646272 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................. binarize=0.3, alpha=1, score=0.657744 -   0.0s
# [CV] .................. binarize=0.1, alpha=1, score=0.669216 -   0.0s
# [CV] .................. binarize=0.3, alpha=1, score=0.646272 -   0.0s
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] binarize=0.1, alpha=1 ...........................................
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] .................. binarize=0.5, alpha=1, score=0.634799 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................. binarize=0.3, alpha=1, score=0.650096 -   0.0s
# [CV] .................. binarize=0.1, alpha=1, score=0.646272 -   0.0s
# [CV] .................. binarize=0.3, alpha=1, score=0.642447 -   0.0s
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] .................. binarize=0.5, alpha=1, score=0.657744 -   0.0s
# [CV] .................. binarize=0.3, alpha=1, score=0.634799 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................. binarize=0.3, alpha=1, score=0.669216 -   0.0s
# [CV] .................. binarize=0.3, alpha=1, score=0.644359 -   0.0s
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] binarize=0.3, alpha=1 ...........................................
# [CV] .................. binarize=0.3, alpha=1, score=0.646272 -   0.0s
# [CV] .................. binarize=0.5, alpha=1, score=0.646272 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................. binarize=0.3, alpha=1, score=0.657744 -   0.0s
# [CV] .................. binarize=0.3, alpha=1, score=0.623327 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................. binarize=0.5, alpha=1, score=0.650096 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................. binarize=0.5, alpha=1, score=0.644359 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................... binarize=1, alpha=1, score=0.537285 -   0.0s
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................. binarize=0.5, alpha=1, score=0.669216 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:    1.7s
# [CV] .................. binarize=0.5, alpha=1, score=0.623327 -   0.0s
# [CV] .................... binarize=1, alpha=1, score=0.569790 -   0.0s
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................. binarize=0.5, alpha=1, score=0.646272 -   0.0s
# [CV] .................... binarize=1, alpha=1, score=0.533461 -   0.0s
# [CV] binarize=1, alpha=1 .............................................
# [CV] binarize=1, alpha=1 .............................................
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................... binarize=1, alpha=1, score=0.510516 -   0.0s
# [CV] .................. binarize=0.5, alpha=1, score=0.657744 -   0.0s
# [CV] binarize=1, alpha=1 .............................................
# [CV] binarize=0.5, alpha=1 ...........................................
# [CV] .................... binarize=1, alpha=1, score=0.546845 -   0.0s
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................. binarize=0.5, alpha=1, score=0.642447 -   0.0s
# [CV] .................... binarize=1, alpha=1, score=0.531549 -   0.0s
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................... binarize=1, alpha=1, score=0.560229 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] .................... binarize=1, alpha=1, score=0.552581 -   0.0s
# [CV] binarize=1, alpha=1 .............................................
# [CV] .................... binarize=1, alpha=1, score=0.533461 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] binarize=0, alpha=10 ............................................
# [CV] ................... binarize=0, alpha=10, score=0.636711 -   0.0s
# [CV] .................... binarize=1, alpha=1, score=0.564054 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] ................... binarize=0, alpha=10, score=0.646272 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................... binarize=0, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] ................... binarize=0, alpha=10, score=0.629063 -   0.0s
# [CV] ................. binarize=0.1, alpha=10, score=0.648184 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................... binarize=0, alpha=10, score=0.669216 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] ................... binarize=0, alpha=10, score=0.648184 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] ................. binarize=0.1, alpha=10, score=0.650096 -   0.0s
# [CV] ................... binarize=0, alpha=10, score=0.648184 -   0.0s
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................... binarize=0, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0, alpha=10 ............................................
# [CV] ................... binarize=0, alpha=10, score=0.650096 -   0.0s
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................. binarize=0.1, alpha=10, score=0.636711 -   0.0s
# [CV] ................. binarize=0.1, alpha=10, score=0.646272 -   0.0s
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................... binarize=0, alpha=10, score=0.642447 -   0.0s
# [CV] ................. binarize=0.1, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................. binarize=0.1, alpha=10, score=0.629063 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.1, alpha=10, score=0.657744 -   0.0s
# [CV] ................. binarize=0.1, alpha=10, score=0.642447 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.636711 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.646272 -   0.0s
# [CV] ................. binarize=0.3, alpha=10, score=0.669216 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.1, alpha=10, score=0.669216 -   0.0s
# [CV] binarize=0.1, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.648184 -   0.0s
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.629063 -   0.0s
# [CV] ................. binarize=0.3, alpha=10, score=0.648184 -   0.0s
# [CV] ................. binarize=0.1, alpha=10, score=0.648184 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:    2.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.5, alpha=10, score=0.636711 -   0.0s
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0.3, alpha=10 ..........................................
# [CV] ................. binarize=0.5, alpha=10, score=0.648184 -   0.0s
# [CV] ................. binarize=0.3, alpha=10, score=0.650096 -   0.0s
# [CV] ................. binarize=0.5, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] ................. binarize=0.3, alpha=10, score=0.642447 -   0.0s
# [CV] ................. binarize=0.5, alpha=10, score=0.650096 -   0.0s
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] binarize=1, alpha=10 ............................................
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................. binarize=0.5, alpha=10, score=0.657744 -   0.0s
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] ................... binarize=1, alpha=10, score=0.510516 -   0.0s
# [CV] ................. binarize=0.5, alpha=10, score=0.646272 -   0.0s
# [CV] binarize=1, alpha=10 ............................................
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] ................. binarize=0.5, alpha=10, score=0.642447 -   0.0s
# [CV] ................... binarize=1, alpha=10, score=0.531549 -   0.0s
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................... binarize=1, alpha=10, score=0.535373 -   0.0s
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................... binarize=1, alpha=10, score=0.550669 -   0.0s
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................... binarize=1, alpha=10, score=0.533461 -   0.1s
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................. binarize=0.5, alpha=10, score=0.629063 -   0.1s
# [CV] ................. binarize=0.5, alpha=10, score=0.669216 -   0.1s
# [CV] ................... binarize=1, alpha=10, score=0.546845 -   0.0s
# [CV] binarize=1, alpha=10 ............................................
# [CV] binarize=0.5, alpha=10 ..........................................
# [CV] ................... binarize=1, alpha=10, score=0.533461 -   0.0s
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................. binarize=0.5, alpha=10, score=0.648184 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] ................... binarize=1, alpha=10, score=0.558317 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] binarize=1, alpha=10 ............................................
# [CV] ................... binarize=1, alpha=10, score=0.558317 -   0.0s
# [CV] .................. binarize=0, alpha=100, score=0.648184 -   0.0s
# [CV] .................. binarize=0, alpha=100, score=0.655832 -   0.0s
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] ................... binarize=1, alpha=10, score=0.546845 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] binarize=0, alpha=100 ...........................................
# [CV] binarize=0, alpha=100 ...........................................
# [CV] .................. binarize=0, alpha=100, score=0.565966 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] .................. binarize=0, alpha=100, score=0.646272 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] .................. binarize=0, alpha=100, score=0.640535 -   0.0s
# [CV] ................ binarize=0.1, alpha=100, score=0.565966 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] .................. binarize=0, alpha=100, score=0.655832 -   0.0s
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] .................. binarize=0, alpha=100, score=0.617591 -   0.0s
# [CV] binarize=0, alpha=100 ...........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.655832 -   0.0s
# [CV] .................. binarize=0, alpha=100, score=0.667304 -   0.0s
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] binarize=0, alpha=100 ...........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.617591 -   0.0s
# [CV] .................. binarize=0, alpha=100, score=0.627151 -   0.0s
# [CV] ................ binarize=0.1, alpha=100, score=0.648184 -   0.0s
# [CV] .................. binarize=0, alpha=100, score=0.652008 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.667304 -   0.0s
# [CV] ................ binarize=0.1, alpha=100, score=0.627151 -   0.0s
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] ................ binarize=0.3, alpha=100, score=0.648184 -   0.0s
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.646272 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.655832 -   0.0s
# [CV] binarize=0.1, alpha=100 .........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.652008 -   0.0s
# [CV] ................ binarize=0.3, alpha=100, score=0.655832 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] ................ binarize=0.3, alpha=100, score=0.646272 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] ................ binarize=0.1, alpha=100, score=0.640535 -   0.0s
# [CV] ................ binarize=0.3, alpha=100, score=0.640535 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] ................ binarize=0.3, alpha=100, score=0.565966 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] ................ binarize=0.3, alpha=100, score=0.617591 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] ................ binarize=0.3, alpha=100, score=0.667304 -   0.0s
# [CV] binarize=0.3, alpha=100 .........................................
# [CV] ................ binarize=0.3, alpha=100, score=0.627151 -   0.0s
# [CV] ................ binarize=0.3, alpha=100, score=0.655832 -   0.0s
# [CV] ................ binarize=0.5, alpha=100, score=0.565966 -   0.0s
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] ................ binarize=0.5, alpha=100, score=0.617591 -   0.0s
# [CV] ................ binarize=0.3, alpha=100, score=0.652008 -   0.0s
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] ................ binarize=0.5, alpha=100, score=0.655832 -   0.0s
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] ................ binarize=0.5, alpha=100, score=0.667304 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.6s
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] ................ binarize=0.5, alpha=100, score=0.627151 -   0.0s
# [CV] ................ binarize=0.5, alpha=100, score=0.648184 -   0.0s
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] .................. binarize=1, alpha=100, score=0.554493 -   0.0s
# [CV] ................ binarize=0.5, alpha=100, score=0.652008 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] binarize=1, alpha=100 ...........................................
# [CV] ................ binarize=0.5, alpha=100, score=0.646272 -   0.0s
# [CV] ................ binarize=0.5, alpha=100, score=0.655832 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] .................. binarize=1, alpha=100, score=0.510516 -   0.0s
# [CV] .................. binarize=1, alpha=100, score=0.564054 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] binarize=1, alpha=100 ...........................................
# [CV] binarize=0.5, alpha=100 .........................................
# [CV] .................. binarize=1, alpha=100, score=0.546845 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] .................. binarize=1, alpha=100, score=0.535373 -   0.0s
# [CV] .................. binarize=1, alpha=100, score=0.533461 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] ................ binarize=0.5, alpha=100, score=0.640535 -   0.0s
# [CV] .................. binarize=1, alpha=100, score=0.558317 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] .................. binarize=1, alpha=100, score=0.533461 -   0.0s
# [CV] .................. binarize=1, alpha=100, score=0.558317 -   0.0s
# [CV] binarize=1, alpha=100 ...........................................
# [CV] .................. binarize=1, alpha=100, score=0.546845 -   0.0s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    2.9s finished
# GridSearchCV(cv=ShuffleSplit(1742, n_iter=10, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'binarize': [0, 0.1, 0.3, 0.5, 1], 'alpha': [0.0001, 0.01, 0.1, 1, 10, 100]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=10)

# %%
sorted(gs.grid_scores_,key=lambda x: x[1], reverse=True) #sorted scores
# Out:
# [mean: 0.64857, std: 0.01078, params: {'binarize': 0, 'alpha': 10},
#  mean: 0.64857, std: 0.01078, params: {'binarize': 0.1, 'alpha': 10},
#  mean: 0.64857, std: 0.01078, params: {'binarize': 0.3, 'alpha': 10},
#  mean: 0.64857, std: 0.01078, params: {'binarize': 0.5, 'alpha': 10},
#  mean: 0.64723, std: 0.01213, params: {'binarize': 0, 'alpha': 1},
#  mean: 0.64723, std: 0.01213, params: {'binarize': 0.1, 'alpha': 1},
#  mean: 0.64723, std: 0.01213, params: {'binarize': 0.3, 'alpha': 1},
#  mean: 0.64723, std: 0.01213, params: {'binarize': 0.5, 'alpha': 1},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0, 'alpha': 0.0001},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0.1, 'alpha': 0.0001},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0.3, 'alpha': 0.0001},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0.5, 'alpha': 0.0001},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0, 'alpha': 0.01},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0.1, 'alpha': 0.01},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0.3, 'alpha': 0.01},
#  mean: 0.64646, std: 0.01145, params: {'binarize': 0.5, 'alpha': 0.01},
#  mean: 0.64627, std: 0.01154, params: {'binarize': 0, 'alpha': 0.1},
#  mean: 0.64627, std: 0.01154, params: {'binarize': 0.1, 'alpha': 0.1},
#  mean: 0.64627, std: 0.01154, params: {'binarize': 0.3, 'alpha': 0.1},
#  mean: 0.64627, std: 0.01154, params: {'binarize': 0.5, 'alpha': 0.1},
#  mean: 0.63767, std: 0.02755, params: {'binarize': 0, 'alpha': 100},
#  mean: 0.63767, std: 0.02755, params: {'binarize': 0.1, 'alpha': 100},
#  mean: 0.63767, std: 0.02755, params: {'binarize': 0.3, 'alpha': 100},
#  mean: 0.63767, std: 0.02755, params: {'binarize': 0.5, 'alpha': 100},
#  mean: 0.54761, std: 0.01736, params: {'binarize': 1, 'alpha': 0.0001},
#  mean: 0.54761, std: 0.01736, params: {'binarize': 1, 'alpha': 0.01},
#  mean: 0.54704, std: 0.01743, params: {'binarize': 1, 'alpha': 0.1},
#  mean: 0.54417, std: 0.01535, params: {'binarize': 1, 'alpha': 100},
#  mean: 0.54398, std: 0.01719, params: {'binarize': 1, 'alpha': 1},
#  mean: 0.54054, std: 0.01387, params: {'binarize': 1, 'alpha': 10}]

# %%
print (gs.best_score_, gs.best_params_)
# Out:
# 0.648565965583 {'binarize': 0, 'alpha': 10}

# %% [markdown]
# ### Best BernoulliNB classifier achieved 64.8%
#
# ### We will now try kNN

# %%
cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

parameters = {'n_jobs': [-1],
              'n_neighbors': [1, 3, 5, 7, 9], #we will focus on odd neighbors to break possible ties
              'weights': ['uniform', 'distance'],
              'metric': ['euclidean', 'minkowski']}

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
gs = GridSearchCV(knn, parameters, cv=cv, n_jobs=-1, verbose=10)

gs.fit(df[colX], df['MetalLevel'])
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.990440 -   0.2s
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.990440 -   0.2s
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.988528 -   0.2s
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.990440 -   0.2s
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.990440 -   0.2s
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1995s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.4s
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.978967 -   0.1s
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.988528 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.996176 -   0.2s
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.982792 -   0.1s
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.996176 -   0.1s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.963671 -   0.1s
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.7s
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.977055 -   0.1s
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.982792 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.986616 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.952199 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.984704 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.965583 -   0.1s
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.977055 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.980880 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.992352 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.982792 -   0.1s
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.961759 -   0.1s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.2s
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.982792 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.946463 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.954111 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.961759 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.923518 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.959847 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.5s
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.942639 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.936902 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.986616 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.988528 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.942639 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.957935 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.921606 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.963671 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.944551 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.931166 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.913958 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.927342 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    2.1s
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.977055 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.915870 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.934990 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.927342 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.980880 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.948375 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.973231 -   0.1s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.961759 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.944551 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.957935 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.913958 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.942639 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.944551 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.908222 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.938815 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    2.6s
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.921606 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.915870 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.915870 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.925430 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.913958 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.969407 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.940727 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.940727 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.988528 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.959847 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.996176 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    3.3s
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.988528 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.982792 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.996176 -   0.1s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.990440 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.982792 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.978967 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.963671 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.986616 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.952199 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.977055 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    3.9s
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.984704 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.980880 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.992352 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.977055 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.982792 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.961759 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.982792 -   0.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.946463 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.954111 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.959847 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.961759 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.923518 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.936902 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.986616 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.942639 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.942639 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.988528 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    4.7s
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.975143 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.957935 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.963671 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.921606 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.950287 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.913958 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.944551 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.931166 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.915870 -   0.1s
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.934990 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.927342 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.977055 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.980880 -   0.1s
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.927342 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.961759 -   0.1s
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.944551 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.948375 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.973231 -   0.1s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.942639 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.913958 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:    5.5s
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.957935 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.956023 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.921606 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.938815 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.944551 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.908222 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.925430 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.915870 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.915870 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.969407 -   0.1s
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.913958 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.971319 -   0.1s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.967495 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.940727 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.965583 -   0.1s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.940727 -   0.1s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.956023 -   0.1s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.959847 -   0.1s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.950287 -   0.1s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    6.3s finished
# GridSearchCV(cv=ShuffleSplit(1742, n_iter=10, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'minkowski'], 'n_neighbors': [1, 3, 5, 7, 9], 'n_jobs': [-1]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=10)

# %%
sorted(gs.grid_scores_,key=lambda x: x[1], reverse=True)
# Out:
# [mean: 0.98623, std: 0.00644, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.98623, std: 0.00644, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.98623, std: 0.00644, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.98623, std: 0.00644, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.97706, std: 0.00913, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.97706, std: 0.00913, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.97151, std: 0.01038, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.97151, std: 0.01038, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.96845, std: 0.00991, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.96845, std: 0.00991, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.96386, std: 0.01155, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.96386, std: 0.01155, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.95927, std: 0.01131, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 9, 'n_jobs': -1},
#  mean: 0.95927, std: 0.01131, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 9, 'n_jobs': -1},
#  mean: 0.94685, std: 0.01071, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.94685, std: 0.01071, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.93174, std: 0.01254, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.93174, std: 0.01254, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.92409, std: 0.01257, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 9, 'n_jobs': -1},
#  mean: 0.92409, std: 0.01257, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 9, 'n_jobs': -1}]

# %%
print (gs.best_score_, gs.best_params_)
# Out:
# 0.986233269598 {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 1, 'n_jobs': -1}

# %% [markdown]
# ## The highest average accuracy of the K Nearest Neighbor model is 98.6% with a euclidean metric, n_neighbors of 1, and uniform weights.¶
# ## We will now run a kNN model with the best parameters and apply them to the full data set.
# ## We will then obtain the accuracy score and plot the confusion matrix.

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

gs_model = KNeighborsClassifier(metric = gs.best_params_['metric'],
                                 n_neighbors = gs.best_params_['n_neighbors'],
                                 weights = gs.best_params_['weights'],
                                   n_jobs=-1)

gs_model.fit(X_train,y_train)
predictions = gs_model.predict(X_test)

# %%
cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

CVscores = cross_val_score(gs_model, df[colX], df['MetalLevel'], cv=cv)
print("CV Accuracy: %0.3f (+/- %0.3f)" % (CVscores.mean(), CVscores.std() * 1.96)) #95% confidence interval

labels = ['Low','High']
conf = confusion_matrix(y_test,predictions,labels)
acc = accuracy_score(y_test,predictions)

print ('Train/Test Accuracy:', acc, '\n')
print ('Confusion Matrix:')
print (conf)

plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf, 
                      title='        MetalLevel Prediction using KNN\n',
                      labels=labels)
# Out:
# CV Accuracy: 0.986 (+/- 0.013)
# Train/Test Accuracy: 0.988527724665
#
# Confusion Matrix:
# [[252   4]
#  [  2 265]]

# %% [markdown]
# For classification task 1, the K Nearest Neighbor model obtained an accuracy score of ~99%. However, we wish to optimize a linear classifier as well since it is easier to interpret the weights for the model vs kNN.
#
# We will now attempt a Stochastic Gradient Descent model with a 70/30 split and 10 iterations for cross validation. The seed remains at 42.
#
# ## SGDClassifier

# %%
cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

parameters = {'alpha': [0.0001, 0.01, 0.1, 1, 10, 100], 
              'loss':['hinge','log','modified_huber','squared_hinge','perceptron'], 
              'penalty' : ['l2','l1','elasticnet'], 
              'class_weight': ['balanced']}

# %% [markdown]
# We seperate out the continuous variables for scaling.  Once scaling is complete, the continuous variables are added back to the independent variable X.

# %%
sgd = SGDClassifier(n_jobs=-1)
gs = GridSearchCV(sgd, parameters, cv=cv)

scl_obj = StandardScaler()
scl_obj.fit(df[continuous])

X = scl_obj.transform(df[continuous])

X = pd.DataFrame(data = X, index = df[continuous].index, columns=continuous)

X = pd.concat([X,df[categorical]], axis=1)

gs.fit(X, df['MetalLevel'])
# Out:
# GridSearchCV(cv=ShuffleSplit(1742, n_iter=10, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=-1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'class_weight': ['balanced'], 'penalty': ['l2', 'l1', 'elasticnet'], 'loss': ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'], 'alpha': [0.0001, 0.01, 0.1, 1, 10, 100]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
sorted(gs.grid_scores_,key=lambda x: x[1], reverse=True)
# Out:
# [mean: 1.00000, std: 0.00000, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 1.00000, std: 0.00000, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.99885, std: 0.00344, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.99713, std: 0.00588, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.95335, std: 0.13996, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.84990, std: 0.22175, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.84226, std: 0.22648, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.84207, std: 0.23560, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.80631, std: 0.23212, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.79713, std: 0.22381, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.78948, std: 0.23766, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.67763, std: 0.19498, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.65449, std: 0.22291, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.63423, std: 0.24150, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.57304, std: 0.20840, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.56750, std: 0.14979, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.56061, std: 0.12494, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.54723, std: 0.16087, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.54034, std: 0.13504, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.53939, std: 0.13115, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.53939, std: 0.09950, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.53078, std: 0.03558, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.52925, std: 0.16196, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.52677, std: 0.03762, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.52620, std: 0.03908, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.52581, std: 0.03933, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.52428, std: 0.12397, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.52294, std: 0.03994, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.52218, std: 0.05191, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.52084, std: 0.04218, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.51893, std: 0.04360, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.51759, std: 0.03880, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.51644, std: 0.04040, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.51530, std: 0.04449, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.51396, std: 0.04493, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.51396, std: 0.04493, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.51338, std: 0.04510, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.51243, std: 0.04538, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.51166, std: 0.04357, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.51090, std: 0.04468, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.50937, std: 0.04611, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.50937, std: 0.04068, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.50918, std: 0.04513, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.50803, std: 0.04652, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.50784, std: 0.04044, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.50784, std: 0.04639, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.50765, std: 0.04642, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.50727, std: 0.04648, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.50707, std: 0.04651, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.50707, std: 0.04651, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.50688, std: 0.04654, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.50421, std: 0.04686, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.50306, std: 0.04695, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.50268, std: 0.04697, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.50249, std: 0.04698, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.50229, std: 0.04699, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.50210, std: 0.04700, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.50172, std: 0.04702, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.50153, std: 0.04702, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.50134, std: 0.04451, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.50134, std: 0.04075, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.50096, std: 0.04262, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.50096, std: 0.04704, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.49962, std: 0.05195, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.49962, std: 0.04705, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.49885, std: 0.04703, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.49866, std: 0.04313, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.49847, std: 0.04138, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.49732, std: 0.04697, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.49732, std: 0.04697, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.49579, std: 0.04387, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.49560, std: 0.04684, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.49484, std: 0.04588, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.49446, std: 0.04672, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.49407, std: 0.04226, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.49331, std: 0.04536, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.48891, std: 0.04449, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.48834, std: 0.03877, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.48681, std: 0.04253, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.48585, std: 0.04487, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.48547, std: 0.04475, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.48432, std: 0.03791, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.48279, std: 0.04379, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.47801, std: 0.04159, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.47763, std: 0.04139, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.47686, std: 0.03962, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.47610, std: 0.04391, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.47342, std: 0.03592, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.47228, std: 0.03470, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.46214, std: 0.02793, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 10}]

# %%
print (gs.best_score_, gs.best_params_)
# Out:
# 1.0 {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.1}

# %% [markdown]
# The highest average accuracy of the SGD model is 100% with a balanced class weight, a log and hinge loss, alpha equal to 0.1 and a penalty of 11.
#
# We will apply the best parameters to the full data to see the model perform.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df['MetalLevel'], 
                                                    test_size=0.30, random_state=42)

# %%
cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

# %%
gs_sgd = SGDClassifier(alpha=gs.best_params_['alpha'], 
                       loss=gs.best_params_['loss'], 
                       penalty=gs.best_params_['penalty'], 
                       class_weight=gs.best_params_['class_weight'])

CVscores = cross_val_score(gs_sgd, X, df['MetalLevel'], cv=cv)
print("Accuracy: %0.3f (+/- %0.3f)" % (CVscores.mean(), CVscores.std() * 1.96))

gs_sgd.fit(X_train, y_train)
yhat = gs_sgd.predict(X_test)

labels = ['Low','High']
conf = confusion_matrix(y_test, yhat, labels)
acc = accuracy_score(y_test, yhat)

print (conf)
print (acc)
# Out:
# Accuracy: 1.000 (+/- 0.000)
# [[256   0]
#  [  0 267]]
# 1.0

# %% [markdown]
# As can be seen above, when the best parameters are applied to the full data set, the 100% accuracy is still achieved.
#
# We will plot the independent variables that have the most influence on our dependent variable.

# %%
plt.figure(figsize=(10, 8))
weights = pd.Series(abs(gs_sgd.coef_[0]),index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %% [markdown]
# Below is a histogram of the IssuerActuarialValue. It is clear that it alone, can adequately distinguish the Metal Levels. The data dictionary points out that a plan is given an actuarial value based on its properties.

# %%
df.IssuerActuarialValue.hist(bins=40)

# %% [markdown]
# ## Classification Task 2: Multi-class Classification of Metal Levels

# %%
#Resetting dataframe
df = df_join_RA

# %% [markdown]
# For the multi-class classification, we will exclude the 'Family Option' from the dataset as we covered this in the previous classification task. There are 5 Metal Levels associated with Individual Health Plans.
#
# In the data dictionary, we also discovered that we can eliminate dental only plans for this task and we also do not wish to include small business options.
#
# We will only focus on Individual Plans here. Due to processing times, we will only focus on plans from 2016, which gives us a ~300K dataset

# %%
df = df[df['Age'] != 66] #Removing the 'FamilyOption' designated by Age = 66
df = df[df['DentalOnlyPlan'] == 0] # Not a Dental Plan Only = 0, DentalOnlyPlan = 1
df = df[df['MarketCoverage'] == 0] # Individual = 0, Small Group = 1
df = df[df['BusinessYear'] == 2016] #limiting the dataset size to 2016 plans

# %%
df.shape
# Out:
# (311282, 149)

# %%
df.groupby('MetalLevel')['key','BusinessYear'].count()
# Out:
#                  key  BusinessYear
# MetalLevel
# Bronze         60858         60858
# Catastrophic    5198          5198
# Gold           39744         39744
# Platinum        7452          7452
# Silver        198030        198030

# %% [markdown]
# The attributes below may be one-hot encoded.

# %%
df.groupby('PlanType')['key','BusinessYear'].count()
# Out:
#              key  BusinessYear
# PlanType
# EPO        70932         70932
# HMO       208334        208334
# POS        14628         14628
# PPO        17388         17388

# %%
df.groupby('QHPNonQHPTypeId')['key','BusinessYear'].count()
# Out:
#                     key  BusinessYear
# QHPNonQHPTypeId
# Both             297298        297298
# On the Exchange   13984         13984

# %%
tmp_df = pd.get_dummies(df.PlanType,prefix='PlanType')
df = pd.concat((df,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(df.QHPNonQHPTypeId,prefix='QHP')
df = pd.concat((df,tmp_df),axis=1) # add back into the dataframe

# %%
#Renaming a few columns for brevity
df = df.rename(columns = {'BeginPrimaryCareCostSharingAfterNumberOfVisits':'BeginCostSharingAfterNumberOfVisits'})
df = df.rename(columns = {'BeginPrimaryCareDeductibleCoinsuranceAfterNumberOfCopays':'BeginDedCoinsAfterNumberOfCopays'})
df = df.rename(columns = {'EHBPediatricDentalApportionmentQuantity':'PediatricDentalApportionmentQty'})
df = df.rename(columns = {'InpatientCopaymentMaximumDays':'InpatientCopayMaxDays'})

# %% [markdown]
# As we can see in the summary below, a high number of missing values remain. We will move forward with attributes that contain no null values and attributes that have at least 50% of values available. The choice of 50% is a lower bound that the team felt was acceptable for imputing. Generally, we observed poor/biased distributions when we imputed attributes with less than 50% available data.

# %%
#Data Summary by Column, Null v Not Null Counts
print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format('Data Type','   Null', 'Not Null', 'Not Null %','','Column Name'))
for column in df.columns:
    print ('{0!s:8} {1:8} {2:8} {3:8} {4:4} {5:8}'.format(df[column].dtype,
                                                         df[column].isnull().sum(), 
                                                         df[column].notnull().sum(),
                                                         round(df[column].notnull().sum()/df[column].notnull().count(),3),
                                                         ' ',column))
# Out:
# Data Type    Null  Not Null Not Null %      Column Name
# int64           0   311282      1.0      BusinessYear
# object          0   311282      1.0      StateCode
# int64           0   311282      1.0      IssuerId
# object          0   311282      1.0      PlanId
# int64           0   311282      1.0      Tobacco
# float64         0   311282      1.0      Age
# float64         0   311282      1.0      IndividualRate
# float64     11316   299966    0.964      IndividualTobaccoRate
# float64    311282        0      0.0      PrimarySubscriberAndOneDependent
# float64    311282        0      0.0      PrimarySubscriberAndTwoDependents
# float64    311282        0      0.0      PrimarySubscriberAndThreeOrMoreDependents
# float64    311282        0      0.0      Couple
# float64    311282        0      0.0      CoupleAndOneDependent
# float64    311282        0      0.0      CoupleAndTwoDependents
# float64    311282        0      0.0      CoupleAndThreeOrMoreDependents
# object          0   311282      1.0      key
# float64    311282        0      0.0      AVCalculatorOutputNumber
# float64         0   311282      1.0      BeginCostSharingAfterNumberOfVisits
# float64         0   311282      1.0      BeginDedCoinsAfterNumberOfCopays
# float64         0   311282      1.0      ChildOnlyOffering
# float64         0   311282      1.0      CompositeRatingOffered
# float64         0   311282      1.0      DentalOnlyPlan
# float64    311282        0      0.0      PediatricDentalApportionmentQty
# float64    311282        0      0.0      EHBPercentPremiumS4
# float64         0   311282      1.0      EHBPercentTotalPremium
# float64         0   311282      1.0      FirstTierUtilization
# float64    311282        0      0.0      HSAOrHRAEmployerContribution
# float64    311282        0      0.0      HSAOrHRAEmployerContributionAmount
# float64         0   311282      1.0      InpatientCopayMaxDays
# float64    311282        0      0.0      IsGuaranteedRate
# float64         0   311282      1.0      IsHSAEligible
# float64         0   311282      1.0      IsNewPlan
# float64         0   311282      1.0      IsNoticeRequiredForPregnancy
# float64         0   311282      1.0      IsReferralRequiredForSpecialist
# float64    169786   141496    0.455      IssuerActuarialValue
# float64         0   311282      1.0      MarketCoverage
# float64         0   311282      1.0      MedicalDrugDeductiblesIntegrated
# float64         0   311282      1.0      MedicalDrugMaximumOutofPocketIntegrated
# object          0   311282      1.0      MetalLevel
# float64         0   311282      1.0      MultipleInNetworkTiers
# float64         0   311282      1.0      NationalNetwork
# float64         0   311282      1.0      OutOfCountryCoverage
# float64         0   311282      1.0      OutOfServiceAreaCoverage
# object          0   311282      1.0      PlanType
# object          0   311282      1.0      QHPNonQHPTypeId
# float64    270112    41170    0.132      SecondTierUtilization
# object          0   311282      1.0      StandardComponentId
# float64         0   311282      1.0      UniquePlanDesign
# float64         0   311282      1.0      WellnessProgramOffered
# float64    177974   133308    0.428      DEHBDedInnTier1Coinsurance
# float64    305992     5290    0.017      DEHBDedInnTier2Coinsurance
# float64    177974   133308    0.428      MEHBDedInnTier1Coinsurance
# float64    305992     5290    0.017      MEHBDedInnTier2Coinsurance
# float64         0   311282      1.0      SBCHavingDiabetesCoinsurance
# float64         0   311282      1.0      SBCHavingaBabyCoinsurance
# float64    278484    32798    0.105      SpecialtyDrugMaximumCoinsurance
# float64    133308   177974    0.572      TEHBDedInnTier1Coinsurance
# float64    275402    35880    0.115      TEHBDedInnTier2Coinsurance
# float64    311282        0      0.0      DEHBCombInnOonIndividualMOOP
# float64    286580    24702    0.079      DEHBDedCombInnOonIndividual
# float64    177974   133308    0.428      DEHBDedInnTier1Individual
# float64    305992     5290    0.017      DEHBDedInnTier2Individual
# float64    297252    14030    0.045      DEHBDedOutOfNetIndividual
# float64    311282        0      0.0      DEHBInnTier1IndividualMOOP
# float64    311282        0      0.0      DEHBOutOfNetIndividualMOOP
# float64    311282        0      0.0      MEHBCombInnOonIndividualMOOP
# float64    284188    27094    0.087      MEHBDedCombInnOonIndividual
# float64    177974   133308    0.428      MEHBDedInnTier1Individual
# float64    305992     5290    0.017      MEHBDedInnTier2Individual
# float64    291364    19918    0.064      MEHBDedOutOfNetIndividual
# float64    311282        0      0.0      MEHBInnTier1IndividualMOOP
# float64    311282        0      0.0      MEHBInnTier2IndividualMOOP
# float64    311282        0      0.0      MEHBOutOfNetIndividualMOOP
# float64    243156    68126    0.219      TEHBCombInnOonIndividualMOOP
# float64    268916    42366    0.136      TEHBDedCombInnOonIndividual
# float64    133308   177974    0.572      TEHBDedInnTier1Individual
# float64    275402    35880    0.115      TEHBDedInnTier2Individual
# float64    248676    62606    0.201      TEHBDedOutOfNetIndividual
# float64         0   311282      1.0      TEHBInnTier1IndividualMOOP
# float64    270112    41170    0.132      TEHBInnTier2IndividualMOOP
# float64    251298    59984    0.193      TEHBOutOfNetIndividualMOOP
# float64    311282        0      0.0      DEHBCombInnOonFamilyMOOP
# float64    311282        0      0.0      DEHBDedCombInnOonFamily
# float64    286580    24702    0.079      DEHBDedCombInnOonFamilyPerGroup
# float64    286580    24702    0.079      DEHBDedCombInnOonFamilyPerPerson
# float64    311282        0      0.0      DEHBDedInnTier1Family
# float64    198030   113252    0.364      DEHBDedInnTier1FamilyPerGroup
# float64    181562   129720    0.417      DEHBDedInnTier1FamilyPerPerson
# float64    305992     5290    0.017      DEHBDedInnTier2FamilyPerGroup
# float64    305992     5290    0.017      DEHBDedInnTier2FamilyPerPerson
# float64    311282        0      0.0      DEHBDedOutOfNetFamily
# float64    297252    14030    0.045      DEHBDedOutOfNetFamilyPerGroup
# float64    297252    14030    0.045      DEHBDedOutOfNetFamilyPerPerson
# float64    311282        0      0.0      DEHBInnTier1FamilyMOOP
# float64    311282        0      0.0      DEHBOutOfNetFamilyMOOP
# float64    311282        0      0.0      MEHBCombInnOonFamilyMOOP
# float64    311282        0      0.0      MEHBCombInnOonFamilyPerGroupMOOP
# float64    311282        0      0.0      MEHBCombInnOonFamilyPerPersonMOOP
# float64    311282        0      0.0      MEHBDedCombInnOonFamily
# float64    285660    25622    0.082      MEHBDedCombInnOonFamilyPerGroup
# float64    285660    25622    0.082      MEHBDedCombInnOonFamilyPerPerson
# float64    311282        0      0.0      MEHBDedInnTier1Family
# float64    179446   131836    0.424      MEHBDedInnTier1FamilyPerGroup
# float64    179446   131836    0.424      MEHBDedInnTier1FamilyPerPerson
# float64    311282        0      0.0      MEHBDedInnTier2Family
# float64    305992     5290    0.017      MEHBDedInnTier2FamilyPerGroup
# float64    305992     5290    0.017      MEHBDedInnTier2FamilyPerPerson
# float64    311282        0      0.0      MEHBDedOutOfNetFamily
# float64    291364    19918    0.064      MEHBDedOutOfNetFamilyPerGroup
# float64    291364    19918    0.064      MEHBDedOutOfNetFamilyPerPerson
# float64    311282        0      0.0      MEHBInnTier1FamilyMOOP
# float64    311282        0      0.0      MEHBInnTier1FamilyPerGroupMOOP
# float64    311282        0      0.0      MEHBInnTier1FamilyPerPersonMOOP
# float64    311282        0      0.0      MEHBInnTier2FamilyMOOP
# float64    311282        0      0.0      MEHBInnTier2FamilyPerGroupMOOP
# float64    311282        0      0.0      MEHBInnTier2FamilyPerPersonMOOP
# float64    311282        0      0.0      MEHBOutOfNetFamilyMOOP
# float64    311282        0      0.0      MEHBOutOfNetFamilyPerGroupMOOP
# float64    311282        0      0.0      MEHBOutOfNetFamilyPerPersonMOOP
# float64    311282        0      0.0      TEHBCombInnOonFamilyMOOP
# float64    243156    68126    0.219      TEHBCombInnOonFamilyPerGroupMOOP
# float64    243156    68126    0.219      TEHBCombInnOonFamilyPerPersonMOOP
# float64    311282        0      0.0      TEHBDedCombInnOonFamily
# float64    268916    42366    0.136      TEHBDedCombInnOonFamilyPerGroup
# float64    268916    42366    0.136      TEHBDedCombInnOonFamilyPerPerson
# float64    311282        0      0.0      TEHBDedInnTier1Family
# float64    133308   177974    0.572      TEHBDedInnTier1FamilyPerGroup
# float64    136620   174662    0.561      TEHBDedInnTier1FamilyPerPerson
# float64    311282        0      0.0      TEHBDedInnTier2Family
# float64    275402    35880    0.115      TEHBDedInnTier2FamilyPerGroup
# float64    275402    35880    0.115      TEHBDedInnTier2FamilyPerPerson
# float64    311282        0      0.0      TEHBDedOutOfNetFamily
# float64    247848    63434    0.204      TEHBDedOutOfNetFamilyPerGroup
# float64    251160    60122    0.193      TEHBDedOutOfNetFamilyPerPerson
# float64    311282        0      0.0      TEHBInnTier1FamilyMOOP
# float64         0   311282      1.0      TEHBInnTier1FamilyPerGroupMOOP
# float64         0   311282      1.0      TEHBInnTier1FamilyPerPersonMOOP
# float64    311282        0      0.0      TEHBInnTier2FamilyMOOP
# float64    270112    41170    0.132      TEHBInnTier2FamilyPerGroupMOOP
# float64    270112    41170    0.132      TEHBInnTier2FamilyPerPersonMOOP
# float64    311282        0      0.0      TEHBOutOfNetFamilyMOOP
# float64    251298    59984    0.193      TEHBOutOfNetFamilyPerGroupMOOP
# float64    251298    59984    0.193      TEHBOutOfNetFamilyPerPersonMOOP
# float64         0   311282      1.0      SBCHavingDiabetesCopayment
# float64         0   311282      1.0      SBCHavingDiabetesDeductible
# float64         0   311282      1.0      SBCHavingDiabetesLimit
# float64         0   311282      1.0      SBCHavingaBabyCopayment
# float64         0   311282      1.0      SBCHavingaBabyDeductible
# float64         0   311282      1.0      SBCHavingaBabyLimit
# float64         0   311282      1.0      PlanType_EPO
# float64         0   311282      1.0      PlanType_HMO
# float64         0   311282      1.0      PlanType_POS
# float64         0   311282      1.0      PlanType_PPO
# float64         0   311282      1.0      QHP_Both
# float64         0   311282      1.0      QHP_On the Exchange

# %% [markdown]
# The attributes below have no missing values

# %%
noNeed = ['BusinessYear','IssuerId'] #In this case, BusinessYear is added to the list as we are only looking at 2016.
noNulls = []
for column in df.columns:
    if ((df[column].notnull().sum()/df[column].notnull().count() == 1) and (df[column].dtype != 'object')
       and (column not in noNeed)):
        print ('{0:6} {1:20}'.format(df[column].notnull().sum()/df[column].notnull().count(),column))
        noNulls.append(column)
# Out:
#    1.0 Tobacco
#    1.0 Age
#    1.0 IndividualRate
#    1.0 BeginCostSharingAfterNumberOfVisits
#    1.0 BeginDedCoinsAfterNumberOfCopays
#    1.0 ChildOnlyOffering
#    1.0 CompositeRatingOffered
#    1.0 DentalOnlyPlan
#    1.0 EHBPercentTotalPremium
#    1.0 FirstTierUtilization
#    1.0 InpatientCopayMaxDays
#    1.0 IsHSAEligible
#    1.0 IsNewPlan
#    1.0 IsNoticeRequiredForPregnancy
#    1.0 IsReferralRequiredForSpecialist
#    1.0 MarketCoverage
#    1.0 MedicalDrugDeductiblesIntegrated
#    1.0 MedicalDrugMaximumOutofPocketIntegrated
#    1.0 MultipleInNetworkTiers
#    1.0 NationalNetwork
#    1.0 OutOfCountryCoverage
#    1.0 OutOfServiceAreaCoverage
#    1.0 UniquePlanDesign
#    1.0 WellnessProgramOffered
#    1.0 SBCHavingDiabetesCoinsurance
#    1.0 SBCHavingaBabyCoinsurance
#    1.0 TEHBInnTier1IndividualMOOP
#    1.0 TEHBInnTier1FamilyPerGroupMOOP
#    1.0 TEHBInnTier1FamilyPerPersonMOOP
#    1.0 SBCHavingDiabetesCopayment
#    1.0 SBCHavingDiabetesDeductible
#    1.0 SBCHavingDiabetesLimit
#    1.0 SBCHavingaBabyCopayment
#    1.0 SBCHavingaBabyDeductible
#    1.0 SBCHavingaBabyLimit
#    1.0 PlanType_EPO
#    1.0 PlanType_HMO
#    1.0 PlanType_POS
#    1.0 PlanType_PPO
#    1.0 QHP_Both
#    1.0 QHP_On the Exchange

# %% [markdown]
# The following 5 attributes have at least 50% of their data available and will thus be imputed with their medians

# %%
imputed = []
for column in df.columns:
    if ((column not in noNulls) and (df[column].dtype != 'object') and (column not in noNeed)
       and ( df[column].notnull().sum()/df[column].notnull().count() > 0.5 )):
        print ('{0:6} {1:20}'.format(round(df[column].notnull().sum()/df[column].notnull().count(),4),column))
        imputed.append(column)
# Out:
# 0.9636 IndividualTobaccoRate
# 0.5717 TEHBDedInnTier1Coinsurance
# 0.5717 TEHBDedInnTier1Individual
# 0.5717 TEHBDedInnTier1FamilyPerGroup
# 0.5611 TEHBDedInnTier1FamilyPerPerson

# %%
df.IndividualTobaccoRate = df.IndividualTobaccoRate.fillna(df.IndividualTobaccoRate.median()) #median
df.TEHBDedInnTier1Coinsurance = df.TEHBDedInnTier1Coinsurance.fillna(df.TEHBDedInnTier1Coinsurance.median()) #median
df.TEHBDedInnTier1Individual = df.TEHBDedInnTier1Individual.fillna(df.TEHBDedInnTier1Individual.median()) #median
df.TEHBDedInnTier1FamilyPerGroup = df.TEHBDedInnTier1FamilyPerGroup.fillna(df.TEHBDedInnTier1FamilyPerGroup.median()) #median
df.TEHBDedInnTier1FamilyPerPerson = df.TEHBDedInnTier1FamilyPerPerson.fillna(df.TEHBDedInnTier1FamilyPerPerson.median()) #median

# %% [markdown]
# ### We now have a preliminary list, colX, of attributes to build a supervised classification model.

# %%
colX = noNulls + imputed

# %% [markdown]
# We will inspect attributes to define them as continuous, categorical, or oneLevel by looking at the number of distinct values that appear in the attribute. oneLevel attributes will not move forward in the analysis as they offer no information in the classification process.

# %%
#establish arrays for continuous, one level and categorical variables
continuous = []
categorical = []
oneLevel = []
for col in colX:
    if df[col].unique().size > 2:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Continuous', df[col].dtype ,col))
        continuous.append(col)
    elif df[col].unique().size == 1:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'One Level', df[col].dtype ,col))
        oneLevel.append(col)
    else:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Categorical', df[col].dtype ,col))
        categorical.append(col)
# Out:
#      2 Categorical  int64      Tobacco
#     46 Continuous   float64    Age
#  48112 Continuous   float64    IndividualRate
#      5 Continuous   float64    BeginCostSharingAfterNumberOfVisits
#      4 Continuous   float64    BeginDedCoinsAfterNumberOfCopays
#      2 Categorical  float64    ChildOnlyOffering
#      1 One Level    float64    CompositeRatingOffered
#      1 One Level    float64    DentalOnlyPlan
#     60 Continuous   float64    EHBPercentTotalPremium
#      3 Continuous   float64    FirstTierUtilization
#      3 Continuous   float64    InpatientCopayMaxDays
#      2 Categorical  float64    IsHSAEligible
#      2 Categorical  float64    IsNewPlan
#      2 Categorical  float64    IsNoticeRequiredForPregnancy
#      2 Categorical  float64    IsReferralRequiredForSpecialist
#      1 One Level    float64    MarketCoverage
#      2 Categorical  float64    MedicalDrugDeductiblesIntegrated
#      1 One Level    float64    MedicalDrugMaximumOutofPocketIntegrated
#      2 Categorical  float64    MultipleInNetworkTiers
#      2 Categorical  float64    NationalNetwork
#      2 Categorical  float64    OutOfCountryCoverage
#      2 Categorical  float64    OutOfServiceAreaCoverage
#      2 Categorical  float64    UniquePlanDesign
#      2 Categorical  float64    WellnessProgramOffered
#     80 Continuous   float64    SBCHavingDiabetesCoinsurance
#    132 Continuous   float64    SBCHavingaBabyCoinsurance
#     81 Continuous   float64    TEHBInnTier1IndividualMOOP
#     84 Continuous   float64    TEHBInnTier1FamilyPerGroupMOOP
#     82 Continuous   float64    TEHBInnTier1FamilyPerPersonMOOP
#    105 Continuous   float64    SBCHavingDiabetesCopayment
#     81 Continuous   float64    SBCHavingDiabetesDeductible
#      6 Continuous   float64    SBCHavingDiabetesLimit
#     53 Continuous   float64    SBCHavingaBabyCopayment
#    119 Continuous   float64    SBCHavingaBabyDeductible
#      5 Continuous   float64    SBCHavingaBabyLimit
#      2 Categorical  float64    PlanType_EPO
#      2 Categorical  float64    PlanType_HMO
#      2 Categorical  float64    PlanType_POS
#      2 Categorical  float64    PlanType_PPO
#      2 Categorical  float64    QHP_Both
#      2 Categorical  float64    QHP_On the Exchange
#  51349 Continuous   float64    IndividualTobaccoRate
#     11 Continuous   float64    TEHBDedInnTier1Coinsurance
#     84 Continuous   float64    TEHBDedInnTier1Individual
#     95 Continuous   float64    TEHBDedInnTier1FamilyPerGroup
#     80 Continuous   float64    TEHBDedInnTier1FamilyPerPerson

# %%
#adding the columns that will be used for analysis
#these are the independent variables
#this excludes the One Level variables
colX = continuous + categorical

# %% [markdown]
# ### Attribute Analysis - Collinearity

# %%
tmp = df[continuous].sample(frac=0.1) #sampled 10% to save time in drawing correlation matrix
print (tmp.shape)

# Compute the correlation matrix
corr = tmp.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = False

sns.set(style="darkgrid")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16,16))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={"shrink": .75}, ax=ax, annot = True, fmt = '.2f')
# Out:
# (31128, 23)

# %% [markdown]
# The above correlation matrix shows a large amount of collinearity between a couple of the attributes, 97%+ Pearson's Correlation. Five attributes will be removed for modeling as they appear to be redundant. The attributes are listed below.
#
# We will create a temporary array for the attributes that we wish to keep in the model by removing attributes showed the highest collinearity.  We will then repeat the process of creating arrays for the continuous and categorical variables (An update).

# %%
collinear = ['TEHBInnTier1FamilyPerGroupMOOP','TEHBInnTier1FamilyPerPersonMOOP',
             'TEHBDedInnTier1FamilyPerGroup','TEHBDedInnTier1FamilyPerPerson',
             'IndividualTobaccoRate']

tmp = []
for col in colX:
    if col not in collinear:
        tmp.append(col)
        
colX = tmp

# %%
continuous = []
categorical = []
oneLevel = []
for col in colX:
    if df[col].unique().size > 2:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Continuous', df[col].dtype ,col))
        continuous.append(col)
    elif df[col].unique().size == 1:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'One Level', df[col].dtype ,col))
        oneLevel.append(col)
    else:
        print('{0:6} {1:12} {2!s:10} {3:20}'.format(df[col].unique().size,'Categorical', df[col].dtype ,col))
        categorical.append(col)
# Out:
#     46 Continuous   float64    Age
#  48112 Continuous   float64    IndividualRate
#      5 Continuous   float64    BeginCostSharingAfterNumberOfVisits
#      4 Continuous   float64    BeginDedCoinsAfterNumberOfCopays
#     60 Continuous   float64    EHBPercentTotalPremium
#      3 Continuous   float64    FirstTierUtilization
#      3 Continuous   float64    InpatientCopayMaxDays
#     80 Continuous   float64    SBCHavingDiabetesCoinsurance
#    132 Continuous   float64    SBCHavingaBabyCoinsurance
#     81 Continuous   float64    TEHBInnTier1IndividualMOOP
#    105 Continuous   float64    SBCHavingDiabetesCopayment
#     81 Continuous   float64    SBCHavingDiabetesDeductible
#      6 Continuous   float64    SBCHavingDiabetesLimit
#     53 Continuous   float64    SBCHavingaBabyCopayment
#    119 Continuous   float64    SBCHavingaBabyDeductible
#      5 Continuous   float64    SBCHavingaBabyLimit
#     11 Continuous   float64    TEHBDedInnTier1Coinsurance
#     84 Continuous   float64    TEHBDedInnTier1Individual
#      2 Categorical  int64      Tobacco
#      2 Categorical  float64    ChildOnlyOffering
#      2 Categorical  float64    IsHSAEligible
#      2 Categorical  float64    IsNewPlan
#      2 Categorical  float64    IsNoticeRequiredForPregnancy
#      2 Categorical  float64    IsReferralRequiredForSpecialist
#      2 Categorical  float64    MedicalDrugDeductiblesIntegrated
#      2 Categorical  float64    MultipleInNetworkTiers
#      2 Categorical  float64    NationalNetwork
#      2 Categorical  float64    OutOfCountryCoverage
#      2 Categorical  float64    OutOfServiceAreaCoverage
#      2 Categorical  float64    UniquePlanDesign
#      2 Categorical  float64    WellnessProgramOffered
#      2 Categorical  float64    PlanType_EPO
#      2 Categorical  float64    PlanType_HMO
#      2 Categorical  float64    PlanType_POS
#      2 Categorical  float64    PlanType_PPO
#      2 Categorical  float64    QHP_Both
#      2 Categorical  float64    QHP_On the Exchange

# %%
tmp = df[continuous].sample(frac=0.1)
print (tmp.shape)

# Compute the correlation matrix
corr = tmp.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = False

sns.set(style="darkgrid")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16,16))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={"shrink": .75}, ax=ax, annot = True, fmt = '.2f')
# Out:
# (31128, 18)

# %% [markdown]
# ### Based on the updated correlation matrix, we have reduced the collinearity by removing specific attributes. We are now ready to begin building models with these updated set of attributes.

# %%
colX = continuous + categorical

# %% [markdown]
# ### To speed up the grid search process, we randomly sampled 30% of the available data. This will assist us in finding optimal model parameters. Once the parameters are determined, we will build models using the entire dataset

# %%
#we randomly downsample to speed up the grid search process
downsample = df.sample(frac=0.3)
print (downsample.shape)
# Out:
# (93385, 155)

# %% [markdown]
# ### Perform GridSearch for SGDClassifier

# %%
cv = ShuffleSplit(n = len(downsample), n_iter=10, test_size=0.3, random_state=42)

parameters = {'alpha': [0.0001, 0.01, 0.1, 1, 10, 100], 
              'loss':['hinge','log','modified_huber','squared_hinge','perceptron'], 
              'penalty' : ['l2','l1','elasticnet'], 
              'class_weight': ['balanced']}

# %% [markdown]
# Before we run the grid search process, we made sure that the continuous variables are the only ones being scaled by the StandardScaler. Once we apply the StandardScaler on the continuous variables, we then concatenate the scaled data with the categorical data and pass it to the GridSearch process. If we had applied the StandardScaler on all the data, the binary categorical attributes would have been shifted and normalized.

# %%
sgd = SGDClassifier(n_jobs=-1)
gs = GridSearchCV(sgd, parameters, cv=cv)

scl_obj = StandardScaler()
scl_obj.fit(downsample[continuous])

X = scl_obj.transform(downsample[continuous])

X = pd.DataFrame(data = X, index = downsample[continuous].index, columns=continuous)

X = pd.concat([X,downsample[categorical]], axis=1)

gs.fit(X, downsample['MetalLevel'])
# Out:
# GridSearchCV(cv=ShuffleSplit(93385, n_iter=10, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=-1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'class_weight': ['balanced'], 'penalty': ['l2', 'l1', 'elasticnet'], 'loss': ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'], 'alpha': [0.0001, 0.01, 0.1, 1, 10, 100]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
sorted(gs.grid_scores_,key=lambda x: x[1], reverse=True) #sorted grid scores
# Out:
# [mean: 0.73005, std: 0.01881, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.72541, std: 0.00769, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.71784, std: 0.00977, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.71609, std: 0.00334, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.71517, std: 0.00695, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.71482, std: 0.00306, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.71425, std: 0.00444, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.71389, std: 0.02029, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.71335, std: 0.00936, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.70716, std: 0.02612, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.70648, std: 0.02615, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.70332, std: 0.00799, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.70268, std: 0.00263, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.70198, std: 0.02993, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.69960, std: 0.00362, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.69174, std: 0.00269, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.69053, std: 0.00444, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.68789, std: 0.03711, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.68499, std: 0.00416, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.68359, std: 0.00258, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.68038, std: 0.05055, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.67781, std: 0.00462, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.66299, std: 0.01194, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.66151, std: 0.01075, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.65988, std: 0.04123, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.65885, std: 0.06793, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.65504, std: 0.05305, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.65403, std: 0.00883, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.65372, std: 0.05959, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.65087, std: 0.02573, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.65044, std: 0.00413, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.64998, std: 0.01908, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.64967, std: 0.02335, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.64863, std: 0.01165, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.64826, std: 0.02441, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.64781, std: 0.07889, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.64528, std: 0.06682, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 0.01},
#  mean: 0.64447, std: 0.05738, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 0.0001},
#  mean: 0.64006, std: 0.01043, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.63984, std: 0.00732, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.63708, std: 0.00179, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.63708, std: 0.00179, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.63708, std: 0.00179, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.63515, std: 0.04409, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.63507, std: 0.05201, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 0.01},
#  mean: 0.63310, std: 0.08193, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 0.0001},
#  mean: 0.62367, std: 0.05401, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 0.01},
#  mean: 0.62088, std: 0.04815, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.61989, std: 0.04809, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 0.0001},
#  mean: 0.61698, std: 0.01852, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.61290, std: 0.14768, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.60906, std: 0.09030, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.60139, std: 0.08812, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.59309, std: 0.13268, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.59258, std: 0.13338, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.59018, std: 0.07647, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.58585, std: 0.15340, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.55886, std: 0.09515, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.55219, std: 0.01586, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.54358, std: 0.18831, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.54203, std: 0.19094, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.54145, std: 0.19130, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.53020, std: 0.21604, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.52857, std: 0.22786, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.52344, std: 0.22759, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.52082, std: 0.04713, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 1},
#  mean: 0.51924, std: 0.22732, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 10},
#  mean: 0.49838, std: 0.21342, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.49740, std: 0.21356, params: {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.49079, std: 0.22374, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 100},
#  mean: 0.48753, std: 0.22288, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.48751, std: 0.23443, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.48000, std: 0.24195, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.46899, std: 0.26014, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 10},
#  mean: 0.43594, std: 0.24969, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.42761, std: 0.15935, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'elasticnet', 'alpha': 0.1},
#  mean: 0.41863, std: 0.27169, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.41298, std: 0.17633, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.40189, std: 0.23646, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.39093, std: 0.24923, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.38535, std: 0.25459, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 10},
#  mean: 0.37557, std: 0.26743, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.35114, std: 0.23473, params: {'class_weight': 'balanced', 'loss': 'modified_huber', 'penalty': 'l1', 'alpha': 100},
#  mean: 0.33482, std: 0.11369, params: {'class_weight': 'balanced', 'loss': 'squared_hinge', 'penalty': 'l2', 'alpha': 0.1},
#  mean: 0.30135, std: 0.24805, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 0.1},
#  mean: 0.29198, std: 0.23584, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l2', 'alpha': 100},
#  mean: 0.24453, std: 0.26268, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.22354, std: 0.18560, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'elasticnet', 'alpha': 1},
#  mean: 0.17220, std: 0.23940, params: {'class_weight': 'balanced', 'loss': 'hinge', 'penalty': 'l1', 'alpha': 1},
#  mean: 0.16363, std: 0.16557, params: {'class_weight': 'balanced', 'loss': 'perceptron', 'penalty': 'elasticnet', 'alpha': 1}]

# %%
print (gs.best_score_, gs.best_params_) #best grid score with corresponding parameters
# Out:
# 0.730054254712 {'class_weight': 'balanced', 'loss': 'log', 'penalty': 'l1', 'alpha': 0.0001}

# %% [markdown]
# ### Build an SGD Classifier model with the optimal GridSearch parameter values and assess accuracy score
#
# ### In this case, we use the entire dataset, not the downsample

# %%
scl_obj = StandardScaler()
scl_obj.fit(df[continuous])

X = scl_obj.transform(df[continuous])

X = pd.DataFrame(data = X, index=df[continuous].index, columns=continuous)

X = pd.concat([X, df[categorical]],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df['MetalLevel'], 
                                                    test_size=0.30, random_state=42)

cv = ShuffleSplit(n = len(df['MetalLevel']), n_iter=10, test_size=0.3, random_state=42) #for cross validation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df['MetalLevel'], 
                                                    test_size=0.30, random_state=42)

gs_sgd = SGDClassifier(alpha=gs.best_params_['alpha'], 
                       loss=gs.best_params_['loss'], 
                       penalty=gs.best_params_['penalty'], 
                       class_weight=gs.best_params_['class_weight'])

scores = cross_val_score(gs_sgd, X, df['MetalLevel'], cv=cv)
print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 1.96))

gs_sgd.fit(X_train, y_train)
yhat = gs_sgd.predict(X_test)

labels = ['Catastrophic','Bronze','Silver','Gold','Platinum']
conf = confusion_matrix(y_test, yhat, labels)
acc = accuracy_score(y_test, yhat)

print (conf)
print (acc)
# Out:
# Accuracy: 0.733 (+/- 0.021)
# [[ 1597    20     8     0     0]
#  [  368 12188  4821   740   116]
#  [    0  6484 45567  6540   863]
#  [    0  1157  3641  6558   510]
#  [    0     3    94    91  2019]]
# 0.727408041977

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, 
                      title='        Confusion Matrix: Individual (SGDClassifier)\n',
                      labels=labels)

# %% [markdown]
# The SGDClassifier generates a set of weights for each class (One-vs-All approach). To determine which attributes are most influential in this model, we normalized each weight set and plotted the weights by attribute for the 5 classes on the same bar plot. Visually there is no clear indication that 1 or a couple of attributes are most important. We also ran a Recursive Feature Elimination (RFE) function on the data but the top 10 features do not seem to reflect what we see visually. It appears that the RFE may only operate on one of the set of weights.
#
# We will try a random forests classfier next and take a look at its feature importances to see if theres a better relationship.

# %%
weights = []
for metal in range(0, len(gs_sgd.classes_)):
    weights.append(pd.Series(abs(gs_sgd.coef_[metal]),index=colX))

allWeights = pd.concat(weights,axis=1)

for metal in range(0, len(gs_sgd.classes_)):
    allWeights = allWeights.rename(columns={metal:gs_sgd.classes_[metal]})
    allWeights[gs_sgd.classes_[metal]] = allWeights[gs_sgd.classes_[metal]]/abs(allWeights[gs_sgd.classes_[metal]]).max()

    
allWeights.sort_values('Bronze',ascending=True).plot(kind='barh',stacked=False,figsize=(14,24))

# allWeights.sort_values('Silver',ascending=True).plot(kind='barh',stacked=False,figsize=(14,24),
#                                                      colors=['#cd7f32','#8A0707','#ffd700','#F0F0F0','#606060'])

plt.xlim([0,1.1])
plt.xticks(np.arange(0, 1.05, .1))
plt.yticks(fontsize=12)
plt.title('One-v-All Coefficients: SGDClassifier \n', fontsize = 16)
plt.xlabel('Normalized Model Weights')
plt.legend(loc='best', fontsize = 'x-large',)

# %% [markdown]
# ### RFE Analysis

# %%
rfe = RFE(estimator=gs_sgd, n_features_to_select=10, step=1)
rfe.fit(X,df['MetalLevel'])
# Out:
# RFE(estimator=SGDClassifier(alpha=0.0001, average=False, class_weight='balanced',
#        epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', n_iter=5, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False),
#   estimator_params=None, n_features_to_select=10, step=1, verbose=0)

# %%
features = []
for i in range(0,len(colX)):
    if rfe.support_[i] == True:
        features.append(colX[i])

# %% [markdown]
# ### These features appear to be most associated with either the Platinum or Catastrophic Metal Levels.

# %%
print (features)
# Out:
# ['BeginCostSharingAfterNumberOfVisits', 'FirstTierUtilization', 'SBCHavingDiabetesCopayment', 'TEHBDedInnTier1Individual', 'Tobacco', 'ChildOnlyOffering', 'IsHSAEligible', 'MedicalDrugDeductiblesIntegrated', 'PlanType_EPO', 'QHP_Both']

# %% [markdown]
# ## Classification with RandomForests

# %%
cv = ShuffleSplit(n = len(downsample['MetalLevel']), n_iter=10, test_size=0.3, random_state=42)

parameters = {'n_estimators': [5,10,15,20,25],
              'criterion':['gini','entropy'],
              'max_features':['sqrt','log2'],
              'class_weight': ['balanced']}

# %%
rf = RandomForestClassifier(n_jobs=-1)
gsrf = GridSearchCV(rf, parameters, cv=cv)

gsrf.fit(downsample[colX], downsample['MetalLevel'])
# Out:
# GridSearchCV(cv=ShuffleSplit(93385, n_iter=10, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'criterion': ['gini', 'entropy'], 'n_estimators': [5, 10, 15, 20, 25], 'max_features': ['sqrt', 'log2'], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
sorted(gsrf.grid_scores_,key=lambda x: x[1], reverse=True)
# Out:
# [mean: 0.95789, std: 0.00073, params: {'criterion': 'entropy', 'n_estimators': 25, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95789, std: 0.00092, params: {'criterion': 'entropy', 'n_estimators': 20, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95783, std: 0.00106, params: {'criterion': 'gini', 'n_estimators': 25, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95780, std: 0.00104, params: {'criterion': 'gini', 'n_estimators': 20, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95763, std: 0.00095, params: {'criterion': 'gini', 'n_estimators': 25, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95761, std: 0.00082, params: {'criterion': 'gini', 'n_estimators': 20, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95758, std: 0.00085, params: {'criterion': 'entropy', 'n_estimators': 25, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95756, std: 0.00105, params: {'criterion': 'entropy', 'n_estimators': 20, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95755, std: 0.00114, params: {'criterion': 'entropy', 'n_estimators': 15, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95748, std: 0.00067, params: {'criterion': 'gini', 'n_estimators': 15, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95739, std: 0.00095, params: {'criterion': 'gini', 'n_estimators': 15, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95706, std: 0.00130, params: {'criterion': 'entropy', 'n_estimators': 15, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95694, std: 0.00056, params: {'criterion': 'gini', 'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95672, std: 0.00135, params: {'criterion': 'entropy', 'n_estimators': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95636, std: 0.00095, params: {'criterion': 'gini', 'n_estimators': 10, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95635, std: 0.00091, params: {'criterion': 'entropy', 'n_estimators': 10, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95449, std: 0.00093, params: {'criterion': 'gini', 'n_estimators': 5, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95431, std: 0.00120, params: {'criterion': 'gini', 'n_estimators': 5, 'max_features': 'sqrt', 'class_weight': 'balanced'},
#  mean: 0.95409, std: 0.00124, params: {'criterion': 'entropy', 'n_estimators': 5, 'max_features': 'log2', 'class_weight': 'balanced'},
#  mean: 0.95383, std: 0.00133, params: {'criterion': 'entropy', 'n_estimators': 5, 'max_features': 'sqrt', 'class_weight': 'balanced'}]

# %%
print (gsrf.best_score_, gsrf.best_params_)
# Out:
# 0.957888349515 {'criterion': 'entropy', 'n_estimators': 25, 'max_features': 'sqrt', 'class_weight': 'balanced'}

# %% [markdown]
# ### We will now fit a Random Forests model with the entire dataset given the optimal grid search parameters

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

# %%
gsrf_model = RandomForestClassifier(n_estimators = gsrf.best_params_['n_estimators'],
                                    criterion = gsrf.best_params_['criterion'],
                                 max_features = gsrf.best_params_['max_features'],
                                 class_weight = gsrf.best_params_['class_weight'],
                                   n_jobs=-1)

scores = cross_val_score(gsrf_model, df[colX] , df['MetalLevel'], cv=cv)
print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 1.96))

gsrf_model.fit(X_train,y_train)
yhat = gsrf_model.predict(X_test)

conf = confusion_matrix(y_test,yhat,labels)
acc = accuracy_score(y_test,yhat)

print (conf)
print (acc)
# Out:
# Accuracy: 0.979 (+/- 0.001)
# [[ 1625     0     0     0     0]
#  [    0 17355   850    28     0]
#  [    0   805 57985   653    11]
#  [    0    38   614 10997   217]
#  [    0     0    13   172  2022]]
# 0.963580874873

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, 
                      title='        Confusion Matrix: Individual (RandomForests)\n',
                      labels=labels)

# %% [markdown]
# Given the high accuracy achieved, the bar plot of the feature importances shows that the Maximum out of pocket, deductibles, and individual premium rates are most important in classifying the metal levels. It is interesting to note that most of the categorical variables are not as influential as they appear to be in the linear SGD classifier model.

# %%
plt.figure(figsize=(12, 12))
weights = pd.Series(gsrf_model.feature_importances_,index=colX)
weights = weights.sort_values(ascending=True)
weights.plot(kind='barh')

# %% [markdown]
# ### In running an RFE with the random forests model, we do get a set of attributes that very much agrees with the feature importances.

# %%
rfe = RFE(estimator=gsrf_model, n_features_to_select=10, step=1)
rfe.fit(df[colX],df['MetalLevel'])
# Out:
# RFE(estimator=RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='entropy', max_depth=None, max_features='sqrt',
#             max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#   estimator_params=None, n_features_to_select=10, step=1, verbose=0)

# %%
features = []
for i in range(0,len(colX)):
    if rfe.support_[i] == True:
        features.append(colX[i])

# %%
print (features)
# Out:
# ['Age', 'IndividualRate', 'EHBPercentTotalPremium', 'TEHBInnTier1IndividualMOOP', 'SBCHavingDiabetesCopayment', 'SBCHavingDiabetesDeductible', 'SBCHavingaBabyDeductible', 'SBCHavingaBabyLimit', 'TEHBDedInnTier1Individual', 'MedicalDrugDeductiblesIntegrated']

# %% [markdown]
# ### Weight Comparison Plots
#
# ### When we compare the feature importances from Random Forests and the OVA weights from the SGD classifier in a bar plot, we see that there is some agreement between the models in terms of which attributes are most important. This mostly occurs with the continuous variables. The most disagreement is seen with the categorical variables. The plot below is sorted by Random Forest importances.

# %%
SGDweights = allWeights
weightsRF = pd.Series(gsrf_model.feature_importances_,index=colX)

allWeights = pd.concat([SGDweights,weightsRF],axis=1)
allWeights = allWeights.rename(columns={0:'RandomForests'})

allWeights['RandomForests'] = allWeights.RandomForests/allWeights.RandomForests.max()

allWeights.sort_values('RandomForests', ascending=True).plot(kind='barh',stacked=False,figsize=(12,24))
plt.xlim([0,1.1])
plt.xticks(np.arange(0, 1.05, .1))
plt.yticks(fontsize=11)
plt.title('Model Comparison: Weight Coefficients\n', fontsize = 16)
plt.xlabel('Normalized Model Weights')
plt.legend(loc='best', fontsize = 'x-large')

# %% [markdown]
# ### We will now try KNN Classifier
#
# ### We dropped the ShuffleSplit cv folds to 3 from 10 because knn is computationally intensive. Similarly, we restricted the n neighbors numbers to odd values to break ties and to reduce the neighbor values to try. To run the grid search we are also using downsampled data as before.

# %%
cv = ShuffleSplit(n = len(downsample['MetalLevel']), n_iter=3, test_size=0.3, random_state=42)

parameters = {'n_jobs': [-1],
              'n_neighbors': [1, 3, 5, 7, 9],
              'weights': ['uniform', 'distance'],
              'metric': ['euclidean', 'minkowski']}

# %%
knn = KNeighborsClassifier()
gs = GridSearchCV(knn, parameters, cv=cv, n_jobs=-1, verbose=10)

gs.fit(downsample[colX], downsample['MetalLevel'])
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.893525 -   8.6s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.893525 -   9.2s
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.892847 -   9.5s
# [CV] n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=uniform, n_jobs=-1, score=0.896274 -   9.5s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.892847 -   8.8s
# [CV] n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   18.0s
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.889670 -  10.0s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.892097 -  10.4s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=euclidean, weights=distance, n_jobs=-1, score=0.896274 -  10.7s
# [CV] n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=euclidean, weights=uniform, n_jobs=-1, score=0.895595 -  10.2s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.894382 -  10.6s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   31.0s
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.893597 -  10.9s
# [CV] n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=euclidean, weights=distance, n_jobs=-1, score=0.898915 -  11.2s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.889706 -   9.7s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.888492 -   8.6s
# [CV] n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.895988 -   9.2s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=uniform, n_jobs=-1, score=0.892990 -   9.6s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.894989 -   8.4s
# [CV] n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   46.8s
# [CV]  n_neighbors=5, metric=euclidean, weights=distance, n_jobs=-1, score=0.898736 -   8.8s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.889563 -   9.2s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.887921 -   9.2s
# [CV] n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=euclidean, weights=uniform, n_jobs=-1, score=0.892740 -   9.4s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.895774 -  10.0s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.898558 -   9.3s
# [CV]  n_neighbors=7, metric=euclidean, weights=distance, n_jobs=-1, score=0.895024 -   9.4s
# [CV] n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1 .....
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.0min
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.888956 -   9.4s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.887671 -   8.4s
# [CV] n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=9, metric=euclidean, weights=uniform, n_jobs=-1, score=0.891348 -   9.3s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.894846 -   9.3s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.894703 -   9.0s
# [CV] n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=9, metric=euclidean, weights=distance, n_jobs=-1, score=0.898629 -   8.7s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.893525 -   8.6s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.892847 -   8.8s
# [CV] n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=1, metric=minkowski, weights=uniform, n_jobs=-1, score=0.896274 -   8.7s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.4min
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.893525 -   9.3s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.892847 -   8.7s
# [CV] n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=1, metric=minkowski, weights=distance, n_jobs=-1, score=0.896274 -   9.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.892097 -   8.2s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.889670 -   8.1s
# [CV] n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.894382 -   8.4s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=uniform, n_jobs=-1, score=0.895595 -   9.4s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.893597 -   8.2s
# [CV] n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=3, metric=minkowski, weights=distance, n_jobs=-1, score=0.898915 -   8.3s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.7min
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.889706 -   8.7s
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.888492 -   8.6s
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=5, metric=minkowski, weights=uniform, n_jobs=-1, score=0.892990 -   8.9s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.895988 -   8.8s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.894989 -   8.9s
# [CV] n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=5, metric=minkowski, weights=distance, n_jobs=-1, score=0.898736 -   9.2s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.889563 -   8.5s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.887921 -   8.6s
# [CV] n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV]  n_neighbors=7, metric=minkowski, weights=uniform, n_jobs=-1, score=0.892740 -   8.6s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.895774 -   8.7s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.895024 -   9.1s
# [CV] n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1 .....
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  2.1min
# [CV]  n_neighbors=7, metric=minkowski, weights=distance, n_jobs=-1, score=0.898558 -   9.0s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.1min remaining:   -2.1s
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.888956 -   9.2s
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.887671 -   8.8s
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [CV] n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1 ....
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.2min remaining:   -2.2s
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.2min remaining:   -2.2s
# [CV]  n_neighbors=9, metric=minkowski, weights=uniform, n_jobs=-1, score=0.891348 -   8.5s
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.3min remaining:   -2.2s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.894846 -   8.3s
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.3min remaining:   -2.3s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.894703 -   7.6s
# [CV]  n_neighbors=9, metric=minkowski, weights=distance, n_jobs=-1, score=0.898629 -   7.7s
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.3min remaining:   -2.3s
# [Parallel(n_jobs=-1)]: Done  61 out of  60 | elapsed:  2.3min remaining:   -2.3s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.3min finished
# GridSearchCV(cv=ShuffleSplit(93385, n_iter=3, test_size=0.3, random_state=42),
#        error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'minkowski'], 'n_neighbors': [1, 3, 5, 7, 9], 'n_jobs': [-1]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=10)

# %%
sorted(gs.grid_scores_,key=lambda x: x[1], reverse=True)
# Out:
# [mean: 0.89657, std: 0.00158, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.89657, std: 0.00158, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.89645, std: 0.00152, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.89645, std: 0.00152, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.89606, std: 0.00182, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 9, 'n_jobs': -1},
#  mean: 0.89606, std: 0.00182, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 9, 'n_jobs': -1},
#  mean: 0.89563, std: 0.00234, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.89563, std: 0.00234, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.89422, std: 0.00148, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.89422, std: 0.00148, params: {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.89422, std: 0.00148, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.89422, std: 0.00148, params: {'weights': 'distance', 'metric': 'minkowski', 'n_neighbors': 1, 'n_jobs': -1},
#  mean: 0.89245, std: 0.00243, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.89245, std: 0.00243, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 3, 'n_jobs': -1},
#  mean: 0.89040, std: 0.00190, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.89040, std: 0.00190, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 5, 'n_jobs': -1},
#  mean: 0.89007, std: 0.00200, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.89007, std: 0.00200, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 7, 'n_jobs': -1},
#  mean: 0.88933, std: 0.00152, params: {'weights': 'uniform', 'metric': 'euclidean', 'n_neighbors': 9, 'n_jobs': -1},
#  mean: 0.88933, std: 0.00152, params: {'weights': 'uniform', 'metric': 'minkowski', 'n_neighbors': 9, 'n_jobs': -1}]

# %%
print (gs.best_score_, gs.best_params_)
# Out:
# 0.896571007044 {'weights': 'distance', 'metric': 'euclidean', 'n_neighbors': 5, 'n_jobs': -1}

# %% [markdown]
# ## The best average accuracy of the K Nearest Neighbor model on the downsample data set is 89.7%, with a euclidean metric, n neighbors of 5, and weights of distance.
# ## We will now apply these best parameters to the full data set.

# %%
X_train, X_test, y_train, y_test = train_test_split(df[colX], 
                                                    df['MetalLevel'], 
                                                    test_size=0.30,random_state=42)

gs_knn = KNeighborsClassifier(metric = gs.best_params_['metric'],
                                 n_neighbors = gs.best_params_['n_neighbors'],
                                 weights = gs.best_params_['weights'],
                                   n_jobs=-1)

scores = cross_val_score(gs_knn, df[colX] , df['MetalLevel'], cv=cv)
print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 1.96))

gs_knn.fit(X_train, y_train)
yhat = gs_knn.predict(X_test)

conf = confusion_matrix(y_test,yhat,labels)
acc = accuracy_score(y_test,yhat)

print (conf)
print (acc)
# Out:
# Accuracy: 0.931 (+/- 0.001)
# [[ 1588    37     0     0     0]
#  [   38 16153  1783   257     2]
#  [    0  1703 56302  1386    63]
#  [    0   299  1915  9417   235]
#  [    0     2   125   219  1861]]
# 0.91364780211

# %% [markdown]
# ## Applied to the full data set, the K Nearest Neighbors has a slightly better accuracy score of 91.3%.
# ## We will now plot the confusion matrix.

# %%
plt.figure(figsize=(8, 6))
conf_normalized = conf.astype('float') / conf.sum(axis=1)[:, np.newaxis]
plot_confusion_matrix(conf_normalized, 
                      title='        Confusion Matrix: Individual (KNN)\n',
                      labels=labels)

# %% [markdown]
# ## To summarize, the best model obtained for  binary classification was the SGD model with an accuracy of 100%.  The best model obtained for Multi-Class classification was the RandomForest model with an accuracy of 96%.
# ## Insurance companies may want to use these models to gain some insight into how their plans are perceived by customers. Customers often rely on Metal Levels to make decisions about plans and it could prove profitable to offer customers more insight into the main components that make up the plan and how it contributes to the Metal Level. One way to test this is to setup an A/B test where customer have more information based on these models while another group of customers do not.
